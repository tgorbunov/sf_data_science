# %% [markdown]
# # Итоговый проект первого года обучения

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #  2. Подготовка к сдаче итогового проекта

# %% [markdown]
# ### На работу над итоговым проектом отводится 3 недели. В течение этого срока вам необходимо будет определиться с темой, реализовать проект и загрузить решение на платформу.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # 3. Сдача итогового проекта

# %% [markdown]
# ![image.png](attachment:image.png)
