# %%
from warnings import filterwarnings

# %%
filterwarnings("ignore")

# %% [markdown]
# S&P 500 — фондовый индекс, в корзину которого включено 505 акций 500 избранных торгуемых на фондовых биржах США

# %%
import pandas as pd

data = pd.read_csv("data/SP500_data.csv", parse_dates=["Date"], index_col=["Date"])
data.head()
# Out:
#                    spx
# Date
# 1994-01-06  467.119995
# 1994-01-07  469.899994
# 1994-01-10  475.269989
# 1994-01-11  474.130005
# 1994-01-12  474.170013

# %%
from matplotlib import pyplot as plt

# %matplotlib inline

plt.rcParams["figure.figsize"] = 30, 12
plt.rcParams["font.size"] = 20
plt.rcParams["xtick.labelsize"] = 10
plt.rcParams["ytick.labelsize"] = 10
plt.rcParams["lines.linewidth"] = 3

data.plot()
plt.show()

# %%
train_df = data.loc[:"2018-12-31"]
test_df = data.loc["2019-01-01":]
train_df.shape, test_df.shape
# Out:
# ((6518, 1), (174, 1))

# %%
plt.rcParams["figure.figsize"] = 18, 5

for year in set(train_df.index.year):
    plt.plot(train_df[["spx"]].loc[train_df.index.year == year])
    plt.title(str(year), size=24)
    plt.show()

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

plt.rcParams["figure.figsize"] = 18, 20

result = seasonal_decompose(train_df.spx)
result.plot()
plt.show()

# %% [markdown]
# Сезонная компонента выглядит очень странно, посмотрим на первые 20 значений

# %%
plt.rcParams["figure.figsize"] = 10, 5
result.seasonal[:20].plot(marker="o")
plt.show()

# %% [markdown]
# График четко показывает повторяющийся цикл каждые 5 периодов. Это довольно логично, поскольку наши данные — это данные о ценах на акции. Мы наблюдаем и собираем данные о ценах на акции каждый рабочий день недели. Это означает, что данные представляли собой еженедельную сезонность, а неделя была рабочей неделей (5 дней в неделю)

# %%
plt.rcParams["figure.figsize"] = 18, 10

fig, ax = plt.subplots(2, 2)

# Окно в месяц (Window = 30)
ax[0, 0].plot(train_df.spx, color="blue", label="SPX Prices")
ax[0, 0].set_title("SPX Prices", size=24)
ax[0, 0].legend()

ax[0, 1].plot(
    train_df.spx.rolling(window=30).mean(),
    color="orange",
    label="Smoothed SPX Prices",
)

ax[0, 1].set_title("Moving Average (30) SPX Prices", size=24)
ax[0, 1].legend()


# Окно в год (Window = 300)
ax[1, 0].plot(train_df.spx, color="blue", label="SPX Prices")
ax[1, 0].set_title("SPX Prices", size=24)
ax[1, 0].legend()

ax[1, 1].plot(
    train_df.spx.rolling(window=300).mean(),
    color="orange",
    label="Smoothed SPX Prices",
)

ax[1, 1].set_title("Moving Average (300) SPX Prices", size=24)
ax[1, 1].legend()

plt.show()

# %%
import statsmodels.graphics.tsaplots as sgt

plt.rcParams["figure.figsize"] = 20, 5
sgt.plot_acf(train_df.spx, lags=360, zero=False)
plt.show()

# %% [markdown]
# цены SPX сильно коррелированы. Корреляция сохраняется даже по прошествии года.

# %%
import statsmodels.graphics.tsaplots as sgt

plt.rcParams["figure.figsize"] = 20, 5
sgt.plot_pacf(train_df.spx, lags=20, method="ywm", zero=False)
plt.show()

# %% [markdown]
# Эти графики показывают, как данные коррелируют с запаздывающей версией самих себя.
# В отличие от того, что предлагали графики ACF, цены SPX с лагом не приносят никакой новой информации. В таких ситуация параметр p выбирается =1

# %%
from statsmodels.tsa.stattools import adfuller

adfuller(train_df["spx"])
# Out:
# (np.float64(-0.3312809396965215),
#  np.float64(0.9209556878912162),
#  10,
#  6507,
#  {'1%': np.float64(-3.4313553606207843),
#   '5%': np.float64(-2.8619842833301883),
#   '10%': np.float64(-2.56700648865667)},
#  np.float64(53000.32567590042))

# %%
test1 = adfuller(train_df["spx"])
print("adf: ", test1[0])
print("p-value: ", test1[1])
print("Critical values: ", test1[4])
if test1[0] > test1[4]["5%"]:
    print("ряд нестационарен")
else:
    print("ряд стационарен")
# Out:
# adf:  -0.3312809396965215
# p-value:  0.9209556878912162
# Critical values:  {'1%': np.float64(-3.4313553606207843), '5%': np.float64(-2.8619842833301883), '10%': np.float64(-2.56700648865667)}
# ряд нестационарен

# %% [markdown]
# Статистика теста больше всех критических значений, поэтому нулевую гипотезу ($H_0$) нельзя отвергнуть.
#
# Поэтому цены SPX не являются стационарными

# %%
def plot_acf_pacf(series):
    plt.rcParams["figure.figsize"] = 18, 5

    fig, axes = plt.subplots(1, 2)

    sgt.plot_acf(series, ax=axes[0], lags=40)
    sgt.plot_pacf(series, ax=axes[1], lags=40, method="ywm")
    plt.show()

# %% [markdown]
# ## Дифференцирование ряда
# $y\_new_t = y_t - y_{t-1}$
#
# where,
# - $y\_new_t$: Дифференцированное значение ряда $t$
# - $y_t$: Фактическое значение ряда $t$
# - $y_{t-1}$: Фактическое значение ряда $t-1$

# %%
plot_acf_pacf(train_df["spx"].diff().dropna())
adfuller(train_df["spx"].diff().dropna())
# Out:
# (np.float64(-27.326250201731202),
#  0.0,
#  9,
#  6507,
#  {'1%': np.float64(-3.4313553606207843),
#   '5%': np.float64(-2.8619842833301883),
#   '10%': np.float64(-2.56700648865667)},
#  np.float64(52991.2781500849))

# %% [markdown]
# Первые разности являются стационарными

# %% [markdown]
# ## ARIMA, SARIMA

# %% [markdown]
# Начнем построение модели **ARIMA** со следующими параметрами:
#
# - p = 1
# - d = 1
# - q = 1
#
# Если рассматривать сезонную модель (**SARMA**), то в модель можно добавить следующие параметры.
#
# - m = 5 (будучи рыночным индексом, данные, скорее всего, будут иметь еженедельно повторяющиеся паттерны, как видно из визуализации)
# - P = 1
# - D = 1
# - Q = 1

# %%
from statsmodels.tsa.arima.model import ARIMA

arima_model = ARIMA(train_df["spx"].dropna(), order=(1, 1, 1))
arima_model_fit = arima_model.fit()
arima_model_fit.summary()
# Out:
# C:\Users\tgorbunov\AppData\Roaming\Python\Python310\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# C:\Users\tgorbunov\AppData\Roaming\Python\Python310\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# C:\Users\tgorbunov\AppData\Roaming\Python\Python310\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                    spx   No. Observations:                 6518
# Model:                 ARIMA(1, 1, 1)   Log Likelihood              -26625.675
# Date:                Sun, 08 Feb 2026   AIC                          53257.350
# Time:                        16:58:19   BIC                          53277.697
# Sample:                    01-06-1994   HQIC                         53264.387
#                          - 12-31-2018
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.7598      0.048     15.908      0.000       0.666       0.853
# ma.L1         -0.8016      0.044    -18.385      0.000      -0.887      -0.716
# sigma2       207.1124      1.766    117.304      0.000     203.652     210.573
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.02   Jarque-Bera (JB):             12081.79
# Prob(Q):                              0.88   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.93   Skew:                            -0.62
# Prob(H) (two-sided):                  0.00   Kurtosis:                         9.55
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

model = SARIMAX(train_df["spx"].dropna(), order=(1, 1, 1))
model_fit = model.fit()
model_fit.summary()
# Out:
# C:\Users\tgorbunov\AppData\Roaming\Python\Python310\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# C:\Users\tgorbunov\AppData\Roaming\Python\Python310\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                    spx   No. Observations:                 6518
# Model:               SARIMAX(1, 1, 1)   Log Likelihood              -26625.675
# Date:                Sun, 08 Feb 2026   AIC                          53257.350
# Time:                        16:58:43   BIC                          53277.697
# Sample:                    01-06-1994   HQIC                         53264.387
#                          - 12-31-2018
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.7598      0.048     15.908      0.000       0.666       0.853
# ma.L1         -0.8016      0.044    -18.385      0.000      -0.887      -0.716
# sigma2       207.1124      1.766    117.304      0.000     203.652     210.573
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.02   Jarque-Bera (JB):             12081.79
# Prob(Q):                              0.88   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.93   Skew:                            -0.62
# Prob(H) (two-sided):                  0.00   Kurtosis:                         9.55
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# Второй столбец раздела I содержит некоторые полезные показатели, которые используются для сравнения различных моделей ARIMA. Как правило, модель с более высоким логарифмическим правдоподобием или более низким IC (AIC, BIC или HQIC) лучше, и наоборот.

# %%
seas_model = SARIMAX(
    train_df["spx"].dropna(), order=(1, 1, 2), seasonal_order=(1, 1, 2, 5)
)

seas_model_fit = seas_model.fit()
seas_model_fit.summary()
# Out:
# C:\Users\tgorbunov\AppData\Roaming\Python\Python310\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# C:\Users\tgorbunov\AppData\Roaming\Python\Python310\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# C:\Users\tgorbunov\AppData\Roaming\Python\Python310\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# =========================================================================================
# Dep. Variable:                               spx   No. Observations:                 6518
# Model:             SARIMAX(1, 1, 2)x(1, 1, 2, 5)   Log Likelihood              -26617.829
# Date:                           Sun, 08 Feb 2026   AIC                          53249.657
# Time:                                   16:59:16   BIC                          53297.127
# Sample:                               01-06-1994   HQIC                         53266.074
#                                     - 12-31-2018
# Covariance Type:                             opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.1559      0.169      0.921      0.357      -0.176       0.488
# ma.L1         -0.1988      0.169     -1.180      0.238      -0.529       0.132
# ma.L2         -0.0333      0.011     -2.899      0.004      -0.056      -0.011
# ar.S.L5       -0.7733      0.081     -9.564      0.000      -0.932      -0.615
# ma.S.L5       -0.2576      0.085     -3.031      0.002      -0.424      -0.091
# ma.S.L10      -0.7416      0.086     -8.662      0.000      -0.909      -0.574
# sigma2       206.7671      1.990    103.912      0.000     202.867     210.667
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):             11680.34
# Prob(Q):                              0.99   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.91   Skew:                            -0.57
# Prob(H) (two-sided):                  0.00   Kurtosis:                         9.46
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
pred_df = pd.DataFrame(index=data.index)

pred_df["model_preds"] = seas_model_fit.predict(
    start=test_df.index[0], end=test_df.index[-1]
)


pred_df["spx"] = data["spx"]

forecast = seas_model_fit.get_forecast(len(test_df.index))
forecast_df = forecast.conf_int(alpha=0.05)  # Confidence level of 95%

pred_df.at[test_df.index, "model_preds_lower"] = forecast_df["lower spx"]
pred_df.at[test_df.index, "model_preds_upper"] = forecast_df["upper spx"]

# %%
plt.rcParams["figure.figsize"] = 18, 12

plt.subplot(2, 1, 1)
plt.plot(pred_df["spx"], color="blue", label="Actuals", alpha=0.4)

plt.plot(
    pred_df.loc[test_df.index]["model_preds"],
    color="red",
    linestyle="-",
    label="Out of Sample Fit",
)

plt.plot(
    pred_df.loc[test_df.index]["model_preds_lower"],
    color="green",
    linestyle="--",
    label="Confidence Intervals (95%)",
    alpha=0.4,
)

plt.plot(
    pred_df.loc[test_df.index]["model_preds_upper"],
    color="green",
    linestyle="--",
    alpha=0.4,
)

plt.title("Full Model Fit", size=24)
plt.legend()

plt.subplot(2, 2, 3)

plt.plot(
    pred_df.loc[test_df.index]["spx"], color="blue", label="Actuals", alpha=0.6
)

plt.plot(
    pred_df.loc[test_df.index]["model_preds"],
    color="red",
    linestyle="-",
    label="Out of Sample Fit",
    alpha=0.6,
)

plt.plot(
    pred_df.loc[test_df.index]["model_preds_lower"],
    color="green",
    linestyle="--",
    label="Confidence Intervals (95%)",
    alpha=0.6,
)

plt.plot(
    pred_df.loc[test_df.index]["model_preds_upper"],
    color="green",
    linestyle="--",
    alpha=0.6,
)

plt.title("Out of Sample Fit", size=24)
plt.legend()

plt.show()

# %%
#%pip install pmdarima
import pmdarima as pm

smodel = pm.auto_arima(
    train_df,
    start_p=1,
    d=1,
    start_q=1,
    max_p=3,
    max_q=3,
    D=1,
    start_P=0,
    m=5,
    test="adf",
    error_action="ignore",
    trace=True,
)

smodel.summary()
# Out:
# Collecting pmdarimaNote: you may need to restart the kernel to use updated packages.
#
#   Downloading pmdarima-2.1.1-cp310-cp310-win_amd64.whl (719 kB)
# Requirement already satisfied: scikit-learn>=0.22 in c:\users\tgorbunov\appdata\roaming\python\python310\site-packages (from pmdarima) (1.7.2)
# Requirement already satisfied: packaging>=17.1 in c:\users\tgorbunov\appdata\roaming\python\python310\site-packages (from pmdarima) (25.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\tgorbunov\appdata\roaming\python\python310\site-packages (from pmdarima) (1.5.2)
# Requirement already satisfied: setuptools!=50.0.0,>=42 in c:\users\tgorbunov\appdata\local\programs\python\python310\lib\site-packages (from pmdarima) (57.4.0)
# Requirement already satisfied: pandas>=0.19 in c:\users\tgorbunov\appdata\roaming\python\python310\site-packages (from pmdarima) (2.3.2)
# Requirement already satisfied: urllib3 in c:\users\tgorbunov\appdata\roaming\python\python310\site-packages (from pmdarima) (2.5.0)
# Collecting Cython!=0.29.18,!=0.29.31,>=0.29
#   Downloading cython-3.2.4-cp310-cp310-win_amd64.whl (2.8 MB)
# Requirement already satisfied: numpy>=1.21.6 in c:\users\tgorbunov\appdata\roaming\python\python310\site-packages (from pmdarima) (2.2.6)
# Requirement already satisfied: scipy>=1.13.0 in c:\users\tgorbunov\appdata\roaming\python\python310\site-packages (from pmdarima) (1.15.3)
# Requirement already satisfied: statsmodels>=0.14.5 in c:\users\tgorbunov\appdata\roaming\python\python310\site-packages (from pmdarima) (0.14.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\tgorbunov\appdata\roaming\python\python310\site-packages (from pandas>=0.19->pmdarima) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\tgorbunov\appdata\roaming\python\python310\site-packages (from pandas>=0.19->pmdarima) (2025.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\tgorbunov\appdata\roaming\python\python310\site-packages (from pandas>=0.19->pmdarima) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\tgorbunov\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.8.2->pandas>=0.19->pmdarima) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\tgorbunov\appdata\roaming\python\python310\site-packages (from scikit-learn>=0.22->pmdarima) (3.6.0)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\tgorbunov\appdata\roaming\python\python310\site-packages (from statsmodels>=0.14.5->pmdarima) (1.0.2)
# Installing collected packages: Cython, pmdarima
# Successfully installed Cython-3.2.4 pmdarima-2.1.1
#   WARNING: The scripts cygdb.exe, cython.exe and cythonize.exe are installed in 'c:\Users\tgorbunov\AppData\Local\Programs\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# WARNING: You are using pip version 21.2.3; however, version 26.0.1 is available.
# You should consider upgrading via the 'c:\Users\tgorbunov\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,1,1)[5]             : AIC=inf, Time=8.08 sec
#  ARIMA(0,1,0)(0,1,0)[5]             : AIC=57943.325, Time=0.34 sec
#  ARIMA(1,1,0)(1,1,0)[5]             : AIC=55834.625, Time=0.87 sec
#  ARIMA(0,1,1)(0,1,1)[5]             : AIC=inf, Time=3.14 sec
#  ARIMA(1,1,0)(0,1,0)[5]             : AIC=57939.123, Time=0.31 sec
#  ARIMA(1,1,0)(2,1,0)[5]             : AIC=55138.362, Time=1.69 sec
#  ARIMA(1,1,0)(2,1,1)[5]             : AIC=inf, Time=9.47 sec
#  ARIMA(1,1,0)(1,1,1)[5]             : AIC=inf, Time=4.64 sec
#  ARIMA(0,1,0)(2,1,0)[5]             : AIC=55142.946, Time=1.22 sec
#  ARIMA(2,1,0)(2,1,0)[5]             : AIC=55124.504, Time=2.04 sec
#  ARIMA(2,1,0)(1,1,0)[5]             : AIC=55827.531, Time=1.25 sec
#  ARIMA(2,1,0)(2,1,1)[5]             : AIC=inf, Time=11.91 sec
#  ARIMA(2,1,0)(1,1,1)[5]             : AIC=inf, Time=6.96 sec
#  ARIMA(3,1,0)(2,1,0)[5]             : AIC=55125.927, Time=2.39 sec
#  ARIMA(2,1,1)(2,1,0)[5]             : AIC=55141.925, Time=2.96 sec
#  ARIMA(1,1,1)(2,1,0)[5]             : AIC=inf, Time=11.38 sec
#  ARIMA(3,1,1)(2,1,0)[5]             : AIC=55127.935, Time=2.99 sec
#  ARIMA(2,1,0)(2,1,0)[5] intercept   : AIC=55126.507, Time=6.55 sec
#
# Best model:  ARIMA(2,1,0)(2,1,0)[5]
# Total fit time: 78.202 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# =========================================================================================
# Dep. Variable:                                 y   No. Observations:                 6518
# Model:             SARIMAX(2, 1, 0)x(2, 1, 0, 5)   Log Likelihood              -27557.252
# Date:                           Sun, 08 Feb 2026   AIC                          55124.504
# Time:                                   17:04:51   BIC                          55158.411
# Sample:                               01-06-1994   HQIC                         55136.230
#                                     - 12-31-2018
# Covariance Type:                             opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.0335      0.008     -4.447      0.000      -0.048      -0.019
# ar.L2         -0.0494      0.007     -7.204      0.000      -0.063      -0.036
# ar.S.L5       -0.6999      0.007    -99.802      0.000      -0.714      -0.686
# ar.S.L10      -0.3228      0.007    -43.233      0.000      -0.337      -0.308
# sigma2       277.3268      2.423    114.438      0.000     272.577     282.077
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):             11066.86
# Prob(Q):                              0.97   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.98   Skew:                             0.15
# Prob(H) (two-sided):                  0.00   Kurtosis:                         9.38
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """
