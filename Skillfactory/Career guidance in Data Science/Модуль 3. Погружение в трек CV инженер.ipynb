# %% [markdown]
# # Модуль 3. Погружение в трек «CV-инженер»

# %% [markdown]
# ## 1. Введение

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 2. Кто такой CV Engineer и чем он занимается

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
