# %% [markdown]
# # <center> S-learner, T-learner. Принципы работы. Практика

# %% [markdown]
# Итак, давайте поработаем с S- и T- learner`ами: вручную и с помощью библиотек [scikit-uplift](https://github.com/maks-sh/scikit-uplift) (sklift) и [CausalML](https://github.com/uber/causalml).

# %% [markdown]
# Для начала установим необходимые библиотеки:

# %%
#! pip install scikit-uplift causalml catboost

# %% [markdown]
# Импортируем необходимые библиотеки и загрузим семпл данных

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# Импортируем S- и T- learner`ы  (SoloModel и TwoModels) из библиотеки scikit-uplift (sklift)
from sklift.models import SoloModel, TwoModels

# Импортируем S- и T-learner`ы (BaseSClassifier и BaseTClassifier) из библиотеки CausalML
# Нам нужны именно Classifier, так как мы будем решать задачу классификации
# Аналогичные реализации (Regressor) есть и для задач регрессии
from causalml.inference.meta import BaseSClassifier, BaseTClassifier


# В качестве классификатора воспользуемся моделью градиентного бустинга от Яндекса (CatBoost)
from catboost import CatBoostClassifier

# Прочитаем файл с данными
df = pd.read_csv("data_add5/data.csv")
df.head()
# Out:
#    recency  history  used_discount  used_bogo   zip_code  is_referral channel  \
# 0       10   142.44              1          0  Surburban            0   Phone
# 1        6   329.08              1          1      Rural            1     Web
# 2        7   180.65              0          1  Surburban            1     Web
# 3        9   675.83              1          0      Rural            1     Web
# 4        2    45.34              1          0      Urban            0     Web
#
#          treatment  target_class
# 0  Buy One Get One             2
# 1         No Offer             0
# 2  Buy One Get One             2
# 3         Discount             2
# 4  Buy One Get One             2

# %% [markdown]
# **Справка о признаках:**
# * **recency** - количество месяцев с последней покупки клиента
# * **history** - общая стоимость исторических покупок
# * **used_discount** - указывает, пользовался ли клиент скидкой ранее
# * **used_bogo** - указывает, пользовался ли клиент промоакцией ранее
# * **zip_code** - класс почтового индекса:
#     * Suburban - пригородный
#     * Urban - городской
#     * Rural - сельский
# * **is_referral** - указывает, был ли клиент приобретен по реферальному каналу
# * **channel** - каналы, которые использует клиент:
#     * Phone - телефон
#     * Web - интернет
#     * Multichannel - многоканальный
# * **treatment** - вид целевого воздействия:
#     * **Discount** - было оказано целевое воздействие (предложена скидка)
#     * **Buy One Get One** - было оказано целевое воздействие (предложена промоакция)
#     * **No Offer** - целевого воздействие не было
# * **target_class** - класс клиента (вспомогательный признак):
#     * **0 - Control Non-Responders(CN)**
#
#         Это клиенты, которым не было выдвинуто предложение (целевое воздействие) и они ничего не купили ((y=0, c) в наших терминах)
#     * **1 - Control Responders(CR)**
#
#         Это клиенты, совершившие покупку без предложения (целевого воздействия) (y=1, c)
#     * **2 - Treatment Non-Responders(CN)**
#
#         Это клиенты, которым было выдвинуто предложение, но они не совершили покупку (y=0, t)
#     * **3 - Treatment Responders(CN)**
#
#         Это клиенты, которым было выдвинуто предложение (совершено целевое воздействие) и они совершили покупку (y=1, t)
#
# При построении классификатора нас интересует только факт того, совершил ли клиент покупку (класс 1) или нет (класс 0). Поэтому целевая переменная при классификации - конверсия.

# %% [markdown]
# Посмотрим на распределение целевых влияний в данных:
#
# * Discount - было оказано целевое влияние (предложена скидка)
# * Buy One Get One - было оказано целевое влияние (предложена промоакция)
# * No Offer - целевого влияния не было

# %%
df['treatment'].value_counts()
# Out:
# treatment
# Buy One Get One    21387
# Discount           21307
# No Offer           21306
# Name: count, dtype: int64

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# Подготовим данные:
# * Преобразуем целевую переменную в признак конверсии, которую будем прогнозировать (купил/не купил)
# * Создадим две отдельные таблицы:
#     * В первой будем хранить информацию о пользователях, которым была предложена скидка (df_discount)
#     * Во второй будем хранить информацию о пользователях, которым была предложена промоакция (df_bogo)
#
#     В каждой из таблиц также сохраним данные о пользователях, на которых не было оказано целевое влияние (контрольная выборка).
# * Также произведем кодировку категориальных признаков.

# %%
# Новый таргет - бинарная переменная (конверсия): 1 - купил, 0 - не купил
df['conversion'] = df['target_class'].map({0: 0, 1: 1, 2: 0, 3: 1})

# Разделим данные на две таблицы - данные по скидкам и промоакциям

# Выделим пользователей, на которых не было целевого воздействия, и тех, которым мы предлагали скидки
df_discount = df.copy().loc[
    (df['treatment'] == 'No Offer') |  (df['treatment'] == 'Discount')
].reset_index(drop=True)

# Выделим пользователей, на которых не было целевого воздействия, и тех, которым мы предлагали промоакции
df_bogo = df.copy().loc[
    (df['treatment'] == 'No Offer') | (df['treatment'] == 'Buy One Get One')
].reset_index(drop=True)

# Перекодируем столбец с влиянием: 1 - было влияние, 0 - не было
df_discount['treatment'] = df_discount['treatment'].apply(lambda x: 0 if x=='No Offer' else 1)
df_bogo['treatment'] = df_bogo['treatment'].apply(lambda x: 0 if x=='No Offer' else 1)

# Закодируем оставшиеся категориальные признаки
df_discount = pd.get_dummies(df_discount)
df_bogo = pd.get_dummies(df_bogo)

# Выведем размерности полученных таблиц:
print(df_discount.shape)
print(df_bogo.shape)
# Out:
# (42613, 14)
# (42693, 14)

# %% [markdown]
# Посмотрим на результаты:

# %%
df_discount.head()
# Out:
#    recency  history  used_discount  used_bogo  is_referral  treatment  \
# 0        6   329.08              1          1            1          0
# 1        9   675.83              1          0            1          1
# 2        9   675.07              1          1            1          1
# 3        2   101.64              0          1            0          1
# 4        4   241.42              0          1            1          0
#
#    target_class  conversion  zip_code_Rural  zip_code_Surburban  \
# 0             0           0            True               False
# 1             2           0            True               False
# 2             2           0            True               False
# 3             3           1           False               False
# 4             0           0            True               False
#
#    zip_code_Urban  channel_Multichannel  channel_Phone  channel_Web
# 0           False                 False          False         True
# 1           False                 False          False         True
# 2           False                 False           True        False
# 3            True                 False          False         True
# 4           False                  True          False        False

# %%
df_bogo.head()
# Out:
#    recency  history  used_discount  used_bogo  is_referral  treatment  \
# 0       10   142.44              1          0            0          1
# 1        6   329.08              1          1            1          0
# 2        7   180.65              0          1            1          1
# 3        2    45.34              1          0            0          1
# 4        6   134.83              0          1            0          1
#
#    target_class  conversion  zip_code_Rural  zip_code_Surburban  \
# 0             2           0           False                True
# 1             0           0            True               False
# 2             2           0           False                True
# 3             2           0           False               False
# 4             3           1           False                True
#
#    zip_code_Urban  channel_Multichannel  channel_Phone  channel_Web
# 0           False                 False           True        False
# 1           False                 False          False         True
# 2           False                 False          False         True
# 3            True                 False          False         True
# 4           False                 False           True        False

# %%
# Определим колонки с факторами, тритментом и таргетом
feature_cols = ['recency', 'history', 'used_discount', 'used_bogo', 'is_referral',
                'zip_code_Rural', 'zip_code_Surburban', 'zip_code_Urban',
                'channel_Multichannel', 'channel_Phone', 'channel_Web']

target_col = 'conversion'
treatment_col = 'treatment'

# %% [markdown]
# ## Работаем с данными о скидках

# %% [markdown]
# ### Обучающая и тестовая выборка

# %% [markdown]
# Мы будем работать с данными о скидках. Оценить uplift-эффект на данных о результатх промоакций вам предстоит самостоятельно.

# %% [markdown]
# Разделим данные на тренировочную и тестовую выборки.

# %%
df_discount_train, df_discount_test = train_test_split(
    df_discount, 
    stratify=df_discount[[treatment_col, target_col]], 
    random_state=13, 
    test_size=0.3
)
print(df_discount_train.shape)
print(df_discount_test.shape)

df_discount_train.head()
# Out:
# (29829, 14)
# (12784, 14)
#        recency  history  used_discount  used_bogo  is_referral  treatment  \
# 28236        1   616.27              1          0            1          1
# 37748       11   158.76              0          1            1          0
# 41505        3   269.60              1          0            1          1
# 1595         3   458.76              1          0            0          1
# 31544        7   209.56              0          1            0          1
#
#        target_class  conversion  zip_code_Rural  zip_code_Surburban  \
# 28236             2           0           False               False
# 37748             0           0           False               False
# 41505             2           0           False               False
# 1595              2           0            True               False
# 31544             2           0           False               False
#
#        zip_code_Urban  channel_Multichannel  channel_Phone  channel_Web
# 28236            True                  True          False        False
# 37748            True                 False          False         True
# 41505            True                 False           True        False
# 1595            False                  True          False        False
# 31544            True                  True          False        False

# %% [markdown]
# ### Quni-curve и qini-score

# %% [markdown]
# Создадим функцию для построения qini-curve и расчета qini-score.

# %%
# Возьмем функцию для оценки qini-curve с прошлого занятия
def qini_df(df, title='train', figsize=(5, 3)):
    # Отранжируем выборку по значению uplift в убывающем порядке
    ranked = df.sort_values("uplift_score", ascending=False)
    
    N_c = sum(ranked['target_class'] <= 1)
    N_t = sum(ranked['target_class'] >= 2)
    
    # Посчитаем в отсортированном датафрейме основные показатели, которые используются при расчете qini
    ranked['n_c1'] = 0
    ranked['n_t1'] = 0
    ranked.loc[ranked.target_class == 1,'n_c1'] = 1
    ranked.loc[ranked.target_class == 3,'n_t1'] = 1
    ranked['n_c1/nc'] = ranked.n_c1.cumsum() / N_c
    ranked['n_t1/nt'] = ranked.n_t1.cumsum() / N_t
    
    # Посчитаем qini curve и рандомную прямую под ней
    ranked['uplift'] = round(ranked['n_t1/nt'] - ranked['n_c1/nc'],5)
    # Добавим случайную кривую
    ranked['random_uplift'] = round(ranked["uplift_score"].rank(pct=True, ascending=False) * ranked['uplift'].iloc[-1],5)
    
    ranked["n"] = ranked["uplift_score"].rank(pct=True, ascending=False)
    
    # Немного кода для визуализации
    fig = plt.figure(figsize=figsize)
    plt.plot(ranked['n'], ranked['uplift'], color='r', label='Model')
    plt.plot(ranked['n'], ranked['random_uplift'], color='b', label='RandomModel')
    plt.legend()
    plt.title('Qini-curve for {} samples'.format(title))
    plt.show()
    quni_score = (ranked['uplift'] - ranked['random_uplift']).sum()
    print('Qini score: {:.3f}'.format(quni_score))

# %% [markdown]
# ## Uplift-моделирование с помощью scikit-uplift

# %% [markdown]
# В этом разделе мы с вами применим реализацию S-learner и T-learner из библиотеки [scikit-uplift](https://github.com/maks-sh/scikit-uplift), а также реализуем эти модели вручную и сравним результаты.

# %% [markdown]
# **Примечание:**
#
# Результаты uplift-моделирования могут незначительно отличаться в зависимости от версии библиотек. Будьте внимательны.

# %% [markdown]
# ### S-learner (scikit-uplift)

# %% [markdown]
# Давайте по нашим данным построим S-learner из библиотеки scikit-uplift ([документация](https://www.uplift-modeling.com/en/latest/index.html)). В качестве классификатора возьмем реализацию градиентного бустинга от Яндекса (CatBoost).
#
# Обучим S-learner из библиотеки sklift ([SoloModel](https://www.uplift-modeling.com/en/latest/api/models/SoloModel.html)), сделаем предсказание uplift на тренировочной и тестовой выборках и оценим качество uplift-моделирования с помощью qini-curve и qini-score.

# %%
# Создаем базовый S-learner
s_learner = SoloModel(
    estimator=CatBoostClassifier(random_seed=13, verbose=0)
)

# Для обучения нам нужны датафрем с факторами, таргет и колонка с фактом воздействия
s_learner = s_learner.fit(
    X=df_discount_train[feature_cols],
    y=df_discount_train[target_col],
    treatment=df_discount_train[treatment_col]
)

# Сделаем предсказание uplift-эффекта на обучающей выборке
uplift_vals = s_learner.predict(df_discount_train[feature_cols])
df_discount_train['uplift_score'] = uplift_vals

# Сделаем предсказание uplift-эффекта на тестовой выборке
uplift_vals = s_learner.predict(df_discount_test[feature_cols])
df_discount_test['uplift_score'] = uplift_vals

# Мы получили какие-то значения рамках решения задачи классификации, давайте посмотрим на qini score
qini_df(df_discount_train, title='train')
qini_df(df_discount_test, title='test')
# Out:
# Qini score: 1008.495
# Qini score: 9.296

# %% [markdown]
# Из результатов моделирования мы видим, что модель CatBoost оказалась сильно переобученной.
#
# Давайте попробуем воспользоваться более простой моделью. В качестве классификатора возьмем логистическую регрессию.

# %%
# Создаем базовый S-learner
s_learner = SoloModel(estimator=LogisticRegression(max_iter=10000))

# Для обучения нам нужны датафрем с факторами, таргет и колонка с фактом воздействия
s_learner = s_learner.fit(
    X=df_discount_train[feature_cols],
    y=df_discount_train[target_col],
    treatment=df_discount_train[treatment_col]
)

# Сделаем предсказание uplift-эффекта на обучающей выборке
uplift_vals = s_learner.predict(df_discount_train[feature_cols])
df_discount_train['uplift_score'] = uplift_vals

# Сделаем предсказание uplift-эффекта на тестовой выборке
uplift_vals = s_learner.predict(df_discount_test[feature_cols])
df_discount_test['uplift_score'] = uplift_vals

# Мы получили какие-то значения рамках решения задачи классификации, давайте посмотрим на qini score
qini_df(df_discount_train)
qini_df(df_discount_test)
# Out:
# Qini score: 116.657
# Qini score: 50.465

# %% [markdown]
# Видим, что результат улучшился, разбор модели (переобучение) удалось уменьшить и тем самым повысить качество на тестовой выборке.

# %% [markdown]
# Ну что же,  базовый S-learner довольно неплохо справляется в данном случае. Чуть позже мы попробуем на этом датасете более продвинутые алгоритмы и сравним подходы.
#
# А сейчас давайте, в качестве упраждения создадим S-learner собственным руками и сравним результат с результатом библиотечной версии.

# %%
# Реализуем функцию, рассчитывающих uplift
def compute_s_uplift(ctb_clf, X):
    # Выставляем целевое влияние в 1 (есть воздействие) для всех наблюдений
    X[treatment_col] = 1
    # Предсказываем вероятность покупки при воздействии
    predict_treatment = ctb_clf.predict_proba(X[feature_cols + [treatment_col]])[:, 1]
    # Выставляем целевое влияние в 0 (нет воздействия) для всех наблюдений
    X[treatment_col] = 0
    # Предсказываем вероятность покупки при отсутвии воздействия
    predict_control = ctb_clf.predict_proba(X[feature_cols + [treatment_col]])[:, 1]
    # Рассчитываем uplift-эффекты по формуле
    uplift = predict_treatment - predict_control
    # Возвращаем результат
    return uplift

# Создадим классификатор
ctb_clf = LogisticRegression(max_iter=10000)

# Обучим его на тренировочных данных (важно: в данных должен присутствовать признак целевого влияния)
ctb_clf.fit(df_discount_train[feature_cols + [treatment_col]], df_discount_train[target_col])

# Оценим uplift-эффекты на тестовых данных
df_discount_train['uplift_score'] = compute_s_uplift(ctb_clf, df_discount_train.copy())
qini_df(df_discount_train)

# Оценим uplift-эффекты на тестовых данных
df_discount_test['uplift_score'] = compute_s_uplift(ctb_clf, df_discount_test.copy())
qini_df(df_discount_test)
# Out:
# Qini score: 116.657
# Qini score: 50.465

# %% [markdown]
# Мы создали собственный S-learner и его результаты совпали с библиотечным, а значим мы сделали все правильно!

# %% [markdown]
# ### T-learner (scikit-uplift)

# %% [markdown]
# Теперь давайте применим T-learner из библиотеки scikit-uplift. Реализация данного подхода содержится в классе [TwoModel](https://www.uplift-modeling.com/en/latest/api/models/TwoModels.html).
#
# В качестве классификаторов в T-learner воспользуемся CatBoost.

# %%
# Создадим базовый T-learner
t_learner = TwoModels(
    estimator_trmnt=CatBoostClassifier(random_seed=13, verbose=0),
    estimator_ctrl=CatBoostClassifier(random_seed=13, verbose=0)
)

# Для обучения нам нужны датафрем с факторами, таргет и колонка с фактом воздействия
t_learner = t_learner.fit(
    X=df_discount_train[feature_cols],
    y=df_discount_train[target_col],
    treatment=df_discount_train[treatment_col]
)

# Сделаем предсказание uplift-эффекта
uplift_vals = t_learner.predict(df_discount_train[feature_cols])
df_discount_train['uplift_score'] = uplift_vals

# Сделаем предсказание uplift-эффекта
uplift_vals = t_learner.predict(df_discount_test[feature_cols])
df_discount_test['uplift_score'] = uplift_vals

# Мы получили какие-то значения рамках решения задачи классификации, давайте посмотрим на qini score
qini_df(df_discount_train, title='train')
qini_df(df_discount_test, title='test')
# Out:
# Qini score: 1614.454
# Qini score: 2.632

# %% [markdown]
# Видим, что результаты T-learner несколько хуже, чем результаты S-learner.
#
# Не стоит расстраиваться и удивляться, результаты значительно зависят от данных и используемых классификаторов.

# %% [markdown]
# Давайте, попробуем обучить T-learner своими руками

# %%
# Создадим классификаторы
ctb_clf_tr = CatBoostClassifier(random_seed=13, verbose=0)
ctb_clf_ctrl = CatBoostClassifier(random_seed=13, verbose=0)

#Обучим их на исходных данных
unique_treatment = df_discount_train[treatment_col].unique()

ctb_clf_tr.fit(
    X=df_discount_train[df_discount_train[treatment_col] == 1][feature_cols], 
    y=df_discount_train[df_discount_train[treatment_col] == 1][target_col]
)
ctb_clf_ctrl.fit(
    X=df_discount_train[df_discount_train[treatment_col] == 0][feature_cols], 
    y=df_discount_train[df_discount_train[treatment_col] == 0][target_col]
)

# Опишем метод, рассчитывающих аплифт
def compute_t_uplift(ctb_clf_tr, ctb_clf_ctrl, X):
    X[treatment_col] = 1
    predict_treatment = ctb_clf_tr.predict_proba(X[feature_cols + [treatment_col]])[:, 1]
    
    X[treatment_col] = 0
    predict_control = ctb_clf_ctrl.predict_proba(X[feature_cols + [treatment_col]])[:, 1]
    
    uplift = predict_treatment - predict_control
    return uplift

# Оценим uplift эффекты
df_discount_train['uplift_score'] = compute_t_uplift(ctb_clf_tr, ctb_clf_ctrl, df_discount_train.copy())
df_discount_test['uplift_score'] = compute_t_uplift(ctb_clf_tr, ctb_clf_ctrl, df_discount_test.copy())

# Мы получили какие-то значения рамках решения задачи классификации, давайте посмотрим на qini score
qini_df(df_discount_train, title='train')
qini_df(df_discount_test, title='test')
# Out:
# Qini score: 1614.454
# Qini score: 2.632

# %% [markdown]
# Мы построили собственный T-learner и его результаты совпали с библиотечной реализацией.

# %% [markdown]
# Итак, что мы видим? На текущей задаче S- и T- learner`ы работают не так хорошо, как хотелось бы.
#
# Посмотрим в дальнейшем как справятся X- и R- learner`ы.

# %% [markdown]
# ## Uplift-моделирование (CausalML)

# %% [markdown]
# Давайте посмотрим на реализацию S-learner и T-learner из библиотеки [CausalML](https://github.com/uber/causalml) от компании Uber ([документация](https://causalml.readthedocs.io/en/latest/index.html)).

# %% [markdown]
# ### S-learner (CausalML)

# %%
# Давайте по данным построим S-learner

# Создадим базовый S-learner
s_learner = BaseSClassifier(learner=CatBoostClassifier(random_seed=13, verbose=0))

# Для обучения нам нужны датафрем с факторами, колонка с фактом воздействия
s_learner.fit(X=df_discount_train[feature_cols],
              treatment=df_discount_train[treatment_col],
              y=df_discount_train[target_col])

# Сделаем предсказание uplift-эффекта на обучающей выборке
uplift_vals = s_learner.predict(np.array(df_discount_train[feature_cols].values.copy()))
df_discount_train['uplift_score'] = uplift_vals

# Сделаем предсказание uplift-эффекта на тестовой выборке
uplift_vals = s_learner.predict(np.array(df_discount_test[feature_cols].values.copy()))
df_discount_test['uplift_score'] = uplift_vals

# Мы получили какие-то значения рамках решения задачи классификации, давайте посмотрим на qini score
qini_df(df_discount_train, title='train')
qini_df(df_discount_test, title='test')
# Out:
# Qini score: 1005.367
# Qini score: 4.567

# %% [markdown]
# **Примечание:**
#
# Обратите внимание, что из-за того, что реализация S-learner в CausalML несколько отличается от классической, которая приведена в библиотеке scikit-uplift, результаты моделирования несколько отличаются. Подробнее о реализации S-learner в CausalML вы можете узнать из документации.

# %% [markdown]
# ### T-learner (CausalML)

# %%
# Давайте по данным построим T-learner

# Создадим базовый T-learner
t_learner = BaseTClassifier(learner=CatBoostClassifier(random_seed=13, verbose=0))

# Для обучения нам нужны датафрем с факторами, колонка с фактом воздействия
t_learner.fit(X=df_discount_train[feature_cols],
              treatment=df_discount_train[treatment_col],
              y=df_discount_train[target_col])

# Сделаем предсказание uplift-эффекта на обучающей выборке
uplift_vals = t_learner.predict(np.array(df_discount_train[feature_cols].values.copy()))
df_discount_train['uplift_score'] = uplift_vals

# Сделаем предсказание uplift-эффекта на тестовой выборке
uplift_vals = t_learner.predict(np.array(df_discount_test[feature_cols].values.copy()))
df_discount_test['uplift_score'] = uplift_vals

# Мы получили какие-то значения рамках решения задачи классификации, давайте посмотрим на qini score
qini_df(df_discount_train, title='train')
qini_df(df_discount_test, title='test')
# Out:
# Qini score: 1614.454
# Qini score: 2.632

# %% [markdown]
# ## Работаем с данными о промоакциях

# %% [markdown]
# Теперь вам предстоит самостоятельно провести uplift-моделирование на данных о промоакциях.

# %% [markdown]
# ### Обучающая и тестовая выборки

# %% [markdown]
# Разделим данные на тренировочную и тестовую выборки.

# %%
df_bogo_train, df_bogo_test = train_test_split(
    df_bogo, 
    stratify=df_bogo[[treatment_col, target_col]], 
    random_state=13, 
    test_size=0.3
)
print(df_bogo_train.shape)
print(df_bogo_test.shape)

df_bogo_train.head()
# Out:
# (29885, 14)
# (12808, 14)
#        recency  history  used_discount  used_bogo  is_referral  treatment  \
# 20518        2   167.94              1          0            1          1
# 34388       11   129.29              1          0            0          1
# 40663        9   129.61              0          1            1          0
# 30626        2   333.87              1          0            1          1
# 16372        4   103.79              1          0            1          1
#
#        target_class  conversion  zip_code_Rural  zip_code_Surburban  \
# 20518             2           0           False                True
# 34388             2           0           False                True
# 40663             0           0            True               False
# 30626             2           0           False                True
# 16372             2           0           False               False
#
#        zip_code_Urban  channel_Multichannel  channel_Phone  channel_Web
# 20518           False                 False          False         True
# 34388           False                 False           True        False
# 40663           False                 False          False         True
# 30626           False                  True          False        False
# 16372            True                 False          False         True

# %% [markdown]
# ### S-learner (CausalML)

# %% [markdown]
# **Задание №1**

# %% [markdown]
# Давайте проведем uplift-моделирование на датасете с промо-акциями (df_bogo) с помощью S-learner из библиотеки `CausalML` (BaseSClassifier) качестве классификатора (learner) используйте алгоритм CatBoostClassifier с параметрами по умолчанию. Параметр random_state установите в значение 13.
#
# Рассчитайте qini-score на тестовой выборке для полученного S-learner. Запишите полученный результат с точностью до 3-его знака после запятой.

# %%
# S-learner (CausalML) для df_bogo
s_learner = BaseSClassifier(learner=CatBoostClassifier(random_state=13))

s_learner.fit(
    X=df_bogo_train[feature_cols],
    treatment=df_bogo_train[treatment_col],
    y=df_bogo_train[target_col]
)

# Uplift-предсказания на тестовой выборке
uplift_vals = s_learner.predict(np.array(df_bogo_test[feature_cols].values.copy()))
df_bogo_test['uplift_score'] = np.ravel(uplift_vals)

# Расчет qini-score на тесте
ranked = df_bogo_test.sort_values('uplift_score', ascending=False).copy()
N_c = (ranked['target_class'] <= 1).sum()
N_t = (ranked['target_class'] >= 2).sum()

ranked['n_c1'] = (ranked['target_class'] == 1).astype(int)
ranked['n_t1'] = (ranked['target_class'] == 3).astype(int)
ranked['n_c1/nc'] = ranked['n_c1'].cumsum() / N_c
ranked['n_t1/nt'] = ranked['n_t1'].cumsum() / N_t
ranked['uplift'] = np.round(ranked['n_t1/nt'] - ranked['n_c1/nc'], 5)
ranked['random_uplift'] = np.round(
    ranked['uplift_score'].rank(pct=True, ascending=False) * ranked['uplift'].iloc[-1], 5
)

qini_score_test = (ranked['uplift'] - ranked['random_uplift']).sum()
print(round(qini_score_test, 3))
# Out:
# Learning rate set to 0.043949
# 0:	learn: 0.6617916	total: 18.2ms	remaining: 18.2s
# 1:	learn: 0.6327347	total: 32.7ms	remaining: 16.3s
# 2:	learn: 0.6077377	total: 43.4ms	remaining: 14.4s
# 3:	learn: 0.5842177	total: 57.6ms	remaining: 14.3s
# 4:	learn: 0.5631196	total: 73.2ms	remaining: 14.6s
# 5:	learn: 0.5443802	total: 86.3ms	remaining: 14.3s
# 6:	learn: 0.5281227	total: 99.3ms	remaining: 14.1s
# 7:	learn: 0.5127072	total: 115ms	remaining: 14.2s
# 8:	learn: 0.4990954	total: 126ms	remaining: 13.9s
# 9:	learn: 0.4872904	total: 138ms	remaining: 13.6s
# 10:	learn: 0.4765228	total: 152ms	remaining: 13.6s
# 11:	learn: 0.4665912	total: 165ms	remaining: 13.6s
# 12:	learn: 0.4574523	total: 177ms	remaining: 13.5s
# 13:	learn: 0.4493759	total: 188ms	remaining: 13.3s
# 14:	learn: 0.4415093	total: 204ms	remaining: 13.4s
# 15:	learn: 0.4346240	total: 219ms	remaining: 13.5s
# 16:	learn: 0.4286395	total: 235ms	remaining: 13.6s
# 17:	learn: 0.4236626	total: 246ms	remaining: 13.4s
# 18:	learn: 0.4188802	total: 260ms	remaining: 13.4s
# 19:	learn: 0.4148500	total: 270ms	remaining: 13.2s
# 20:	learn: 0.4108710	total: 280ms	remaining: 13.1s
# 21:	learn: 0.4071260	total: 294ms	remaining: 13.1s
# 22:	learn: 0.4035754	total: 316ms	remaining: 13.4s
# 23:	learn: 0.4006880	total: 331ms	remaining: 13.5s
# 24:	learn: 0.3978414	total: 346ms	remaining: 13.5s
# 25:	learn: 0.3954378	total: 359ms	remaining: 13.4s
# 26:	learn: 0.3932635	total: 373ms	remaining: 13.4s
# 27:	learn: 0.3912525	total: 386ms	remaining: 13.4s
# 28:	learn: 0.3895822	total: 396ms	remaining: 13.3s
# 29:	learn: 0.3878132	total: 409ms	remaining: 13.2s
# 30:	learn: 0.3863485	total: 422ms	remaining: 13.2s
# 31:	learn: 0.3849712	total: 434ms	remaining: 13.1s
# 32:	learn: 0.3834108	total: 449ms	remaining: 13.1s
# 33:	learn: 0.3821686	total: 465ms	remaining: 13.2s
# 34:	learn: 0.3809882	total: 481ms	remaining: 13.3s
# 35:	learn: 0.3798471	total: 493ms	remaining: 13.2s
# 36:	learn: 0.3788527	total: 506ms	remaining: 13.2s
# 37:	learn: 0.3778352	total: 519ms	remaining: 13.1s
# 38:	learn: 0.3770249	total: 531ms	remaining: 13.1s
# 39:	learn: 0.3763250	total: 541ms	remaining: 13s
# 40:	learn: 0.3754633	total: 553ms	remaining: 12.9s
# 41:	learn: 0.3747939	total: 565ms	remaining: 12.9s
# 42:	learn: 0.3742207	total: 577ms	remaining: 12.8s
# 43:	learn: 0.3735372	total: 589ms	remaining: 12.8s
# 44:	learn: 0.3730986	total: 598ms	remaining: 12.7s
# 45:	learn: 0.3727197	total: 608ms	remaining: 12.6s
# 46:	learn: 0.3722916	total: 620ms	remaining: 12.6s
# 47:	learn: 0.3720231	total: 631ms	remaining: 12.5s
# 48:	learn: 0.3716693	total: 641ms	remaining: 12.4s
# 49:	learn: 0.3713600	total: 651ms	remaining: 12.4s
# 50:	learn: 0.3708729	total: 662ms	remaining: 12.3s
# 51:	learn: 0.3705772	total: 674ms	remaining: 12.3s
# 52:	learn: 0.3703141	total: 687ms	remaining: 12.3s
# 53:	learn: 0.3700300	total: 699ms	remaining: 12.3s
# 54:	learn: 0.3697149	total: 713ms	remaining: 12.2s
# 55:	learn: 0.3694319	total: 725ms	remaining: 12.2s
# 56:	learn: 0.3692236	total: 739ms	remaining: 12.2s
# 57:	learn: 0.3689980	total: 752ms	remaining: 12.2s
# 58:	learn: 0.3687894	total: 764ms	remaining: 12.2s
# 59:	learn: 0.3685152	total: 777ms	remaining: 12.2s
# 60:	learn: 0.3683033	total: 789ms	remaining: 12.1s
# 61:	learn: 0.3681892	total: 800ms	remaining: 12.1s
# 62:	learn: 0.3679583	total: 812ms	remaining: 12.1s
# 63:	learn: 0.3677652	total: 826ms	remaining: 12.1s
# 64:	learn: 0.3675943	total: 841ms	remaining: 12.1s
# 65:	learn: 0.3674119	total: 854ms	remaining: 12.1s
# 66:	learn: 0.3672914	total: 867ms	remaining: 12.1s
# 67:	learn: 0.3671552	total: 880ms	remaining: 12.1s
# 68:	learn: 0.3669185	total: 894ms	remaining: 12.1s
# 69:	learn: 0.3667792	total: 908ms	remaining: 12.1s
# 70:	learn: 0.3665737	total: 922ms	remaining: 12.1s
# 71:	learn: 0.3665395	total: 933ms	remaining: 12s
# 72:	learn: 0.3663934	total: 946ms	remaining: 12s
# 73:	learn: 0.3662791	total: 958ms	remaining: 12s
# 74:	learn: 0.3661429	total: 970ms	remaining: 12s
# 75:	learn: 0.3660341	total: 983ms	remaining: 12s
# 76:	learn: 0.3659057	total: 994ms	remaining: 11.9s
# 77:	learn: 0.3657490	total: 1.01s	remaining: 11.9s
# 78:	learn: 0.3656163	total: 1.02s	remaining: 11.9s
# 79:	learn: 0.3655327	total: 1.03s	remaining: 11.8s
# 80:	learn: 0.3654926	total: 1.04s	remaining: 11.8s
# 81:	learn: 0.3654701	total: 1.05s	remaining: 11.8s
# 82:	learn: 0.3653461	total: 1.07s	remaining: 11.8s
# 83:	learn: 0.3652494	total: 1.08s	remaining: 11.8s
# 84:	learn: 0.3651867	total: 1.1s	remaining: 11.8s
# 85:	learn: 0.3651162	total: 1.11s	remaining: 11.8s
# 86:	learn: 0.3650265	total: 1.12s	remaining: 11.8s
# 87:	learn: 0.3649811	total: 1.14s	remaining: 11.8s
# 88:	learn: 0.3649581	total: 1.15s	remaining: 11.8s
# 89:	learn: 0.3648959	total: 1.16s	remaining: 11.7s
# 90:	learn: 0.3648196	total: 1.17s	remaining: 11.7s
# 91:	learn: 0.3647691	total: 1.19s	remaining: 11.7s
# 92:	learn: 0.3646858	total: 1.2s	remaining: 11.7s
# 93:	learn: 0.3646088	total: 1.21s	remaining: 11.7s
# 94:	learn: 0.3645407	total: 1.22s	remaining: 11.6s
# 95:	learn: 0.3644861	total: 1.23s	remaining: 11.6s
# 96:	learn: 0.3644332	total: 1.25s	remaining: 11.6s
# 97:	learn: 0.3643870	total: 1.26s	remaining: 11.6s
# 98:	learn: 0.3643097	total: 1.27s	remaining: 11.6s
# 99:	learn: 0.3642478	total: 1.28s	remaining: 11.5s
# 100:	learn: 0.3641767	total: 1.29s	remaining: 11.5s
# 101:	learn: 0.3641041	total: 1.3s	remaining: 11.5s
# 102:	learn: 0.3640508	total: 1.32s	remaining: 11.5s
# 103:	learn: 0.3639705	total: 1.33s	remaining: 11.4s
# 104:	learn: 0.3639347	total: 1.34s	remaining: 11.4s
# 105:	learn: 0.3638690	total: 1.35s	remaining: 11.4s
# 106:	learn: 0.3637842	total: 1.36s	remaining: 11.4s
# 107:	learn: 0.3637270	total: 1.37s	remaining: 11.3s
# 108:	learn: 0.3636932	total: 1.38s	remaining: 11.3s
# 109:	learn: 0.3636518	total: 1.4s	remaining: 11.3s
# 110:	learn: 0.3636182	total: 1.41s	remaining: 11.3s
# 111:	learn: 0.3636108	total: 1.42s	remaining: 11.2s
# 112:	learn: 0.3635628	total: 1.43s	remaining: 11.2s
# 113:	learn: 0.3635558	total: 1.44s	remaining: 11.2s
# 114:	learn: 0.3635082	total: 1.45s	remaining: 11.2s
# 115:	learn: 0.3634321	total: 1.47s	remaining: 11.2s
# 116:	learn: 0.3633909	total: 1.48s	remaining: 11.2s
# 117:	learn: 0.3633326	total: 1.49s	remaining: 11.1s
# 118:	learn: 0.3632875	total: 1.5s	remaining: 11.1s
# 119:	learn: 0.3632486	total: 1.52s	remaining: 11.1s
# 120:	learn: 0.3632076	total: 1.54s	remaining: 11.2s
# 121:	learn: 0.3631099	total: 1.55s	remaining: 11.2s
# 122:	learn: 0.3630409	total: 1.56s	remaining: 11.2s
# 123:	learn: 0.3629956	total: 1.58s	remaining: 11.2s
# 124:	learn: 0.3629306	total: 1.59s	remaining: 11.1s
# 125:	learn: 0.3628857	total: 1.6s	remaining: 11.1s
# 126:	learn: 0.3628692	total: 1.61s	remaining: 11.1s
# 127:	learn: 0.3628609	total: 1.63s	remaining: 11.1s
# 128:	learn: 0.3628309	total: 1.64s	remaining: 11.1s
# 129:	learn: 0.3628000	total: 1.65s	remaining: 11.1s
# 130:	learn: 0.3627398	total: 1.66s	remaining: 11s
# 131:	learn: 0.3626598	total: 1.68s	remaining: 11s
# 132:	learn: 0.3626208	total: 1.69s	remaining: 11s
# 133:	learn: 0.3626195	total: 1.7s	remaining: 11s
# 134:	learn: 0.3625602	total: 1.71s	remaining: 11s
# 135:	learn: 0.3624878	total: 1.72s	remaining: 10.9s
# 136:	learn: 0.3624093	total: 1.73s	remaining: 10.9s
# 137:	learn: 0.3623466	total: 1.75s	remaining: 10.9s
# 138:	learn: 0.3622783	total: 1.76s	remaining: 10.9s
# 139:	learn: 0.3622756	total: 1.76s	remaining: 10.8s
# 140:	learn: 0.3622590	total: 1.78s	remaining: 10.8s
# 141:	learn: 0.3621936	total: 1.79s	remaining: 10.8s
# 142:	learn: 0.3621448	total: 1.8s	remaining: 10.8s
# 143:	learn: 0.3620995	total: 1.81s	remaining: 10.8s
# 144:	learn: 0.3620539	total: 1.82s	remaining: 10.7s
# 145:	learn: 0.3619927	total: 1.83s	remaining: 10.7s
# 146:	learn: 0.3619228	total: 1.84s	remaining: 10.7s
# 147:	learn: 0.3618770	total: 1.86s	remaining: 10.7s
# 148:	learn: 0.3618309	total: 1.87s	remaining: 10.7s
# 149:	learn: 0.3617877	total: 1.88s	remaining: 10.7s
# 150:	learn: 0.3617552	total: 1.89s	remaining: 10.6s
# 151:	learn: 0.3617552	total: 1.9s	remaining: 10.6s
# 152:	learn: 0.3617222	total: 1.91s	remaining: 10.6s
# 153:	learn: 0.3616869	total: 1.93s	remaining: 10.6s
# 154:	learn: 0.3616547	total: 1.94s	remaining: 10.6s
# 155:	learn: 0.3616093	total: 1.95s	remaining: 10.5s
# 156:	learn: 0.3615694	total: 1.96s	remaining: 10.5s
# 157:	learn: 0.3615416	total: 1.97s	remaining: 10.5s
# 158:	learn: 0.3615037	total: 1.98s	remaining: 10.5s
# 159:	learn: 0.3614810	total: 1.99s	remaining: 10.5s
# 160:	learn: 0.3614302	total: 2s	remaining: 10.5s
# 161:	learn: 0.3613943	total: 2.02s	remaining: 10.4s
# 162:	learn: 0.3613454	total: 2.03s	remaining: 10.4s
# 163:	learn: 0.3613252	total: 2.04s	remaining: 10.4s
# 164:	learn: 0.3612586	total: 2.05s	remaining: 10.4s
# 165:	learn: 0.3612107	total: 2.06s	remaining: 10.4s
# 166:	learn: 0.3611636	total: 2.08s	remaining: 10.4s
# 167:	learn: 0.3611312	total: 2.09s	remaining: 10.3s
# 168:	learn: 0.3611228	total: 2.1s	remaining: 10.3s
# 169:	learn: 0.3610871	total: 2.11s	remaining: 10.3s
# 170:	learn: 0.3610539	total: 2.12s	remaining: 10.3s
# 171:	learn: 0.3610026	total: 2.13s	remaining: 10.3s
# 172:	learn: 0.3609477	total: 2.14s	remaining: 10.2s
# 173:	learn: 0.3609175	total: 2.15s	remaining: 10.2s
# 174:	learn: 0.3609175	total: 2.16s	remaining: 10.2s
# 175:	learn: 0.3608632	total: 2.17s	remaining: 10.2s
# 176:	learn: 0.3608558	total: 2.18s	remaining: 10.2s
# 177:	learn: 0.3607935	total: 2.19s	remaining: 10.1s
# 178:	learn: 0.3607747	total: 2.21s	remaining: 10.1s
# 179:	learn: 0.3607417	total: 2.22s	remaining: 10.1s
# 180:	learn: 0.3607056	total: 2.23s	remaining: 10.1s
# 181:	learn: 0.3606448	total: 2.25s	remaining: 10.1s
# 182:	learn: 0.3606180	total: 2.26s	remaining: 10.1s
# 183:	learn: 0.3605683	total: 2.27s	remaining: 10.1s
# 184:	learn: 0.3605207	total: 2.29s	remaining: 10.1s
# 185:	learn: 0.3604916	total: 2.3s	remaining: 10.1s
# 186:	learn: 0.3604693	total: 2.32s	remaining: 10.1s
# 187:	learn: 0.3604311	total: 2.33s	remaining: 10.1s
# 188:	learn: 0.3603958	total: 2.34s	remaining: 10.1s
# 189:	learn: 0.3603793	total: 2.36s	remaining: 10s
# 190:	learn: 0.3603424	total: 2.37s	remaining: 10s
# 191:	learn: 0.3603073	total: 2.38s	remaining: 10s
# 192:	learn: 0.3602692	total: 2.4s	remaining: 10s
# 193:	learn: 0.3602084	total: 2.41s	remaining: 10s
# 194:	learn: 0.3601614	total: 2.42s	remaining: 10s
# 195:	learn: 0.3601138	total: 2.44s	remaining: 9.99s
# 196:	learn: 0.3600792	total: 2.45s	remaining: 9.98s
# 197:	learn: 0.3600445	total: 2.46s	remaining: 9.97s
# 198:	learn: 0.3600183	total: 2.48s	remaining: 9.96s
# 199:	learn: 0.3599816	total: 2.49s	remaining: 9.95s
# 200:	learn: 0.3599770	total: 2.5s	remaining: 9.93s
# 201:	learn: 0.3599178	total: 2.51s	remaining: 9.92s
# 202:	learn: 0.3599085	total: 2.52s	remaining: 9.9s
# 203:	learn: 0.3598629	total: 2.54s	remaining: 9.89s
# 204:	learn: 0.3598325	total: 2.55s	remaining: 9.88s
# 205:	learn: 0.3597963	total: 2.56s	remaining: 9.87s
# 206:	learn: 0.3597823	total: 2.57s	remaining: 9.86s
# 207:	learn: 0.3597527	total: 2.59s	remaining: 9.85s
# 208:	learn: 0.3596762	total: 2.6s	remaining: 9.84s
# 209:	learn: 0.3596320	total: 2.61s	remaining: 9.83s
# 210:	learn: 0.3595953	total: 2.62s	remaining: 9.81s
# 211:	learn: 0.3595703	total: 2.64s	remaining: 9.8s
# 212:	learn: 0.3595510	total: 2.65s	remaining: 9.79s
# 213:	learn: 0.3595503	total: 2.66s	remaining: 9.77s
# 214:	learn: 0.3594962	total: 2.67s	remaining: 9.76s
# 215:	learn: 0.3594688	total: 2.69s	remaining: 9.75s
# 216:	learn: 0.3594306	total: 2.7s	remaining: 9.73s
# 217:	learn: 0.3593979	total: 2.71s	remaining: 9.72s
# 218:	learn: 0.3593273	total: 2.72s	remaining: 9.72s
# 219:	learn: 0.3592930	total: 2.74s	remaining: 9.7s
# 220:	learn: 0.3592343	total: 2.75s	remaining: 9.69s
# 221:	learn: 0.3592343	total: 2.76s	remaining: 9.67s
# 222:	learn: 0.3591980	total: 2.77s	remaining: 9.66s
# 223:	learn: 0.3591743	total: 2.78s	remaining: 9.64s
# 224:	learn: 0.3591448	total: 2.79s	remaining: 9.63s
# 225:	learn: 0.3591125	total: 2.81s	remaining: 9.62s
# 226:	learn: 0.3590836	total: 2.82s	remaining: 9.61s
# 227:	learn: 0.3590169	total: 2.83s	remaining: 9.6s
# 228:	learn: 0.3589427	total: 2.85s	remaining: 9.59s
# 229:	learn: 0.3589045	total: 2.86s	remaining: 9.59s
# 230:	learn: 0.3588519	total: 2.88s	remaining: 9.58s
# 231:	learn: 0.3588126	total: 2.89s	remaining: 9.58s
# 232:	learn: 0.3587534	total: 2.91s	remaining: 9.58s
# 233:	learn: 0.3587036	total: 2.92s	remaining: 9.57s
# 234:	learn: 0.3586480	total: 2.94s	remaining: 9.56s
# 235:	learn: 0.3586064	total: 2.95s	remaining: 9.55s
# 236:	learn: 0.3586064	total: 2.96s	remaining: 9.53s
# 237:	learn: 0.3585500	total: 2.97s	remaining: 9.52s
# 238:	learn: 0.3585079	total: 2.98s	remaining: 9.51s
# 239:	learn: 0.3584624	total: 3s	remaining: 9.5s
# 240:	learn: 0.3584103	total: 3.01s	remaining: 9.48s
# 241:	learn: 0.3583783	total: 3.02s	remaining: 9.47s
# 242:	learn: 0.3583380	total: 3.04s	remaining: 9.46s
# 243:	learn: 0.3583068	total: 3.05s	remaining: 9.45s
# 244:	learn: 0.3582737	total: 3.06s	remaining: 9.44s
# 245:	learn: 0.3581676	total: 3.08s	remaining: 9.43s
# 246:	learn: 0.3581452	total: 3.09s	remaining: 9.42s
# 247:	learn: 0.3581131	total: 3.1s	remaining: 9.41s
# 248:	learn: 0.3580784	total: 3.12s	remaining: 9.4s
# 249:	learn: 0.3580197	total: 3.13s	remaining: 9.39s
# 250:	learn: 0.3579602	total: 3.14s	remaining: 9.38s
# 251:	learn: 0.3579172	total: 3.16s	remaining: 9.37s
# 252:	learn: 0.3578719	total: 3.17s	remaining: 9.36s
# 253:	learn: 0.3578022	total: 3.18s	remaining: 9.35s
# 254:	learn: 0.3577627	total: 3.2s	remaining: 9.34s
# 255:	learn: 0.3577161	total: 3.21s	remaining: 9.33s
# 256:	learn: 0.3576723	total: 3.22s	remaining: 9.32s
# 257:	learn: 0.3576456	total: 3.24s	remaining: 9.31s
# 258:	learn: 0.3576230	total: 3.25s	remaining: 9.3s
# 259:	learn: 0.3575716	total: 3.26s	remaining: 9.29s
# 260:	learn: 0.3575453	total: 3.28s	remaining: 9.28s
# 261:	learn: 0.3575068	total: 3.29s	remaining: 9.27s
# 262:	learn: 0.3574568	total: 3.31s	remaining: 9.26s
# 263:	learn: 0.3574079	total: 3.32s	remaining: 9.25s
# 264:	learn: 0.3573455	total: 3.33s	remaining: 9.24s
# 265:	learn: 0.3573117	total: 3.35s	remaining: 9.23s
# 266:	learn: 0.3572649	total: 3.36s	remaining: 9.22s
# 267:	learn: 0.3572191	total: 3.37s	remaining: 9.21s
# 268:	learn: 0.3571692	total: 3.38s	remaining: 9.19s
# 269:	learn: 0.3571126	total: 3.4s	remaining: 9.18s
# 270:	learn: 0.3570773	total: 3.41s	remaining: 9.17s
# 271:	learn: 0.3570164	total: 3.42s	remaining: 9.16s
# 272:	learn: 0.3569815	total: 3.44s	remaining: 9.15s
# 273:	learn: 0.3569116	total: 3.45s	remaining: 9.15s
# 274:	learn: 0.3568674	total: 3.47s	remaining: 9.14s
# 275:	learn: 0.3568286	total: 3.48s	remaining: 9.13s
# 276:	learn: 0.3567835	total: 3.49s	remaining: 9.12s
# 277:	learn: 0.3567506	total: 3.51s	remaining: 9.11s
# 278:	learn: 0.3566875	total: 3.52s	remaining: 9.1s
# 279:	learn: 0.3566487	total: 3.54s	remaining: 9.09s
# 280:	learn: 0.3566063	total: 3.55s	remaining: 9.08s
# 281:	learn: 0.3565576	total: 3.56s	remaining: 9.07s
# 282:	learn: 0.3565030	total: 3.57s	remaining: 9.06s
# 283:	learn: 0.3564567	total: 3.59s	remaining: 9.04s
# 284:	learn: 0.3564200	total: 3.6s	remaining: 9.04s
# 285:	learn: 0.3563764	total: 3.62s	remaining: 9.03s
# 286:	learn: 0.3563375	total: 3.63s	remaining: 9.02s
# 287:	learn: 0.3563098	total: 3.64s	remaining: 9.01s
# 288:	learn: 0.3562594	total: 3.66s	remaining: 9s
# 289:	learn: 0.3562121	total: 3.67s	remaining: 8.99s
# 290:	learn: 0.3561696	total: 3.68s	remaining: 8.98s
# 291:	learn: 0.3561151	total: 3.7s	remaining: 8.97s
# 292:	learn: 0.3560728	total: 3.71s	remaining: 8.95s
# 293:	learn: 0.3560120	total: 3.72s	remaining: 8.94s
# 294:	learn: 0.3559679	total: 3.74s	remaining: 8.93s
# 295:	learn: 0.3559268	total: 3.75s	remaining: 8.92s
# 296:	learn: 0.3558805	total: 3.76s	remaining: 8.91s
# 297:	learn: 0.3558437	total: 3.78s	remaining: 8.9s
# 298:	learn: 0.3557883	total: 3.79s	remaining: 8.89s
# 299:	learn: 0.3557368	total: 3.8s	remaining: 8.88s
# 300:	learn: 0.3556762	total: 3.82s	remaining: 8.87s
# 301:	learn: 0.3556362	total: 3.83s	remaining: 8.86s
# 302:	learn: 0.3555893	total: 3.85s	remaining: 8.85s
# 303:	learn: 0.3555375	total: 3.86s	remaining: 8.84s
# 304:	learn: 0.3555059	total: 3.87s	remaining: 8.83s
# 305:	learn: 0.3554588	total: 3.89s	remaining: 8.82s
# 306:	learn: 0.3554259	total: 3.9s	remaining: 8.81s
# 307:	learn: 0.3553772	total: 3.91s	remaining: 8.79s
# 308:	learn: 0.3553234	total: 3.93s	remaining: 8.78s
# 309:	learn: 0.3552900	total: 3.94s	remaining: 8.77s
# 310:	learn: 0.3552503	total: 3.95s	remaining: 8.76s
# 311:	learn: 0.3552136	total: 3.97s	remaining: 8.75s
# 312:	learn: 0.3551730	total: 3.98s	remaining: 8.74s
# 313:	learn: 0.3551310	total: 4s	remaining: 8.73s
# 314:	learn: 0.3550590	total: 4.01s	remaining: 8.72s
# 315:	learn: 0.3550099	total: 4.02s	remaining: 8.71s
# 316:	learn: 0.3549779	total: 4.04s	remaining: 8.7s
# 317:	learn: 0.3549369	total: 4.05s	remaining: 8.69s
# 318:	learn: 0.3548964	total: 4.06s	remaining: 8.68s
# 319:	learn: 0.3548688	total: 4.08s	remaining: 8.67s
# 320:	learn: 0.3548335	total: 4.09s	remaining: 8.66s
# 321:	learn: 0.3547940	total: 4.11s	remaining: 8.64s
# 322:	learn: 0.3547464	total: 4.12s	remaining: 8.63s
# 323:	learn: 0.3547116	total: 4.13s	remaining: 8.62s
# 324:	learn: 0.3546667	total: 4.14s	remaining: 8.61s
# 325:	learn: 0.3546028	total: 4.16s	remaining: 8.59s
# 326:	learn: 0.3545601	total: 4.17s	remaining: 8.58s
# 327:	learn: 0.3545021	total: 4.18s	remaining: 8.57s
# 328:	learn: 0.3544716	total: 4.2s	remaining: 8.56s
# 329:	learn: 0.3544489	total: 4.21s	remaining: 8.55s
# 330:	learn: 0.3544079	total: 4.22s	remaining: 8.53s
# 331:	learn: 0.3543610	total: 4.24s	remaining: 8.52s
# 332:	learn: 0.3543262	total: 4.25s	remaining: 8.51s
# 333:	learn: 0.3542889	total: 4.26s	remaining: 8.51s
# 334:	learn: 0.3542474	total: 4.28s	remaining: 8.5s
# 335:	learn: 0.3542132	total: 4.29s	remaining: 8.49s
# 336:	learn: 0.3541849	total: 4.31s	remaining: 8.47s
# 337:	learn: 0.3541522	total: 4.32s	remaining: 8.46s
# 338:	learn: 0.3541119	total: 4.33s	remaining: 8.45s
# 339:	learn: 0.3540451	total: 4.34s	remaining: 8.43s
# 340:	learn: 0.3539967	total: 4.36s	remaining: 8.42s
# 341:	learn: 0.3539448	total: 4.37s	remaining: 8.4s
# 342:	learn: 0.3539064	total: 4.38s	remaining: 8.39s
# 343:	learn: 0.3538746	total: 4.39s	remaining: 8.37s
# 344:	learn: 0.3538308	total: 4.4s	remaining: 8.36s
# 345:	learn: 0.3537961	total: 4.42s	remaining: 8.35s
# 346:	learn: 0.3537647	total: 4.43s	remaining: 8.33s
# 347:	learn: 0.3537330	total: 4.44s	remaining: 8.32s
# 348:	learn: 0.3537106	total: 4.45s	remaining: 8.3s
# 349:	learn: 0.3536436	total: 4.46s	remaining: 8.29s
# 350:	learn: 0.3535798	total: 4.48s	remaining: 8.28s
# 351:	learn: 0.3535528	total: 4.49s	remaining: 8.26s
# 352:	learn: 0.3534952	total: 4.5s	remaining: 8.25s
# 353:	learn: 0.3534609	total: 4.51s	remaining: 8.23s
# 354:	learn: 0.3534309	total: 4.52s	remaining: 8.22s
# 355:	learn: 0.3534006	total: 4.54s	remaining: 8.21s
# 356:	learn: 0.3533554	total: 4.55s	remaining: 8.19s
# 357:	learn: 0.3532831	total: 4.56s	remaining: 8.18s
# 358:	learn: 0.3532431	total: 4.58s	remaining: 8.17s
# 359:	learn: 0.3531997	total: 4.59s	remaining: 8.16s
# 360:	learn: 0.3531583	total: 4.6s	remaining: 8.15s
# 361:	learn: 0.3531220	total: 4.62s	remaining: 8.14s
# 362:	learn: 0.3530808	total: 4.63s	remaining: 8.13s
# 363:	learn: 0.3530438	total: 4.64s	remaining: 8.11s
# 364:	learn: 0.3530017	total: 4.66s	remaining: 8.1s
# 365:	learn: 0.3529662	total: 4.67s	remaining: 8.09s
# 366:	learn: 0.3529083	total: 4.68s	remaining: 8.08s
# 367:	learn: 0.3528757	total: 4.7s	remaining: 8.07s
# 368:	learn: 0.3528243	total: 4.71s	remaining: 8.06s
# 369:	learn: 0.3527849	total: 4.73s	remaining: 8.05s
# 370:	learn: 0.3527522	total: 4.74s	remaining: 8.04s
# 371:	learn: 0.3527097	total: 4.75s	remaining: 8.02s
# 372:	learn: 0.3526611	total: 4.77s	remaining: 8.01s
# 373:	learn: 0.3526287	total: 4.78s	remaining: 8s
# 374:	learn: 0.3525979	total: 4.79s	remaining: 7.99s
# 375:	learn: 0.3525607	total: 4.8s	remaining: 7.97s
# 376:	learn: 0.3525259	total: 4.82s	remaining: 7.96s
# 377:	learn: 0.3524919	total: 4.83s	remaining: 7.95s
# 378:	learn: 0.3524431	total: 4.84s	remaining: 7.94s
# 379:	learn: 0.3524213	total: 4.86s	remaining: 7.92s
# 380:	learn: 0.3523877	total: 4.87s	remaining: 7.91s
# 381:	learn: 0.3523228	total: 4.88s	remaining: 7.9s
# 382:	learn: 0.3522918	total: 4.9s	remaining: 7.89s
# 383:	learn: 0.3522550	total: 4.91s	remaining: 7.88s
# 384:	learn: 0.3522322	total: 4.92s	remaining: 7.86s
# 385:	learn: 0.3521983	total: 4.93s	remaining: 7.85s
# 386:	learn: 0.3521543	total: 4.95s	remaining: 7.84s
# 387:	learn: 0.3521281	total: 4.96s	remaining: 7.83s
# 388:	learn: 0.3520790	total: 4.97s	remaining: 7.81s
# 389:	learn: 0.3520364	total: 4.99s	remaining: 7.8s
# 390:	learn: 0.3519927	total: 5s	remaining: 7.79s
# 391:	learn: 0.3519474	total: 5.01s	remaining: 7.78s
# 392:	learn: 0.3519249	total: 5.03s	remaining: 7.76s
# 393:	learn: 0.3518796	total: 5.04s	remaining: 7.75s
# 394:	learn: 0.3518206	total: 5.05s	remaining: 7.74s
# 395:	learn: 0.3517928	total: 5.06s	remaining: 7.72s
# 396:	learn: 0.3517432	total: 5.08s	remaining: 7.71s
# 397:	learn: 0.3517013	total: 5.09s	remaining: 7.7s
# 398:	learn: 0.3516652	total: 5.1s	remaining: 7.69s
# 399:	learn: 0.3516266	total: 5.12s	remaining: 7.68s
# 400:	learn: 0.3516009	total: 5.13s	remaining: 7.66s
# 401:	learn: 0.3515465	total: 5.14s	remaining: 7.65s
# 402:	learn: 0.3515141	total: 5.16s	remaining: 7.64s
# 403:	learn: 0.3514723	total: 5.17s	remaining: 7.63s
# 404:	learn: 0.3514364	total: 5.18s	remaining: 7.61s
# 405:	learn: 0.3513873	total: 5.2s	remaining: 7.6s
# 406:	learn: 0.3513399	total: 5.21s	remaining: 7.59s
# 407:	learn: 0.3513056	total: 5.22s	remaining: 7.58s
# 408:	learn: 0.3512654	total: 5.23s	remaining: 7.56s
# 409:	learn: 0.3512318	total: 5.25s	remaining: 7.55s
# 410:	learn: 0.3511993	total: 5.26s	remaining: 7.54s
# 411:	learn: 0.3511468	total: 5.27s	remaining: 7.53s
# 412:	learn: 0.3511091	total: 5.29s	remaining: 7.51s
# 413:	learn: 0.3510697	total: 5.3s	remaining: 7.5s
# 414:	learn: 0.3510416	total: 5.31s	remaining: 7.49s
# 415:	learn: 0.3510070	total: 5.33s	remaining: 7.47s
# 416:	learn: 0.3509687	total: 5.34s	remaining: 7.46s
# 417:	learn: 0.3509417	total: 5.35s	remaining: 7.45s
# 418:	learn: 0.3509159	total: 5.36s	remaining: 7.44s
# 419:	learn: 0.3508676	total: 5.38s	remaining: 7.42s
# 420:	learn: 0.3508439	total: 5.39s	remaining: 7.41s
# 421:	learn: 0.3508111	total: 5.4s	remaining: 7.4s
# 422:	learn: 0.3507822	total: 5.42s	remaining: 7.39s
# 423:	learn: 0.3507528	total: 5.43s	remaining: 7.37s
# 424:	learn: 0.3507192	total: 5.44s	remaining: 7.36s
# 425:	learn: 0.3506803	total: 5.45s	remaining: 7.35s
# 426:	learn: 0.3506532	total: 5.46s	remaining: 7.33s
# 427:	learn: 0.3506188	total: 5.48s	remaining: 7.32s
# 428:	learn: 0.3505861	total: 5.49s	remaining: 7.31s
# 429:	learn: 0.3505360	total: 5.51s	remaining: 7.3s
# 430:	learn: 0.3504970	total: 5.52s	remaining: 7.29s
# 431:	learn: 0.3504561	total: 5.53s	remaining: 7.27s
# 432:	learn: 0.3504185	total: 5.54s	remaining: 7.26s
# 433:	learn: 0.3503847	total: 5.56s	remaining: 7.25s
# 434:	learn: 0.3503582	total: 5.57s	remaining: 7.24s
# 435:	learn: 0.3503131	total: 5.58s	remaining: 7.22s
# 436:	learn: 0.3502646	total: 5.6s	remaining: 7.21s
# 437:	learn: 0.3502330	total: 5.61s	remaining: 7.2s
# 438:	learn: 0.3501846	total: 5.62s	remaining: 7.19s
# 439:	learn: 0.3501443	total: 5.64s	remaining: 7.17s
# 440:	learn: 0.3501022	total: 5.65s	remaining: 7.16s
# 441:	learn: 0.3500691	total: 5.66s	remaining: 7.15s
# 442:	learn: 0.3500313	total: 5.67s	remaining: 7.14s
# 443:	learn: 0.3499877	total: 5.69s	remaining: 7.13s
# 444:	learn: 0.3499422	total: 5.7s	remaining: 7.11s
# 445:	learn: 0.3498882	total: 5.72s	remaining: 7.1s
# 446:	learn: 0.3498535	total: 5.73s	remaining: 7.09s
# 447:	learn: 0.3498206	total: 5.74s	remaining: 7.08s
# 448:	learn: 0.3497938	total: 5.75s	remaining: 7.06s
# 449:	learn: 0.3497552	total: 5.77s	remaining: 7.05s
# 450:	learn: 0.3497200	total: 5.78s	remaining: 7.04s
# 451:	learn: 0.3496893	total: 5.79s	remaining: 7.03s
# 452:	learn: 0.3496456	total: 5.81s	remaining: 7.01s
# 453:	learn: 0.3496058	total: 5.82s	remaining: 7s
# 454:	learn: 0.3495806	total: 5.83s	remaining: 6.99s
# 455:	learn: 0.3495499	total: 5.85s	remaining: 6.98s
# 456:	learn: 0.3495055	total: 5.86s	remaining: 6.96s
# 457:	learn: 0.3494608	total: 5.87s	remaining: 6.95s
# 458:	learn: 0.3494276	total: 5.89s	remaining: 6.94s
# 459:	learn: 0.3493907	total: 5.9s	remaining: 6.93s
# 460:	learn: 0.3493508	total: 5.91s	remaining: 6.91s
# 461:	learn: 0.3493131	total: 5.93s	remaining: 6.9s
# 462:	learn: 0.3492700	total: 5.94s	remaining: 6.89s
# 463:	learn: 0.3492330	total: 5.95s	remaining: 6.88s
# 464:	learn: 0.3491940	total: 5.97s	remaining: 6.87s
# 465:	learn: 0.3491580	total: 5.98s	remaining: 6.85s
# 466:	learn: 0.3491236	total: 5.99s	remaining: 6.84s
# 467:	learn: 0.3490920	total: 6.01s	remaining: 6.83s
# 468:	learn: 0.3490664	total: 6.02s	remaining: 6.81s
# 469:	learn: 0.3490351	total: 6.03s	remaining: 6.8s
# 470:	learn: 0.3490120	total: 6.04s	remaining: 6.79s
# 471:	learn: 0.3489782	total: 6.06s	remaining: 6.78s
# 472:	learn: 0.3489284	total: 6.07s	remaining: 6.77s
# 473:	learn: 0.3488856	total: 6.09s	remaining: 6.75s
# 474:	learn: 0.3488520	total: 6.1s	remaining: 6.74s
# 475:	learn: 0.3488145	total: 6.11s	remaining: 6.73s
# 476:	learn: 0.3487749	total: 6.13s	remaining: 6.72s
# 477:	learn: 0.3487255	total: 6.14s	remaining: 6.7s
# 478:	learn: 0.3486774	total: 6.15s	remaining: 6.69s
# 479:	learn: 0.3486470	total: 6.16s	remaining: 6.68s
# 480:	learn: 0.3486204	total: 6.18s	remaining: 6.66s
# 481:	learn: 0.3485845	total: 6.19s	remaining: 6.65s
# 482:	learn: 0.3485436	total: 6.2s	remaining: 6.64s
# 483:	learn: 0.3485142	total: 6.22s	remaining: 6.63s
# 484:	learn: 0.3484728	total: 6.23s	remaining: 6.61s
# 485:	learn: 0.3484279	total: 6.24s	remaining: 6.6s
# 486:	learn: 0.3483912	total: 6.26s	remaining: 6.59s
# 487:	learn: 0.3483555	total: 6.27s	remaining: 6.58s
# 488:	learn: 0.3483262	total: 6.28s	remaining: 6.57s
# 489:	learn: 0.3482803	total: 6.3s	remaining: 6.55s
# 490:	learn: 0.3482473	total: 6.31s	remaining: 6.54s
# 491:	learn: 0.3482205	total: 6.33s	remaining: 6.53s
# 492:	learn: 0.3481794	total: 6.34s	remaining: 6.52s
# 493:	learn: 0.3481535	total: 6.35s	remaining: 6.51s
# 494:	learn: 0.3481233	total: 6.37s	remaining: 6.5s
# 495:	learn: 0.3480813	total: 6.38s	remaining: 6.48s
# 496:	learn: 0.3480355	total: 6.39s	remaining: 6.47s
# 497:	learn: 0.3479993	total: 6.41s	remaining: 6.46s
# 498:	learn: 0.3479681	total: 6.42s	remaining: 6.44s
# 499:	learn: 0.3479271	total: 6.43s	remaining: 6.43s
# 500:	learn: 0.3478925	total: 6.45s	remaining: 6.42s
# 501:	learn: 0.3478357	total: 6.46s	remaining: 6.41s
# 502:	learn: 0.3477805	total: 6.47s	remaining: 6.4s
# 503:	learn: 0.3477417	total: 6.49s	remaining: 6.38s
# 504:	learn: 0.3476962	total: 6.5s	remaining: 6.37s
# 505:	learn: 0.3476626	total: 6.51s	remaining: 6.36s
# 506:	learn: 0.3476353	total: 6.53s	remaining: 6.35s
# 507:	learn: 0.3475961	total: 6.54s	remaining: 6.34s
# 508:	learn: 0.3475699	total: 6.56s	remaining: 6.32s
# 509:	learn: 0.3475291	total: 6.57s	remaining: 6.31s
# 510:	learn: 0.3474917	total: 6.58s	remaining: 6.3s
# 511:	learn: 0.3474624	total: 6.6s	remaining: 6.29s
# 512:	learn: 0.3474212	total: 6.61s	remaining: 6.28s
# 513:	learn: 0.3473891	total: 6.62s	remaining: 6.26s
# 514:	learn: 0.3473357	total: 6.64s	remaining: 6.25s
# 515:	learn: 0.3473017	total: 6.65s	remaining: 6.24s
# 516:	learn: 0.3472755	total: 6.66s	remaining: 6.23s
# 517:	learn: 0.3472434	total: 6.68s	remaining: 6.21s
# 518:	learn: 0.3472059	total: 6.69s	remaining: 6.2s
# 519:	learn: 0.3471586	total: 6.71s	remaining: 6.19s
# 520:	learn: 0.3471247	total: 6.72s	remaining: 6.18s
# 521:	learn: 0.3471005	total: 6.73s	remaining: 6.16s
# 522:	learn: 0.3470510	total: 6.74s	remaining: 6.15s
# 523:	learn: 0.3470262	total: 6.76s	remaining: 6.14s
# 524:	learn: 0.3469808	total: 6.77s	remaining: 6.13s
# 525:	learn: 0.3469479	total: 6.79s	remaining: 6.11s
# 526:	learn: 0.3469289	total: 6.8s	remaining: 6.1s
# 527:	learn: 0.3469056	total: 6.81s	remaining: 6.09s
# 528:	learn: 0.3468794	total: 6.83s	remaining: 6.08s
# 529:	learn: 0.3468551	total: 6.84s	remaining: 6.07s
# 530:	learn: 0.3468189	total: 6.86s	remaining: 6.05s
# 531:	learn: 0.3467818	total: 6.87s	remaining: 6.04s
# 532:	learn: 0.3467463	total: 6.88s	remaining: 6.03s
# 533:	learn: 0.3467239	total: 6.9s	remaining: 6.02s
# 534:	learn: 0.3466679	total: 6.91s	remaining: 6.01s
# 535:	learn: 0.3466383	total: 6.92s	remaining: 5.99s
# 536:	learn: 0.3466002	total: 6.94s	remaining: 5.98s
# 537:	learn: 0.3465721	total: 6.95s	remaining: 5.97s
# 538:	learn: 0.3465171	total: 6.98s	remaining: 5.97s
# 539:	learn: 0.3464781	total: 7s	remaining: 5.96s
# 540:	learn: 0.3464488	total: 7.01s	remaining: 5.95s
# 541:	learn: 0.3464203	total: 7.03s	remaining: 5.94s
# 542:	learn: 0.3463979	total: 7.04s	remaining: 5.93s
# 543:	learn: 0.3463689	total: 7.05s	remaining: 5.91s
# 544:	learn: 0.3463384	total: 7.07s	remaining: 5.9s
# 545:	learn: 0.3463022	total: 7.08s	remaining: 5.89s
# 546:	learn: 0.3462730	total: 7.09s	remaining: 5.87s
# 547:	learn: 0.3462419	total: 7.11s	remaining: 5.86s
# 548:	learn: 0.3462146	total: 7.12s	remaining: 5.85s
# 549:	learn: 0.3461667	total: 7.13s	remaining: 5.84s
# 550:	learn: 0.3461211	total: 7.15s	remaining: 5.82s
# 551:	learn: 0.3460945	total: 7.16s	remaining: 5.81s
# 552:	learn: 0.3460500	total: 7.17s	remaining: 5.8s
# 553:	learn: 0.3460251	total: 7.18s	remaining: 5.78s
# 554:	learn: 0.3459950	total: 7.2s	remaining: 5.77s
# 555:	learn: 0.3459594	total: 7.21s	remaining: 5.76s
# 556:	learn: 0.3459247	total: 7.22s	remaining: 5.74s
# 557:	learn: 0.3458826	total: 7.24s	remaining: 5.73s
# 558:	learn: 0.3458609	total: 7.25s	remaining: 5.72s
# 559:	learn: 0.3458281	total: 7.26s	remaining: 5.7s
# 560:	learn: 0.3457980	total: 7.27s	remaining: 5.69s
# 561:	learn: 0.3457723	total: 7.29s	remaining: 5.68s
# 562:	learn: 0.3457409	total: 7.3s	remaining: 5.67s
# 563:	learn: 0.3456956	total: 7.31s	remaining: 5.65s
# 564:	learn: 0.3456628	total: 7.33s	remaining: 5.64s
# 565:	learn: 0.3456313	total: 7.34s	remaining: 5.63s
# 566:	learn: 0.3455907	total: 7.35s	remaining: 5.61s
# 567:	learn: 0.3455547	total: 7.36s	remaining: 5.6s
# 568:	learn: 0.3455049	total: 7.37s	remaining: 5.59s
# 569:	learn: 0.3454741	total: 7.39s	remaining: 5.57s
# 570:	learn: 0.3454422	total: 7.4s	remaining: 5.56s
# 571:	learn: 0.3454083	total: 7.41s	remaining: 5.55s
# 572:	learn: 0.3453733	total: 7.43s	remaining: 5.53s
# 573:	learn: 0.3453387	total: 7.44s	remaining: 5.52s
# 574:	learn: 0.3453084	total: 7.45s	remaining: 5.51s
# 575:	learn: 0.3452832	total: 7.46s	remaining: 5.5s
# 576:	learn: 0.3452564	total: 7.48s	remaining: 5.48s
# 577:	learn: 0.3452332	total: 7.49s	remaining: 5.47s
# 578:	learn: 0.3451963	total: 7.5s	remaining: 5.46s
# 579:	learn: 0.3451658	total: 7.52s	remaining: 5.44s
# 580:	learn: 0.3451409	total: 7.53s	remaining: 5.43s
# 581:	learn: 0.3450980	total: 7.54s	remaining: 5.42s
# 582:	learn: 0.3450679	total: 7.56s	remaining: 5.4s
# 583:	learn: 0.3450426	total: 7.57s	remaining: 5.39s
# 584:	learn: 0.3450159	total: 7.58s	remaining: 5.38s
# 585:	learn: 0.3449821	total: 7.59s	remaining: 5.37s
# 586:	learn: 0.3449419	total: 7.61s	remaining: 5.35s
# 587:	learn: 0.3449022	total: 7.62s	remaining: 5.34s
# 588:	learn: 0.3448737	total: 7.63s	remaining: 5.33s
# 589:	learn: 0.3448444	total: 7.65s	remaining: 5.31s
# 590:	learn: 0.3448217	total: 7.66s	remaining: 5.3s
# 591:	learn: 0.3447853	total: 7.67s	remaining: 5.29s
# 592:	learn: 0.3447401	total: 7.68s	remaining: 5.28s
# 593:	learn: 0.3447153	total: 7.7s	remaining: 5.26s
# 594:	learn: 0.3446739	total: 7.71s	remaining: 5.25s
# 595:	learn: 0.3446315	total: 7.73s	remaining: 5.24s
# 596:	learn: 0.3445978	total: 7.74s	remaining: 5.22s
# 597:	learn: 0.3445679	total: 7.75s	remaining: 5.21s
# 598:	learn: 0.3445394	total: 7.77s	remaining: 5.2s
# 599:	learn: 0.3445173	total: 7.78s	remaining: 5.19s
# 600:	learn: 0.3444903	total: 7.79s	remaining: 5.17s
# 601:	learn: 0.3444487	total: 7.81s	remaining: 5.16s
# 602:	learn: 0.3444112	total: 7.82s	remaining: 5.15s
# 603:	learn: 0.3443771	total: 7.83s	remaining: 5.14s
# 604:	learn: 0.3443368	total: 7.85s	remaining: 5.12s
# 605:	learn: 0.3443122	total: 7.86s	remaining: 5.11s
# 606:	learn: 0.3442837	total: 7.87s	remaining: 5.1s
# 607:	learn: 0.3442530	total: 7.88s	remaining: 5.08s
# 608:	learn: 0.3442175	total: 7.9s	remaining: 5.07s
# 609:	learn: 0.3441883	total: 7.91s	remaining: 5.06s
# 610:	learn: 0.3441531	total: 7.92s	remaining: 5.04s
# 611:	learn: 0.3441333	total: 7.94s	remaining: 5.03s
# 612:	learn: 0.3440936	total: 7.95s	remaining: 5.02s
# 613:	learn: 0.3440444	total: 7.96s	remaining: 5.01s
# 614:	learn: 0.3440035	total: 7.98s	remaining: 5s
# 615:	learn: 0.3439735	total: 7.99s	remaining: 4.98s
# 616:	learn: 0.3439532	total: 8.01s	remaining: 4.97s
# 617:	learn: 0.3439238	total: 8.02s	remaining: 4.96s
# 618:	learn: 0.3438937	total: 8.03s	remaining: 4.94s
# 619:	learn: 0.3438604	total: 8.04s	remaining: 4.93s
# 620:	learn: 0.3438183	total: 8.06s	remaining: 4.92s
# 621:	learn: 0.3437961	total: 8.07s	remaining: 4.9s
# 622:	learn: 0.3437731	total: 8.08s	remaining: 4.89s
# 623:	learn: 0.3437389	total: 8.1s	remaining: 4.88s
# 624:	learn: 0.3437078	total: 8.11s	remaining: 4.87s
# 625:	learn: 0.3436718	total: 8.12s	remaining: 4.85s
# 626:	learn: 0.3436228	total: 8.13s	remaining: 4.84s
# 627:	learn: 0.3436003	total: 8.15s	remaining: 4.83s
# 628:	learn: 0.3435704	total: 8.16s	remaining: 4.81s
# 629:	learn: 0.3435308	total: 8.18s	remaining: 4.8s
# 630:	learn: 0.3435103	total: 8.19s	remaining: 4.79s
# 631:	learn: 0.3434925	total: 8.2s	remaining: 4.78s
# 632:	learn: 0.3434574	total: 8.21s	remaining: 4.76s
# 633:	learn: 0.3434082	total: 8.23s	remaining: 4.75s
# 634:	learn: 0.3433787	total: 8.24s	remaining: 4.74s
# 635:	learn: 0.3433218	total: 8.25s	remaining: 4.72s
# 636:	learn: 0.3432846	total: 8.27s	remaining: 4.71s
# 637:	learn: 0.3432553	total: 8.28s	remaining: 4.7s
# 638:	learn: 0.3432080	total: 8.29s	remaining: 4.68s
# 639:	learn: 0.3431790	total: 8.3s	remaining: 4.67s
# 640:	learn: 0.3431417	total: 8.32s	remaining: 4.66s
# 641:	learn: 0.3431055	total: 8.33s	remaining: 4.65s
# 642:	learn: 0.3430672	total: 8.35s	remaining: 4.63s
# 643:	learn: 0.3430452	total: 8.36s	remaining: 4.62s
# 644:	learn: 0.3429988	total: 8.37s	remaining: 4.61s
# 645:	learn: 0.3429738	total: 8.38s	remaining: 4.59s
# 646:	learn: 0.3429542	total: 8.39s	remaining: 4.58s
# 647:	learn: 0.3429106	total: 8.41s	remaining: 4.57s
# 648:	learn: 0.3428804	total: 8.42s	remaining: 4.55s
# 649:	learn: 0.3428632	total: 8.43s	remaining: 4.54s
# 650:	learn: 0.3428207	total: 8.45s	remaining: 4.53s
# 651:	learn: 0.3427978	total: 8.46s	remaining: 4.51s
# 652:	learn: 0.3427671	total: 8.47s	remaining: 4.5s
# 653:	learn: 0.3427416	total: 8.48s	remaining: 4.49s
# 654:	learn: 0.3427130	total: 8.5s	remaining: 4.48s
# 655:	learn: 0.3426884	total: 8.51s	remaining: 4.46s
# 656:	learn: 0.3426477	total: 8.52s	remaining: 4.45s
# 657:	learn: 0.3426134	total: 8.54s	remaining: 4.44s
# 658:	learn: 0.3425845	total: 8.55s	remaining: 4.42s
# 659:	learn: 0.3425689	total: 8.56s	remaining: 4.41s
# 660:	learn: 0.3425345	total: 8.58s	remaining: 4.4s
# 661:	learn: 0.3425121	total: 8.59s	remaining: 4.38s
# 662:	learn: 0.3424731	total: 8.6s	remaining: 4.37s
# 663:	learn: 0.3424508	total: 8.62s	remaining: 4.36s
# 664:	learn: 0.3424284	total: 8.63s	remaining: 4.35s
# 665:	learn: 0.3423955	total: 8.64s	remaining: 4.33s
# 666:	learn: 0.3423724	total: 8.65s	remaining: 4.32s
# 667:	learn: 0.3423302	total: 8.66s	remaining: 4.31s
# 668:	learn: 0.3422950	total: 8.68s	remaining: 4.29s
# 669:	learn: 0.3422581	total: 8.69s	remaining: 4.28s
# 670:	learn: 0.3422397	total: 8.7s	remaining: 4.26s
# 671:	learn: 0.3422095	total: 8.71s	remaining: 4.25s
# 672:	learn: 0.3421741	total: 8.72s	remaining: 4.24s
# 673:	learn: 0.3421521	total: 8.73s	remaining: 4.22s
# 674:	learn: 0.3421319	total: 8.75s	remaining: 4.21s
# 675:	learn: 0.3421065	total: 8.76s	remaining: 4.2s
# 676:	learn: 0.3420817	total: 8.77s	remaining: 4.18s
# 677:	learn: 0.3420544	total: 8.78s	remaining: 4.17s
# 678:	learn: 0.3420134	total: 8.79s	remaining: 4.16s
# 679:	learn: 0.3419568	total: 8.8s	remaining: 4.14s
# 680:	learn: 0.3419215	total: 8.82s	remaining: 4.13s
# 681:	learn: 0.3418958	total: 8.83s	remaining: 4.12s
# 682:	learn: 0.3418688	total: 8.84s	remaining: 4.1s
# 683:	learn: 0.3418367	total: 8.85s	remaining: 4.09s
# 684:	learn: 0.3418083	total: 8.86s	remaining: 4.08s
# 685:	learn: 0.3417803	total: 8.87s	remaining: 4.06s
# 686:	learn: 0.3417545	total: 8.89s	remaining: 4.05s
# 687:	learn: 0.3417182	total: 8.9s	remaining: 4.04s
# 688:	learn: 0.3416916	total: 8.91s	remaining: 4.02s
# 689:	learn: 0.3416649	total: 8.93s	remaining: 4.01s
# 690:	learn: 0.3416383	total: 8.94s	remaining: 4s
# 691:	learn: 0.3416038	total: 8.95s	remaining: 3.98s
# 692:	learn: 0.3415804	total: 8.96s	remaining: 3.97s
# 693:	learn: 0.3415487	total: 8.97s	remaining: 3.96s
# 694:	learn: 0.3415156	total: 8.99s	remaining: 3.94s
# 695:	learn: 0.3414873	total: 9s	remaining: 3.93s
# 696:	learn: 0.3414465	total: 9.01s	remaining: 3.92s
# 697:	learn: 0.3414039	total: 9.02s	remaining: 3.9s
# 698:	learn: 0.3413646	total: 9.03s	remaining: 3.89s
# 699:	learn: 0.3413373	total: 9.05s	remaining: 3.88s
# 700:	learn: 0.3413150	total: 9.06s	remaining: 3.86s
# 701:	learn: 0.3412754	total: 9.07s	remaining: 3.85s
# 702:	learn: 0.3412533	total: 9.08s	remaining: 3.83s
# 703:	learn: 0.3412349	total: 9.09s	remaining: 3.82s
# 704:	learn: 0.3411937	total: 9.1s	remaining: 3.81s
# 705:	learn: 0.3411670	total: 9.11s	remaining: 3.79s
# 706:	learn: 0.3411227	total: 9.12s	remaining: 3.78s
# 707:	learn: 0.3410946	total: 9.14s	remaining: 3.77s
# 708:	learn: 0.3410688	total: 9.15s	remaining: 3.75s
# 709:	learn: 0.3410473	total: 9.16s	remaining: 3.74s
# 710:	learn: 0.3410251	total: 9.18s	remaining: 3.73s
# 711:	learn: 0.3409965	total: 9.19s	remaining: 3.72s
# 712:	learn: 0.3409635	total: 9.2s	remaining: 3.7s
# 713:	learn: 0.3409179	total: 9.21s	remaining: 3.69s
# 714:	learn: 0.3408794	total: 9.23s	remaining: 3.68s
# 715:	learn: 0.3408503	total: 9.24s	remaining: 3.67s
# 716:	learn: 0.3408126	total: 9.25s	remaining: 3.65s
# 717:	learn: 0.3407795	total: 9.27s	remaining: 3.64s
# 718:	learn: 0.3407556	total: 9.28s	remaining: 3.63s
# 719:	learn: 0.3407279	total: 9.29s	remaining: 3.61s
# 720:	learn: 0.3407094	total: 9.3s	remaining: 3.6s
# 721:	learn: 0.3406573	total: 9.31s	remaining: 3.59s
# 722:	learn: 0.3406074	total: 9.33s	remaining: 3.57s
# 723:	learn: 0.3405650	total: 9.34s	remaining: 3.56s
# 724:	learn: 0.3405261	total: 9.36s	remaining: 3.55s
# 725:	learn: 0.3404953	total: 9.37s	remaining: 3.54s
# 726:	learn: 0.3404687	total: 9.38s	remaining: 3.52s
# 727:	learn: 0.3404387	total: 9.39s	remaining: 3.51s
# 728:	learn: 0.3403941	total: 9.4s	remaining: 3.5s
# 729:	learn: 0.3403667	total: 9.42s	remaining: 3.48s
# 730:	learn: 0.3403461	total: 9.43s	remaining: 3.47s
# 731:	learn: 0.3403133	total: 9.44s	remaining: 3.46s
# 732:	learn: 0.3402702	total: 9.46s	remaining: 3.44s
# 733:	learn: 0.3402384	total: 9.47s	remaining: 3.43s
# 734:	learn: 0.3402117	total: 9.48s	remaining: 3.42s
# 735:	learn: 0.3401603	total: 9.5s	remaining: 3.41s
# 736:	learn: 0.3401290	total: 9.51s	remaining: 3.39s
# 737:	learn: 0.3401015	total: 9.52s	remaining: 3.38s
# 738:	learn: 0.3400852	total: 9.54s	remaining: 3.37s
# 739:	learn: 0.3400683	total: 9.55s	remaining: 3.35s
# 740:	learn: 0.3400221	total: 9.56s	remaining: 3.34s
# 741:	learn: 0.3399959	total: 9.57s	remaining: 3.33s
# 742:	learn: 0.3399589	total: 9.59s	remaining: 3.32s
# 743:	learn: 0.3399226	total: 9.6s	remaining: 3.3s
# 744:	learn: 0.3399018	total: 9.61s	remaining: 3.29s
# 745:	learn: 0.3398794	total: 9.63s	remaining: 3.28s
# 746:	learn: 0.3398557	total: 9.64s	remaining: 3.26s
# 747:	learn: 0.3398377	total: 9.65s	remaining: 3.25s
# 748:	learn: 0.3398055	total: 9.66s	remaining: 3.24s
# 749:	learn: 0.3397750	total: 9.68s	remaining: 3.23s
# 750:	learn: 0.3397397	total: 9.69s	remaining: 3.21s
# 751:	learn: 0.3397033	total: 9.7s	remaining: 3.2s
# 752:	learn: 0.3396858	total: 9.71s	remaining: 3.19s
# 753:	learn: 0.3396599	total: 9.73s	remaining: 3.17s
# 754:	learn: 0.3396206	total: 9.74s	remaining: 3.16s
# 755:	learn: 0.3395868	total: 9.75s	remaining: 3.15s
# 756:	learn: 0.3395407	total: 9.77s	remaining: 3.13s
# 757:	learn: 0.3395173	total: 9.78s	remaining: 3.12s
# 758:	learn: 0.3394740	total: 9.79s	remaining: 3.11s
# 759:	learn: 0.3394509	total: 9.8s	remaining: 3.1s
# 760:	learn: 0.3394291	total: 9.81s	remaining: 3.08s
# 761:	learn: 0.3394038	total: 9.82s	remaining: 3.07s
# 762:	learn: 0.3393862	total: 9.84s	remaining: 3.06s
# 763:	learn: 0.3393597	total: 9.85s	remaining: 3.04s
# 764:	learn: 0.3393274	total: 9.86s	remaining: 3.03s
# 765:	learn: 0.3393070	total: 9.87s	remaining: 3.02s
# 766:	learn: 0.3392843	total: 9.88s	remaining: 3s
# 767:	learn: 0.3392586	total: 9.89s	remaining: 2.99s
# 768:	learn: 0.3392253	total: 9.9s	remaining: 2.98s
# 769:	learn: 0.3392102	total: 9.92s	remaining: 2.96s
# 770:	learn: 0.3391799	total: 9.93s	remaining: 2.95s
# 771:	learn: 0.3391646	total: 9.94s	remaining: 2.94s
# 772:	learn: 0.3391438	total: 9.95s	remaining: 2.92s
# 773:	learn: 0.3391017	total: 9.96s	remaining: 2.91s
# 774:	learn: 0.3390559	total: 9.97s	remaining: 2.9s
# 775:	learn: 0.3390281	total: 9.98s	remaining: 2.88s
# 776:	learn: 0.3390100	total: 9.99s	remaining: 2.87s
# 777:	learn: 0.3389779	total: 10s	remaining: 2.85s
# 778:	learn: 0.3389480	total: 10s	remaining: 2.84s
# 779:	learn: 0.3389192	total: 10s	remaining: 2.83s
# 780:	learn: 0.3388774	total: 10s	remaining: 2.81s
# 781:	learn: 0.3388552	total: 10s	remaining: 2.8s
# 782:	learn: 0.3388304	total: 10.1s	remaining: 2.79s
# 783:	learn: 0.3387966	total: 10.1s	remaining: 2.77s
# 784:	learn: 0.3387632	total: 10.1s	remaining: 2.76s
# 785:	learn: 0.3387324	total: 10.1s	remaining: 2.75s
# 786:	learn: 0.3387136	total: 10.1s	remaining: 2.73s
# 787:	learn: 0.3386725	total: 10.1s	remaining: 2.72s
# 788:	learn: 0.3386357	total: 10.1s	remaining: 2.71s
# 789:	learn: 0.3386085	total: 10.1s	remaining: 2.7s
# 790:	learn: 0.3385697	total: 10.2s	remaining: 2.68s
# 791:	learn: 0.3385491	total: 10.2s	remaining: 2.67s
# 792:	learn: 0.3385315	total: 10.2s	remaining: 2.66s
# 793:	learn: 0.3385085	total: 10.2s	remaining: 2.65s
# 794:	learn: 0.3384645	total: 10.2s	remaining: 2.63s
# 795:	learn: 0.3384294	total: 10.2s	remaining: 2.62s
# 796:	learn: 0.3384132	total: 10.2s	remaining: 2.61s
# 797:	learn: 0.3383898	total: 10.2s	remaining: 2.59s
# 798:	learn: 0.3383568	total: 10.3s	remaining: 2.58s
# 799:	learn: 0.3383325	total: 10.3s	remaining: 2.57s
# 800:	learn: 0.3383061	total: 10.3s	remaining: 2.56s
# 801:	learn: 0.3382691	total: 10.3s	remaining: 2.54s
# 802:	learn: 0.3381989	total: 10.3s	remaining: 2.53s
# 803:	learn: 0.3381627	total: 10.3s	remaining: 2.52s
# 804:	learn: 0.3381268	total: 10.3s	remaining: 2.5s
# 805:	learn: 0.3380910	total: 10.4s	remaining: 2.49s
# 806:	learn: 0.3380611	total: 10.4s	remaining: 2.48s
# 807:	learn: 0.3380397	total: 10.4s	remaining: 2.47s
# 808:	learn: 0.3380135	total: 10.4s	remaining: 2.45s
# 809:	learn: 0.3379932	total: 10.4s	remaining: 2.44s
# 810:	learn: 0.3379666	total: 10.4s	remaining: 2.43s
# 811:	learn: 0.3379301	total: 10.4s	remaining: 2.41s
# 812:	learn: 0.3379015	total: 10.4s	remaining: 2.4s
# 813:	learn: 0.3378599	total: 10.5s	remaining: 2.39s
# 814:	learn: 0.3378173	total: 10.5s	remaining: 2.38s
# 815:	learn: 0.3377880	total: 10.5s	remaining: 2.36s
# 816:	learn: 0.3377625	total: 10.5s	remaining: 2.35s
# 817:	learn: 0.3377427	total: 10.5s	remaining: 2.34s
# 818:	learn: 0.3377174	total: 10.5s	remaining: 2.33s
# 819:	learn: 0.3376735	total: 10.5s	remaining: 2.31s
# 820:	learn: 0.3376525	total: 10.5s	remaining: 2.3s
# 821:	learn: 0.3376246	total: 10.6s	remaining: 2.29s
# 822:	learn: 0.3375938	total: 10.6s	remaining: 2.27s
# 823:	learn: 0.3375400	total: 10.6s	remaining: 2.26s
# 824:	learn: 0.3375076	total: 10.6s	remaining: 2.25s
# 825:	learn: 0.3374837	total: 10.6s	remaining: 2.23s
# 826:	learn: 0.3374434	total: 10.6s	remaining: 2.22s
# 827:	learn: 0.3374218	total: 10.6s	remaining: 2.21s
# 828:	learn: 0.3374018	total: 10.7s	remaining: 2.2s
# 829:	learn: 0.3373687	total: 10.7s	remaining: 2.18s
# 830:	learn: 0.3373246	total: 10.7s	remaining: 2.17s
# 831:	learn: 0.3372905	total: 10.7s	remaining: 2.16s
# 832:	learn: 0.3372480	total: 10.7s	remaining: 2.15s
# 833:	learn: 0.3372164	total: 10.7s	remaining: 2.13s
# 834:	learn: 0.3371877	total: 10.7s	remaining: 2.12s
# 835:	learn: 0.3371430	total: 10.7s	remaining: 2.11s
# 836:	learn: 0.3371044	total: 10.8s	remaining: 2.09s
# 837:	learn: 0.3370891	total: 10.8s	remaining: 2.08s
# 838:	learn: 0.3370461	total: 10.8s	remaining: 2.07s
# 839:	learn: 0.3370025	total: 10.8s	remaining: 2.06s
# 840:	learn: 0.3369760	total: 10.8s	remaining: 2.04s
# 841:	learn: 0.3369345	total: 10.8s	remaining: 2.03s
# 842:	learn: 0.3369156	total: 10.8s	remaining: 2.02s
# 843:	learn: 0.3368822	total: 10.8s	remaining: 2s
# 844:	learn: 0.3368411	total: 10.8s	remaining: 1.99s
# 845:	learn: 0.3368204	total: 10.9s	remaining: 1.98s
# 846:	learn: 0.3367876	total: 10.9s	remaining: 1.96s
# 847:	learn: 0.3367506	total: 10.9s	remaining: 1.95s
# 848:	learn: 0.3367240	total: 10.9s	remaining: 1.94s
# 849:	learn: 0.3366764	total: 10.9s	remaining: 1.92s
# 850:	learn: 0.3366488	total: 10.9s	remaining: 1.91s
# 851:	learn: 0.3366218	total: 10.9s	remaining: 1.9s
# 852:	learn: 0.3365969	total: 10.9s	remaining: 1.89s
# 853:	learn: 0.3365745	total: 11s	remaining: 1.87s
# 854:	learn: 0.3365447	total: 11s	remaining: 1.86s
# 855:	learn: 0.3365202	total: 11s	remaining: 1.85s
# 856:	learn: 0.3364808	total: 11s	remaining: 1.83s
# 857:	learn: 0.3364492	total: 11s	remaining: 1.82s
# 858:	learn: 0.3364154	total: 11s	remaining: 1.81s
# 859:	learn: 0.3363735	total: 11s	remaining: 1.79s
# 860:	learn: 0.3363443	total: 11s	remaining: 1.78s
# 861:	learn: 0.3363175	total: 11s	remaining: 1.77s
# 862:	learn: 0.3362927	total: 11.1s	remaining: 1.75s
# 863:	learn: 0.3362637	total: 11.1s	remaining: 1.74s
# 864:	learn: 0.3362290	total: 11.1s	remaining: 1.73s
# 865:	learn: 0.3361834	total: 11.1s	remaining: 1.72s
# 866:	learn: 0.3361547	total: 11.1s	remaining: 1.7s
# 867:	learn: 0.3361013	total: 11.1s	remaining: 1.69s
# 868:	learn: 0.3360791	total: 11.1s	remaining: 1.68s
# 869:	learn: 0.3360495	total: 11.1s	remaining: 1.67s
# 870:	learn: 0.3360298	total: 11.2s	remaining: 1.65s
# 871:	learn: 0.3360003	total: 11.2s	remaining: 1.64s
# 872:	learn: 0.3359844	total: 11.2s	remaining: 1.63s
# 873:	learn: 0.3359681	total: 11.2s	remaining: 1.61s
# 874:	learn: 0.3359427	total: 11.2s	remaining: 1.6s
# 875:	learn: 0.3359134	total: 11.2s	remaining: 1.59s
# 876:	learn: 0.3358828	total: 11.2s	remaining: 1.57s
# 877:	learn: 0.3358461	total: 11.2s	remaining: 1.56s
# 878:	learn: 0.3358125	total: 11.3s	remaining: 1.55s
# 879:	learn: 0.3357737	total: 11.3s	remaining: 1.54s
# 880:	learn: 0.3357561	total: 11.3s	remaining: 1.52s
# 881:	learn: 0.3357330	total: 11.3s	remaining: 1.51s
# 882:	learn: 0.3356977	total: 11.3s	remaining: 1.5s
# 883:	learn: 0.3356737	total: 11.3s	remaining: 1.49s
# 884:	learn: 0.3356349	total: 11.3s	remaining: 1.47s
# 885:	learn: 0.3355959	total: 11.3s	remaining: 1.46s
# 886:	learn: 0.3355731	total: 11.4s	remaining: 1.45s
# 887:	learn: 0.3355503	total: 11.4s	remaining: 1.43s
# 888:	learn: 0.3355277	total: 11.4s	remaining: 1.42s
# 889:	learn: 0.3354951	total: 11.4s	remaining: 1.41s
# 890:	learn: 0.3354728	total: 11.4s	remaining: 1.4s
# 891:	learn: 0.3354364	total: 11.4s	remaining: 1.38s
# 892:	learn: 0.3353908	total: 11.4s	remaining: 1.37s
# 893:	learn: 0.3353504	total: 11.4s	remaining: 1.36s
# 894:	learn: 0.3353201	total: 11.5s	remaining: 1.34s
# 895:	learn: 0.3352753	total: 11.5s	remaining: 1.33s
# 896:	learn: 0.3352429	total: 11.5s	remaining: 1.32s
# 897:	learn: 0.3352142	total: 11.5s	remaining: 1.3s
# 898:	learn: 0.3351844	total: 11.5s	remaining: 1.29s
# 899:	learn: 0.3351528	total: 11.5s	remaining: 1.28s
# 900:	learn: 0.3351064	total: 11.5s	remaining: 1.27s
# 901:	learn: 0.3350749	total: 11.5s	remaining: 1.25s
# 902:	learn: 0.3350493	total: 11.6s	remaining: 1.24s
# 903:	learn: 0.3350218	total: 11.6s	remaining: 1.23s
# 904:	learn: 0.3349911	total: 11.6s	remaining: 1.22s
# 905:	learn: 0.3349634	total: 11.6s	remaining: 1.2s
# 906:	learn: 0.3349242	total: 11.6s	remaining: 1.19s
# 907:	learn: 0.3348908	total: 11.6s	remaining: 1.18s
# 908:	learn: 0.3348593	total: 11.6s	remaining: 1.16s
# 909:	learn: 0.3348126	total: 11.6s	remaining: 1.15s
# 910:	learn: 0.3347770	total: 11.7s	remaining: 1.14s
# 911:	learn: 0.3347360	total: 11.7s	remaining: 1.13s
# 912:	learn: 0.3347035	total: 11.7s	remaining: 1.11s
# 913:	learn: 0.3346715	total: 11.7s	remaining: 1.1s
# 914:	learn: 0.3346526	total: 11.7s	remaining: 1.09s
# 915:	learn: 0.3346213	total: 11.7s	remaining: 1.07s
# 916:	learn: 0.3345897	total: 11.7s	remaining: 1.06s
# 917:	learn: 0.3345613	total: 11.8s	remaining: 1.05s
# 918:	learn: 0.3345286	total: 11.8s	remaining: 1.04s
# 919:	learn: 0.3344963	total: 11.8s	remaining: 1.02s
# 920:	learn: 0.3344678	total: 11.8s	remaining: 1.01s
# 921:	learn: 0.3344253	total: 11.8s	remaining: 999ms
# 922:	learn: 0.3344037	total: 11.8s	remaining: 986ms
# 923:	learn: 0.3343754	total: 11.8s	remaining: 973ms
# 924:	learn: 0.3343520	total: 11.8s	remaining: 960ms
# 925:	learn: 0.3343320	total: 11.9s	remaining: 947ms
# 926:	learn: 0.3343010	total: 11.9s	remaining: 934ms
# 927:	learn: 0.3342832	total: 11.9s	remaining: 922ms
# 928:	learn: 0.3342477	total: 11.9s	remaining: 909ms
# 929:	learn: 0.3342324	total: 11.9s	remaining: 896ms
# 930:	learn: 0.3341887	total: 11.9s	remaining: 883ms
# 931:	learn: 0.3341695	total: 11.9s	remaining: 870ms
# 932:	learn: 0.3341312	total: 11.9s	remaining: 857ms
# 933:	learn: 0.3341196	total: 11.9s	remaining: 844ms
# 934:	learn: 0.3340785	total: 12s	remaining: 831ms
# 935:	learn: 0.3340530	total: 12s	remaining: 819ms
# 936:	learn: 0.3340263	total: 12s	remaining: 806ms
# 937:	learn: 0.3340096	total: 12s	remaining: 793ms
# 938:	learn: 0.3339810	total: 12s	remaining: 780ms
# 939:	learn: 0.3339340	total: 12s	remaining: 767ms
# 940:	learn: 0.3338981	total: 12s	remaining: 754ms
# 941:	learn: 0.3338621	total: 12s	remaining: 742ms
# 942:	learn: 0.3338278	total: 12.1s	remaining: 729ms
# 943:	learn: 0.3338074	total: 12.1s	remaining: 716ms
# 944:	learn: 0.3337661	total: 12.1s	remaining: 703ms
# 945:	learn: 0.3337220	total: 12.1s	remaining: 691ms
# 946:	learn: 0.3337056	total: 12.1s	remaining: 678ms
# 947:	learn: 0.3336658	total: 12.1s	remaining: 665ms
# 948:	learn: 0.3336210	total: 12.1s	remaining: 652ms
# 949:	learn: 0.3336038	total: 12.1s	remaining: 639ms
# 950:	learn: 0.3335801	total: 12.2s	remaining: 627ms
# 951:	learn: 0.3335424	total: 12.2s	remaining: 614ms
# 952:	learn: 0.3335220	total: 12.2s	remaining: 601ms
# 953:	learn: 0.3334985	total: 12.2s	remaining: 588ms
# 954:	learn: 0.3334605	total: 12.2s	remaining: 575ms
# 955:	learn: 0.3334326	total: 12.2s	remaining: 563ms
# 956:	learn: 0.3333947	total: 12.2s	remaining: 550ms
# 957:	learn: 0.3333604	total: 12.2s	remaining: 537ms
# 958:	learn: 0.3333306	total: 12.3s	remaining: 524ms
# 959:	learn: 0.3333072	total: 12.3s	remaining: 511ms
# 960:	learn: 0.3332771	total: 12.3s	remaining: 499ms
# 961:	learn: 0.3332436	total: 12.3s	remaining: 486ms
# 962:	learn: 0.3332266	total: 12.3s	remaining: 473ms
# 963:	learn: 0.3332010	total: 12.3s	remaining: 460ms
# 964:	learn: 0.3331702	total: 12.3s	remaining: 447ms
# 965:	learn: 0.3331353	total: 12.3s	remaining: 435ms
# 966:	learn: 0.3330883	total: 12.4s	remaining: 422ms
# 967:	learn: 0.3330476	total: 12.4s	remaining: 409ms
# 968:	learn: 0.3330212	total: 12.4s	remaining: 396ms
# 969:	learn: 0.3329903	total: 12.4s	remaining: 383ms
# 970:	learn: 0.3329596	total: 12.4s	remaining: 371ms
# 971:	learn: 0.3329325	total: 12.4s	remaining: 358ms
# 972:	learn: 0.3329052	total: 12.4s	remaining: 345ms
# 973:	learn: 0.3328779	total: 12.4s	remaining: 332ms
# 974:	learn: 0.3328567	total: 12.5s	remaining: 319ms
# 975:	learn: 0.3328171	total: 12.5s	remaining: 307ms
# 976:	learn: 0.3327863	total: 12.5s	remaining: 294ms
# 977:	learn: 0.3327621	total: 12.5s	remaining: 281ms
# 978:	learn: 0.3327154	total: 12.5s	remaining: 268ms
# 979:	learn: 0.3326921	total: 12.5s	remaining: 256ms
# 980:	learn: 0.3326705	total: 12.5s	remaining: 243ms
# 981:	learn: 0.3326414	total: 12.5s	remaining: 230ms
# 982:	learn: 0.3326102	total: 12.6s	remaining: 217ms
# 983:	learn: 0.3325803	total: 12.6s	remaining: 204ms
# 984:	learn: 0.3325582	total: 12.6s	remaining: 192ms
# 985:	learn: 0.3325388	total: 12.6s	remaining: 179ms
# 986:	learn: 0.3325091	total: 12.6s	remaining: 166ms
# 987:	learn: 0.3324831	total: 12.6s	remaining: 153ms
# 988:	learn: 0.3324531	total: 12.6s	remaining: 141ms
# 989:	learn: 0.3324285	total: 12.7s	remaining: 128ms
# 990:	learn: 0.3323954	total: 12.7s	remaining: 115ms
# 991:	learn: 0.3323527	total: 12.7s	remaining: 102ms
# 992:	learn: 0.3323271	total: 12.7s	remaining: 89.5ms
# 993:	learn: 0.3322928	total: 12.7s	remaining: 76.7ms
# 994:	learn: 0.3322724	total: 12.7s	remaining: 63.9ms
# 995:	learn: 0.3322335	total: 12.7s	remaining: 51.1ms
# 996:	learn: 0.3321935	total: 12.7s	remaining: 38.3ms
# 997:	learn: 0.3321629	total: 12.8s	remaining: 25.6ms
# 998:	learn: 0.3321412	total: 12.8s	remaining: 12.8ms
# 999:	learn: 0.3321110	total: 12.8s	remaining: 0us
# 82.588

# %% [markdown]
# ### T-learner (CausalML)

# %% [markdown]
# **Задание №2**
#
# Давайте проведем uplift-моделирование на датасете с промо-акциями (df_bogo) с помощью T-learner из библиотеки `CausalML` (BaseTClassifier) качестве классификатора (learner) используйте алгоритм CatBoostClassifier с параметрами по умолчанию. Параметр random_state установите в значение 13.
#
# Рассчитайте qini-score на тестовой выборке для полученного T-learner. Запишите полученный результат с точностью до 3-его знака после запятой.

# %%
# T-learner (CausalML) для df_bogo
t_learner = BaseTClassifier(learner=CatBoostClassifier(random_state=13))

t_learner.fit(
    X=df_bogo_train[feature_cols],
    treatment=df_bogo_train[treatment_col],
    y=df_bogo_train[target_col]
)

# Uplift-предсказания на тестовой выборке
uplift_vals = t_learner.predict(np.array(df_bogo_test[feature_cols].values.copy()))
df_bogo_test['uplift_score'] = np.ravel(uplift_vals)

# Расчет qini-score на тесте
ranked = df_bogo_test.sort_values('uplift_score', ascending=False).copy()
N_c = (ranked['target_class'] <= 1).sum()
N_t = (ranked['target_class'] >= 2).sum()

ranked['n_c1'] = (ranked['target_class'] == 1).astype(int)
ranked['n_t1'] = (ranked['target_class'] == 3).astype(int)
ranked['n_c1/nc'] = ranked['n_c1'].cumsum() / N_c
ranked['n_t1/nt'] = ranked['n_t1'].cumsum() / N_t
ranked['uplift'] = np.round(ranked['n_t1/nt'] - ranked['n_c1/nc'], 5)
ranked['random_uplift'] = np.round(
    ranked['uplift_score'].rank(pct=True, ascending=False) * ranked['uplift'].iloc[-1], 5
)

qini_score_test = (ranked['uplift'] - ranked['random_uplift']).sum()
print(round(qini_score_test, 3))
# Out:
# Learning rate set to 0.032663
# 0:	learn: 0.6650783	total: 10.3ms	remaining: 10.3s
# 1:	learn: 0.6393802	total: 20.5ms	remaining: 10.2s
# 2:	learn: 0.6157642	total: 32.1ms	remaining: 10.7s
# 3:	learn: 0.5936723	total: 42.6ms	remaining: 10.6s
# 4:	learn: 0.5741862	total: 52.2ms	remaining: 10.4s
# 5:	learn: 0.5557552	total: 61.2ms	remaining: 10.1s
# 6:	learn: 0.5377145	total: 72.7ms	remaining: 10.3s
# 7:	learn: 0.5210792	total: 84ms	remaining: 10.4s
# 8:	learn: 0.5066083	total: 92.4ms	remaining: 10.2s
# 9:	learn: 0.4926161	total: 102ms	remaining: 10.1s
# 10:	learn: 0.4803036	total: 112ms	remaining: 10.1s
# 11:	learn: 0.4693821	total: 119ms	remaining: 9.82s
# 12:	learn: 0.4593004	total: 126ms	remaining: 9.6s
# 13:	learn: 0.4491640	total: 134ms	remaining: 9.45s
# 14:	learn: 0.4405325	total: 142ms	remaining: 9.34s
# 15:	learn: 0.4316391	total: 151ms	remaining: 9.31s
# 16:	learn: 0.4240268	total: 159ms	remaining: 9.21s
# 17:	learn: 0.4171335	total: 165ms	remaining: 9s
# 18:	learn: 0.4098712	total: 173ms	remaining: 8.94s
# 19:	learn: 0.4036669	total: 183ms	remaining: 8.94s
# 20:	learn: 0.3980461	total: 191ms	remaining: 8.89s
# 21:	learn: 0.3923312	total: 201ms	remaining: 8.95s
# 22:	learn: 0.3876440	total: 212ms	remaining: 9.01s
# 23:	learn: 0.3831716	total: 224ms	remaining: 9.09s
# 24:	learn: 0.3793871	total: 233ms	remaining: 9.07s
# 25:	learn: 0.3756445	total: 245ms	remaining: 9.16s
# 26:	learn: 0.3721667	total: 257ms	remaining: 9.27s
# 27:	learn: 0.3688942	total: 269ms	remaining: 9.35s
# 28:	learn: 0.3657496	total: 281ms	remaining: 9.41s
# 29:	learn: 0.3631129	total: 290ms	remaining: 9.38s
# 30:	learn: 0.3605339	total: 299ms	remaining: 9.35s
# 31:	learn: 0.3583421	total: 309ms	remaining: 9.34s
# 32:	learn: 0.3559775	total: 322ms	remaining: 9.42s
# 33:	learn: 0.3535156	total: 333ms	remaining: 9.46s
# 34:	learn: 0.3517128	total: 341ms	remaining: 9.4s
# 35:	learn: 0.3500208	total: 349ms	remaining: 9.34s
# 36:	learn: 0.3479428	total: 360ms	remaining: 9.38s
# 37:	learn: 0.3465109	total: 367ms	remaining: 9.3s
# 38:	learn: 0.3451739	total: 375ms	remaining: 9.23s
# 39:	learn: 0.3435881	total: 385ms	remaining: 9.23s
# 40:	learn: 0.3421441	total: 396ms	remaining: 9.26s
# 41:	learn: 0.3408777	total: 407ms	remaining: 9.27s
# 42:	learn: 0.3395719	total: 417ms	remaining: 9.29s
# 43:	learn: 0.3385045	total: 427ms	remaining: 9.28s
# 44:	learn: 0.3373073	total: 437ms	remaining: 9.28s
# 45:	learn: 0.3365154	total: 445ms	remaining: 9.24s
# 46:	learn: 0.3358120	total: 453ms	remaining: 9.19s
# 47:	learn: 0.3348069	total: 463ms	remaining: 9.19s
# 48:	learn: 0.3341013	total: 472ms	remaining: 9.16s
# 49:	learn: 0.3334194	total: 482ms	remaining: 9.16s
# 50:	learn: 0.3324865	total: 493ms	remaining: 9.17s
# 51:	learn: 0.3319133	total: 501ms	remaining: 9.14s
# 52:	learn: 0.3313294	total: 511ms	remaining: 9.13s
# 53:	learn: 0.3307666	total: 519ms	remaining: 9.1s
# 54:	learn: 0.3303889	total: 526ms	remaining: 9.04s
# 55:	learn: 0.3296897	total: 536ms	remaining: 9.04s
# 56:	learn: 0.3292574	total: 545ms	remaining: 9.02s
# 57:	learn: 0.3288779	total: 554ms	remaining: 9s
# 58:	learn: 0.3284710	total: 564ms	remaining: 9s
# 59:	learn: 0.3279088	total: 573ms	remaining: 8.98s
# 60:	learn: 0.3274485	total: 584ms	remaining: 8.98s
# 61:	learn: 0.3271579	total: 593ms	remaining: 8.97s
# 62:	learn: 0.3269458	total: 600ms	remaining: 8.93s
# 63:	learn: 0.3267514	total: 606ms	remaining: 8.87s
# 64:	learn: 0.3262824	total: 617ms	remaining: 8.88s
# 65:	learn: 0.3260470	total: 627ms	remaining: 8.87s
# 66:	learn: 0.3257068	total: 639ms	remaining: 8.9s
# 67:	learn: 0.3252299	total: 650ms	remaining: 8.9s
# 68:	learn: 0.3247798	total: 661ms	remaining: 8.91s
# 69:	learn: 0.3244877	total: 671ms	remaining: 8.92s
# 70:	learn: 0.3242769	total: 681ms	remaining: 8.91s
# 71:	learn: 0.3239015	total: 693ms	remaining: 8.93s
# 72:	learn: 0.3236570	total: 704ms	remaining: 8.94s
# 73:	learn: 0.3233952	total: 716ms	remaining: 8.95s
# 74:	learn: 0.3230638	total: 726ms	remaining: 8.96s
# 75:	learn: 0.3227249	total: 737ms	remaining: 8.96s
# 76:	learn: 0.3225268	total: 747ms	remaining: 8.96s
# 77:	learn: 0.3224103	total: 757ms	remaining: 8.94s
# 78:	learn: 0.3222948	total: 765ms	remaining: 8.91s
# 79:	learn: 0.3220552	total: 775ms	remaining: 8.92s
# 80:	learn: 0.3218147	total: 787ms	remaining: 8.93s
# 81:	learn: 0.3216283	total: 798ms	remaining: 8.94s
# 82:	learn: 0.3214033	total: 810ms	remaining: 8.95s
# 83:	learn: 0.3212923	total: 820ms	remaining: 8.94s
# 84:	learn: 0.3211140	total: 830ms	remaining: 8.93s
# 85:	learn: 0.3209646	total: 841ms	remaining: 8.94s
# 86:	learn: 0.3208511	total: 853ms	remaining: 8.95s
# 87:	learn: 0.3207009	total: 865ms	remaining: 8.97s
# 88:	learn: 0.3206649	total: 873ms	remaining: 8.94s
# 89:	learn: 0.3205443	total: 885ms	remaining: 8.94s
# 90:	learn: 0.3203839	total: 897ms	remaining: 8.96s
# 91:	learn: 0.3203133	total: 907ms	remaining: 8.96s
# 92:	learn: 0.3202058	total: 919ms	remaining: 8.96s
# 93:	learn: 0.3200919	total: 931ms	remaining: 8.97s
# 94:	learn: 0.3198865	total: 943ms	remaining: 8.98s
# 95:	learn: 0.3197132	total: 954ms	remaining: 8.98s
# 96:	learn: 0.3195384	total: 965ms	remaining: 8.98s
# 97:	learn: 0.3194487	total: 976ms	remaining: 8.99s
# 98:	learn: 0.3193082	total: 988ms	remaining: 8.99s
# 99:	learn: 0.3192008	total: 1000ms	remaining: 9s
# 100:	learn: 0.3191437	total: 1.01s	remaining: 9.01s
# 101:	learn: 0.3190230	total: 1.02s	remaining: 9s
# 102:	learn: 0.3188968	total: 1.03s	remaining: 9.01s
# 103:	learn: 0.3188880	total: 1.04s	remaining: 8.97s
# 104:	learn: 0.3187811	total: 1.05s	remaining: 8.97s
# 105:	learn: 0.3187735	total: 1.06s	remaining: 8.95s
# 106:	learn: 0.3186955	total: 1.07s	remaining: 8.93s
# 107:	learn: 0.3185934	total: 1.08s	remaining: 8.94s
# 108:	learn: 0.3185178	total: 1.09s	remaining: 8.95s
# 109:	learn: 0.3183868	total: 1.1s	remaining: 8.93s
# 110:	learn: 0.3183157	total: 1.11s	remaining: 8.93s
# 111:	learn: 0.3182285	total: 1.13s	remaining: 8.93s
# 112:	learn: 0.3181353	total: 1.14s	remaining: 8.93s
# 113:	learn: 0.3180256	total: 1.15s	remaining: 8.92s
# 114:	learn: 0.3179383	total: 1.16s	remaining: 8.91s
# 115:	learn: 0.3179274	total: 1.17s	remaining: 8.88s
# 116:	learn: 0.3178155	total: 1.18s	remaining: 8.88s
# 117:	learn: 0.3178046	total: 1.19s	remaining: 8.86s
# 118:	learn: 0.3177180	total: 1.2s	remaining: 8.85s
# 119:	learn: 0.3176463	total: 1.21s	remaining: 8.85s
# 120:	learn: 0.3175485	total: 1.22s	remaining: 8.86s
# 121:	learn: 0.3174397	total: 1.23s	remaining: 8.85s
# 122:	learn: 0.3174007	total: 1.24s	remaining: 8.85s
# 123:	learn: 0.3173197	total: 1.25s	remaining: 8.85s
# 124:	learn: 0.3172948	total: 1.26s	remaining: 8.83s
# 125:	learn: 0.3172209	total: 1.27s	remaining: 8.84s
# 126:	learn: 0.3171715	total: 1.28s	remaining: 8.83s
# 127:	learn: 0.3171050	total: 1.29s	remaining: 8.82s
# 128:	learn: 0.3170313	total: 1.3s	remaining: 8.8s
# 129:	learn: 0.3169798	total: 1.31s	remaining: 8.79s
# 130:	learn: 0.3169473	total: 1.32s	remaining: 8.77s
# 131:	learn: 0.3169088	total: 1.33s	remaining: 8.76s
# 132:	learn: 0.3168233	total: 1.34s	remaining: 8.75s
# 133:	learn: 0.3167497	total: 1.35s	remaining: 8.74s
# 134:	learn: 0.3166889	total: 1.36s	remaining: 8.73s
# 135:	learn: 0.3165901	total: 1.37s	remaining: 8.72s
# 136:	learn: 0.3165868	total: 1.38s	remaining: 8.68s
# 137:	learn: 0.3165365	total: 1.39s	remaining: 8.67s
# 138:	learn: 0.3164402	total: 1.4s	remaining: 8.65s
# 139:	learn: 0.3163761	total: 1.41s	remaining: 8.64s
# 140:	learn: 0.3163702	total: 1.41s	remaining: 8.61s
# 141:	learn: 0.3162670	total: 1.42s	remaining: 8.6s
# 142:	learn: 0.3161838	total: 1.43s	remaining: 8.59s
# 143:	learn: 0.3160993	total: 1.44s	remaining: 8.57s
# 144:	learn: 0.3160294	total: 1.45s	remaining: 8.57s
# 145:	learn: 0.3159279	total: 1.46s	remaining: 8.56s
# 146:	learn: 0.3158618	total: 1.47s	remaining: 8.55s
# 147:	learn: 0.3157981	total: 1.48s	remaining: 8.55s
# 148:	learn: 0.3157224	total: 1.5s	remaining: 8.54s
# 149:	learn: 0.3156639	total: 1.5s	remaining: 8.52s
# 150:	learn: 0.3156153	total: 1.51s	remaining: 8.51s
# 151:	learn: 0.3155377	total: 1.52s	remaining: 8.51s
# 152:	learn: 0.3154738	total: 1.53s	remaining: 8.49s
# 153:	learn: 0.3154738	total: 1.54s	remaining: 8.46s
# 154:	learn: 0.3154476	total: 1.55s	remaining: 8.44s
# 155:	learn: 0.3153997	total: 1.56s	remaining: 8.43s
# 156:	learn: 0.3153269	total: 1.57s	remaining: 8.43s
# 157:	learn: 0.3152847	total: 1.58s	remaining: 8.42s
# 158:	learn: 0.3152112	total: 1.59s	remaining: 8.41s
# 159:	learn: 0.3151780	total: 1.6s	remaining: 8.39s
# 160:	learn: 0.3150933	total: 1.61s	remaining: 8.39s
# 161:	learn: 0.3150464	total: 1.62s	remaining: 8.39s
# 162:	learn: 0.3149601	total: 1.63s	remaining: 8.38s
# 163:	learn: 0.3148876	total: 1.64s	remaining: 8.37s
# 164:	learn: 0.3148407	total: 1.65s	remaining: 8.36s
# 165:	learn: 0.3148157	total: 1.66s	remaining: 8.35s
# 166:	learn: 0.3147493	total: 1.67s	remaining: 8.34s
# 167:	learn: 0.3146741	total: 1.68s	remaining: 8.33s
# 168:	learn: 0.3146122	total: 1.69s	remaining: 8.32s
# 169:	learn: 0.3145475	total: 1.7s	remaining: 8.31s
# 170:	learn: 0.3144697	total: 1.71s	remaining: 8.3s
# 171:	learn: 0.3144384	total: 1.72s	remaining: 8.3s
# 172:	learn: 0.3143748	total: 1.73s	remaining: 8.29s
# 173:	learn: 0.3143678	total: 1.74s	remaining: 8.27s
# 174:	learn: 0.3143283	total: 1.75s	remaining: 8.26s
# 175:	learn: 0.3142806	total: 1.76s	remaining: 8.25s
# 176:	learn: 0.3142444	total: 1.77s	remaining: 8.24s
# 177:	learn: 0.3142001	total: 1.78s	remaining: 8.23s
# 178:	learn: 0.3141203	total: 1.79s	remaining: 8.23s
# 179:	learn: 0.3141095	total: 1.8s	remaining: 8.21s
# 180:	learn: 0.3140354	total: 1.81s	remaining: 8.21s
# 181:	learn: 0.3139787	total: 1.82s	remaining: 8.2s
# 182:	learn: 0.3139321	total: 1.83s	remaining: 8.19s
# 183:	learn: 0.3139321	total: 1.84s	remaining: 8.17s
# 184:	learn: 0.3138838	total: 1.85s	remaining: 8.16s
# 185:	learn: 0.3138488	total: 1.86s	remaining: 8.15s
# 186:	learn: 0.3138168	total: 1.87s	remaining: 8.14s
# 187:	learn: 0.3138167	total: 1.88s	remaining: 8.12s
# 188:	learn: 0.3137431	total: 1.89s	remaining: 8.1s
# 189:	learn: 0.3137013	total: 1.9s	remaining: 8.09s
# 190:	learn: 0.3136011	total: 1.91s	remaining: 8.08s
# 191:	learn: 0.3135366	total: 1.92s	remaining: 8.07s
# 192:	learn: 0.3134873	total: 1.93s	remaining: 8.06s
# 193:	learn: 0.3134388	total: 1.94s	remaining: 8.04s
# 194:	learn: 0.3133900	total: 1.95s	remaining: 8.03s
# 195:	learn: 0.3133430	total: 1.95s	remaining: 8.02s
# 196:	learn: 0.3132888	total: 1.96s	remaining: 8.01s
# 197:	learn: 0.3132849	total: 1.97s	remaining: 7.99s
# 198:	learn: 0.3132838	total: 1.98s	remaining: 7.96s
# 199:	learn: 0.3132350	total: 1.99s	remaining: 7.95s
# 200:	learn: 0.3131914	total: 2s	remaining: 7.94s
# 201:	learn: 0.3131230	total: 2.01s	remaining: 7.94s
# 202:	learn: 0.3130705	total: 2.02s	remaining: 7.93s
# 203:	learn: 0.3130215	total: 2.03s	remaining: 7.92s
# 204:	learn: 0.3129574	total: 2.04s	remaining: 7.91s
# 205:	learn: 0.3129573	total: 2.05s	remaining: 7.89s
# 206:	learn: 0.3128967	total: 2.06s	remaining: 7.88s
# 207:	learn: 0.3128527	total: 2.07s	remaining: 7.87s
# 208:	learn: 0.3128089	total: 2.08s	remaining: 7.86s
# 209:	learn: 0.3127542	total: 2.08s	remaining: 7.85s
# 210:	learn: 0.3127304	total: 2.1s	remaining: 7.83s
# 211:	learn: 0.3126881	total: 2.1s	remaining: 7.82s
# 212:	learn: 0.3126190	total: 2.11s	remaining: 7.81s
# 213:	learn: 0.3125816	total: 2.12s	remaining: 7.8s
# 214:	learn: 0.3125311	total: 2.13s	remaining: 7.79s
# 215:	learn: 0.3125303	total: 2.14s	remaining: 7.77s
# 216:	learn: 0.3124889	total: 2.15s	remaining: 7.76s
# 217:	learn: 0.3124483	total: 2.16s	remaining: 7.75s
# 218:	learn: 0.3123797	total: 2.17s	remaining: 7.74s
# 219:	learn: 0.3123284	total: 2.18s	remaining: 7.73s
# 220:	learn: 0.3122902	total: 2.19s	remaining: 7.72s
# 221:	learn: 0.3122573	total: 2.2s	remaining: 7.71s
# 222:	learn: 0.3122032	total: 2.21s	remaining: 7.7s
# 223:	learn: 0.3121603	total: 2.22s	remaining: 7.7s
# 224:	learn: 0.3120920	total: 2.23s	remaining: 7.69s
# 225:	learn: 0.3120425	total: 2.24s	remaining: 7.67s
# 226:	learn: 0.3119960	total: 2.25s	remaining: 7.66s
# 227:	learn: 0.3119662	total: 2.26s	remaining: 7.65s
# 228:	learn: 0.3118784	total: 2.27s	remaining: 7.64s
# 229:	learn: 0.3118400	total: 2.28s	remaining: 7.63s
# 230:	learn: 0.3118068	total: 2.29s	remaining: 7.62s
# 231:	learn: 0.3117568	total: 2.3s	remaining: 7.61s
# 232:	learn: 0.3117280	total: 2.31s	remaining: 7.6s
# 233:	learn: 0.3116820	total: 2.32s	remaining: 7.59s
# 234:	learn: 0.3116538	total: 2.33s	remaining: 7.58s
# 235:	learn: 0.3116438	total: 2.34s	remaining: 7.57s
# 236:	learn: 0.3115742	total: 2.35s	remaining: 7.56s
# 237:	learn: 0.3114730	total: 2.36s	remaining: 7.55s
# 238:	learn: 0.3114247	total: 2.37s	remaining: 7.54s
# 239:	learn: 0.3113540	total: 2.38s	remaining: 7.54s
# 240:	learn: 0.3113136	total: 2.39s	remaining: 7.53s
# 241:	learn: 0.3112600	total: 2.4s	remaining: 7.52s
# 242:	learn: 0.3112285	total: 2.41s	remaining: 7.5s
# 243:	learn: 0.3111965	total: 2.42s	remaining: 7.49s
# 244:	learn: 0.3111582	total: 2.43s	remaining: 7.48s
# 245:	learn: 0.3111176	total: 2.44s	remaining: 7.47s
# 246:	learn: 0.3110682	total: 2.45s	remaining: 7.46s
# 247:	learn: 0.3110416	total: 2.46s	remaining: 7.45s
# 248:	learn: 0.3109984	total: 2.47s	remaining: 7.44s
# 249:	learn: 0.3109511	total: 2.48s	remaining: 7.43s
# 250:	learn: 0.3109207	total: 2.48s	remaining: 7.42s
# 251:	learn: 0.3108703	total: 2.49s	remaining: 7.4s
# 252:	learn: 0.3108336	total: 2.5s	remaining: 7.39s
# 253:	learn: 0.3108083	total: 2.51s	remaining: 7.38s
# 254:	learn: 0.3107508	total: 2.52s	remaining: 7.37s
# 255:	learn: 0.3107473	total: 2.53s	remaining: 7.36s
# 256:	learn: 0.3107200	total: 2.54s	remaining: 7.35s
# 257:	learn: 0.3106553	total: 2.55s	remaining: 7.34s
# 258:	learn: 0.3106331	total: 2.56s	remaining: 7.33s
# 259:	learn: 0.3105708	total: 2.57s	remaining: 7.32s
# 260:	learn: 0.3105342	total: 2.58s	remaining: 7.31s
# 261:	learn: 0.3105285	total: 2.59s	remaining: 7.29s
# 262:	learn: 0.3104493	total: 2.6s	remaining: 7.29s
# 263:	learn: 0.3103998	total: 2.61s	remaining: 7.28s
# 264:	learn: 0.3103315	total: 2.62s	remaining: 7.27s
# 265:	learn: 0.3103298	total: 2.63s	remaining: 7.25s
# 266:	learn: 0.3102006	total: 2.63s	remaining: 7.24s
# 267:	learn: 0.3101382	total: 2.65s	remaining: 7.22s
# 268:	learn: 0.3100879	total: 2.65s	remaining: 7.21s
# 269:	learn: 0.3100456	total: 2.67s	remaining: 7.21s
# 270:	learn: 0.3100130	total: 2.67s	remaining: 7.2s
# 271:	learn: 0.3099913	total: 2.68s	remaining: 7.18s
# 272:	learn: 0.3099192	total: 2.69s	remaining: 7.17s
# 273:	learn: 0.3098623	total: 2.7s	remaining: 7.16s
# 274:	learn: 0.3098222	total: 2.71s	remaining: 7.15s
# 275:	learn: 0.3097487	total: 2.72s	remaining: 7.14s
# 276:	learn: 0.3097089	total: 2.73s	remaining: 7.13s
# 277:	learn: 0.3096589	total: 2.74s	remaining: 7.12s
# 278:	learn: 0.3096108	total: 2.75s	remaining: 7.11s
# 279:	learn: 0.3095809	total: 2.76s	remaining: 7.11s
# 280:	learn: 0.3095254	total: 2.77s	remaining: 7.1s
# 281:	learn: 0.3095226	total: 2.78s	remaining: 7.08s
# 282:	learn: 0.3094437	total: 2.79s	remaining: 7.07s
# 283:	learn: 0.3094019	total: 2.8s	remaining: 7.06s
# 284:	learn: 0.3093283	total: 2.81s	remaining: 7.05s
# 285:	learn: 0.3092957	total: 2.82s	remaining: 7.04s
# 286:	learn: 0.3092413	total: 2.83s	remaining: 7.03s
# 287:	learn: 0.3091787	total: 2.84s	remaining: 7.02s
# 288:	learn: 0.3091338	total: 2.85s	remaining: 7.01s
# 289:	learn: 0.3090677	total: 2.86s	remaining: 7s
# 290:	learn: 0.3089881	total: 2.87s	remaining: 6.99s
# 291:	learn: 0.3089520	total: 2.88s	remaining: 6.98s
# 292:	learn: 0.3089002	total: 2.89s	remaining: 6.97s
# 293:	learn: 0.3088336	total: 2.9s	remaining: 6.97s
# 294:	learn: 0.3087702	total: 2.91s	remaining: 6.96s
# 295:	learn: 0.3087029	total: 2.92s	remaining: 6.95s
# 296:	learn: 0.3086483	total: 2.93s	remaining: 6.94s
# 297:	learn: 0.3085788	total: 2.94s	remaining: 6.94s
# 298:	learn: 0.3085788	total: 2.95s	remaining: 6.92s
# 299:	learn: 0.3085166	total: 2.96s	remaining: 6.91s
# 300:	learn: 0.3084514	total: 2.97s	remaining: 6.91s
# 301:	learn: 0.3083942	total: 2.98s	remaining: 6.9s
# 302:	learn: 0.3083372	total: 2.99s	remaining: 6.89s
# 303:	learn: 0.3082836	total: 3s	remaining: 6.88s
# 304:	learn: 0.3082399	total: 3.01s	remaining: 6.87s
# 305:	learn: 0.3081826	total: 3.02s	remaining: 6.86s
# 306:	learn: 0.3081272	total: 3.03s	remaining: 6.85s
# 307:	learn: 0.3080744	total: 3.04s	remaining: 6.83s
# 308:	learn: 0.3080188	total: 3.05s	remaining: 6.83s
# 309:	learn: 0.3079388	total: 3.06s	remaining: 6.82s
# 310:	learn: 0.3078553	total: 3.07s	remaining: 6.8s
# 311:	learn: 0.3078156	total: 3.08s	remaining: 6.8s
# 312:	learn: 0.3077748	total: 3.09s	remaining: 6.79s
# 313:	learn: 0.3077254	total: 3.1s	remaining: 6.78s
# 314:	learn: 0.3076760	total: 3.12s	remaining: 6.77s
# 315:	learn: 0.3076110	total: 3.13s	remaining: 6.77s
# 316:	learn: 0.3075674	total: 3.14s	remaining: 6.76s
# 317:	learn: 0.3074952	total: 3.15s	remaining: 6.75s
# 318:	learn: 0.3074409	total: 3.16s	remaining: 6.74s
# 319:	learn: 0.3073872	total: 3.17s	remaining: 6.73s
# 320:	learn: 0.3073512	total: 3.18s	remaining: 6.72s
# 321:	learn: 0.3073029	total: 3.19s	remaining: 6.71s
# 322:	learn: 0.3072526	total: 3.2s	remaining: 6.7s
# 323:	learn: 0.3072131	total: 3.21s	remaining: 6.69s
# 324:	learn: 0.3071737	total: 3.22s	remaining: 6.68s
# 325:	learn: 0.3071176	total: 3.23s	remaining: 6.67s
# 326:	learn: 0.3070463	total: 3.23s	remaining: 6.66s
# 327:	learn: 0.3070025	total: 3.25s	remaining: 6.65s
# 328:	learn: 0.3069268	total: 3.25s	remaining: 6.64s
# 329:	learn: 0.3068791	total: 3.26s	remaining: 6.63s
# 330:	learn: 0.3068196	total: 3.27s	remaining: 6.62s
# 331:	learn: 0.3067758	total: 3.28s	remaining: 6.61s
# 332:	learn: 0.3067243	total: 3.29s	remaining: 6.59s
# 333:	learn: 0.3066480	total: 3.3s	remaining: 6.58s
# 334:	learn: 0.3065803	total: 3.31s	remaining: 6.57s
# 335:	learn: 0.3065233	total: 3.32s	remaining: 6.57s
# 336:	learn: 0.3064548	total: 3.33s	remaining: 6.56s
# 337:	learn: 0.3063979	total: 3.34s	remaining: 6.55s
# 338:	learn: 0.3063397	total: 3.35s	remaining: 6.54s
# 339:	learn: 0.3062830	total: 3.37s	remaining: 6.53s
# 340:	learn: 0.3062387	total: 3.38s	remaining: 6.52s
# 341:	learn: 0.3061831	total: 3.38s	remaining: 6.51s
# 342:	learn: 0.3061388	total: 3.4s	remaining: 6.5s
# 343:	learn: 0.3060975	total: 3.41s	remaining: 6.5s
# 344:	learn: 0.3060648	total: 3.42s	remaining: 6.49s
# 345:	learn: 0.3060063	total: 3.43s	remaining: 6.48s
# 346:	learn: 0.3059439	total: 3.44s	remaining: 6.47s
# 347:	learn: 0.3058811	total: 3.45s	remaining: 6.46s
# 348:	learn: 0.3058337	total: 3.46s	remaining: 6.45s
# 349:	learn: 0.3057731	total: 3.47s	remaining: 6.44s
# 350:	learn: 0.3057141	total: 3.48s	remaining: 6.43s
# 351:	learn: 0.3056547	total: 3.49s	remaining: 6.42s
# 352:	learn: 0.3056035	total: 3.5s	remaining: 6.41s
# 353:	learn: 0.3055634	total: 3.51s	remaining: 6.4s
# 354:	learn: 0.3055117	total: 3.52s	remaining: 6.39s
# 355:	learn: 0.3054696	total: 3.53s	remaining: 6.38s
# 356:	learn: 0.3054246	total: 3.54s	remaining: 6.38s
# 357:	learn: 0.3053542	total: 3.55s	remaining: 6.36s
# 358:	learn: 0.3053058	total: 3.56s	remaining: 6.36s
# 359:	learn: 0.3052503	total: 3.57s	remaining: 6.35s
# 360:	learn: 0.3052054	total: 3.58s	remaining: 6.34s
# 361:	learn: 0.3051443	total: 3.59s	remaining: 6.33s
# 362:	learn: 0.3050959	total: 3.6s	remaining: 6.32s
# 363:	learn: 0.3050228	total: 3.61s	remaining: 6.31s
# 364:	learn: 0.3049388	total: 3.62s	remaining: 6.3s
# 365:	learn: 0.3048972	total: 3.63s	remaining: 6.29s
# 366:	learn: 0.3048255	total: 3.64s	remaining: 6.28s
# 367:	learn: 0.3047878	total: 3.65s	remaining: 6.27s
# 368:	learn: 0.3047464	total: 3.66s	remaining: 6.26s
# 369:	learn: 0.3047009	total: 3.67s	remaining: 6.25s
# 370:	learn: 0.3046459	total: 3.68s	remaining: 6.24s
# 371:	learn: 0.3045919	total: 3.69s	remaining: 6.23s
# 372:	learn: 0.3045248	total: 3.7s	remaining: 6.22s
# 373:	learn: 0.3044755	total: 3.71s	remaining: 6.21s
# 374:	learn: 0.3044243	total: 3.72s	remaining: 6.2s
# 375:	learn: 0.3043759	total: 3.73s	remaining: 6.2s
# 376:	learn: 0.3042907	total: 3.75s	remaining: 6.19s
# 377:	learn: 0.3042317	total: 3.76s	remaining: 6.18s
# 378:	learn: 0.3041919	total: 3.77s	remaining: 6.17s
# 379:	learn: 0.3041622	total: 3.78s	remaining: 6.16s
# 380:	learn: 0.3041228	total: 3.79s	remaining: 6.16s
# 381:	learn: 0.3040868	total: 3.8s	remaining: 6.14s
# 382:	learn: 0.3040372	total: 3.81s	remaining: 6.14s
# 383:	learn: 0.3039416	total: 3.82s	remaining: 6.13s
# 384:	learn: 0.3038798	total: 3.83s	remaining: 6.12s
# 385:	learn: 0.3038090	total: 3.84s	remaining: 6.11s
# 386:	learn: 0.3037573	total: 3.85s	remaining: 6.1s
# 387:	learn: 0.3036941	total: 3.86s	remaining: 6.09s
# 388:	learn: 0.3036417	total: 3.87s	remaining: 6.08s
# 389:	learn: 0.3036060	total: 3.88s	remaining: 6.07s
# 390:	learn: 0.3035672	total: 3.89s	remaining: 6.06s
# 391:	learn: 0.3035210	total: 3.9s	remaining: 6.05s
# 392:	learn: 0.3034850	total: 3.91s	remaining: 6.04s
# 393:	learn: 0.3034427	total: 3.92s	remaining: 6.03s
# 394:	learn: 0.3034032	total: 3.93s	remaining: 6.03s
# 395:	learn: 0.3033574	total: 3.94s	remaining: 6.02s
# 396:	learn: 0.3033243	total: 3.96s	remaining: 6.01s
# 397:	learn: 0.3032810	total: 3.97s	remaining: 6s
# 398:	learn: 0.3032364	total: 3.98s	remaining: 5.99s
# 399:	learn: 0.3031749	total: 3.99s	remaining: 5.98s
# 400:	learn: 0.3031210	total: 4s	remaining: 5.97s
# 401:	learn: 0.3030778	total: 4.01s	remaining: 5.96s
# 402:	learn: 0.3030006	total: 4.02s	remaining: 5.95s
# 403:	learn: 0.3029393	total: 4.03s	remaining: 5.94s
# 404:	learn: 0.3028940	total: 4.04s	remaining: 5.93s
# 405:	learn: 0.3028346	total: 4.05s	remaining: 5.92s
# 406:	learn: 0.3027927	total: 4.06s	remaining: 5.92s
# 407:	learn: 0.3027454	total: 4.07s	remaining: 5.91s
# 408:	learn: 0.3026751	total: 4.08s	remaining: 5.9s
# 409:	learn: 0.3026090	total: 4.09s	remaining: 5.89s
# 410:	learn: 0.3025691	total: 4.1s	remaining: 5.88s
# 411:	learn: 0.3025170	total: 4.12s	remaining: 5.88s
# 412:	learn: 0.3024608	total: 4.13s	remaining: 5.87s
# 413:	learn: 0.3024158	total: 4.14s	remaining: 5.86s
# 414:	learn: 0.3023650	total: 4.15s	remaining: 5.85s
# 415:	learn: 0.3023232	total: 4.16s	remaining: 5.83s
# 416:	learn: 0.3022694	total: 4.17s	remaining: 5.83s
# 417:	learn: 0.3022037	total: 4.18s	remaining: 5.81s
# 418:	learn: 0.3021678	total: 4.18s	remaining: 5.8s
# 419:	learn: 0.3021120	total: 4.2s	remaining: 5.79s
# 420:	learn: 0.3020657	total: 4.21s	remaining: 5.78s
# 421:	learn: 0.3020114	total: 4.22s	remaining: 5.78s
# 422:	learn: 0.3019812	total: 4.23s	remaining: 5.77s
# 423:	learn: 0.3019148	total: 4.24s	remaining: 5.76s
# 424:	learn: 0.3018743	total: 4.25s	remaining: 5.75s
# 425:	learn: 0.3018321	total: 4.26s	remaining: 5.74s
# 426:	learn: 0.3017901	total: 4.27s	remaining: 5.73s
# 427:	learn: 0.3017224	total: 4.28s	remaining: 5.72s
# 428:	learn: 0.3016866	total: 4.29s	remaining: 5.71s
# 429:	learn: 0.3016367	total: 4.3s	remaining: 5.71s
# 430:	learn: 0.3015808	total: 4.31s	remaining: 5.7s
# 431:	learn: 0.3015286	total: 4.33s	remaining: 5.69s
# 432:	learn: 0.3014658	total: 4.34s	remaining: 5.68s
# 433:	learn: 0.3014079	total: 4.35s	remaining: 5.67s
# 434:	learn: 0.3013804	total: 4.36s	remaining: 5.66s
# 435:	learn: 0.3013437	total: 4.37s	remaining: 5.65s
# 436:	learn: 0.3012877	total: 4.38s	remaining: 5.64s
# 437:	learn: 0.3012451	total: 4.39s	remaining: 5.63s
# 438:	learn: 0.3012082	total: 4.4s	remaining: 5.62s
# 439:	learn: 0.3011733	total: 4.41s	remaining: 5.61s
# 440:	learn: 0.3011414	total: 4.42s	remaining: 5.6s
# 441:	learn: 0.3011093	total: 4.43s	remaining: 5.59s
# 442:	learn: 0.3010475	total: 4.44s	remaining: 5.58s
# 443:	learn: 0.3009934	total: 4.45s	remaining: 5.57s
# 444:	learn: 0.3009444	total: 4.46s	remaining: 5.56s
# 445:	learn: 0.3008705	total: 4.47s	remaining: 5.55s
# 446:	learn: 0.3008183	total: 4.48s	remaining: 5.54s
# 447:	learn: 0.3007713	total: 4.49s	remaining: 5.53s
# 448:	learn: 0.3007347	total: 4.5s	remaining: 5.52s
# 449:	learn: 0.3006747	total: 4.51s	remaining: 5.51s
# 450:	learn: 0.3006465	total: 4.52s	remaining: 5.51s
# 451:	learn: 0.3005970	total: 4.54s	remaining: 5.5s
# 452:	learn: 0.3005298	total: 4.55s	remaining: 5.49s
# 453:	learn: 0.3004470	total: 4.56s	remaining: 5.48s
# 454:	learn: 0.3004132	total: 4.57s	remaining: 5.47s
# 455:	learn: 0.3003799	total: 4.58s	remaining: 5.46s
# 456:	learn: 0.3003057	total: 4.59s	remaining: 5.45s
# 457:	learn: 0.3002618	total: 4.6s	remaining: 5.44s
# 458:	learn: 0.3002037	total: 4.61s	remaining: 5.43s
# 459:	learn: 0.3001699	total: 4.62s	remaining: 5.42s
# 460:	learn: 0.3000876	total: 4.63s	remaining: 5.41s
# 461:	learn: 0.3000500	total: 4.64s	remaining: 5.4s
# 462:	learn: 0.3000069	total: 4.65s	remaining: 5.39s
# 463:	learn: 0.2999596	total: 4.66s	remaining: 5.38s
# 464:	learn: 0.2999041	total: 4.67s	remaining: 5.37s
# 465:	learn: 0.2998733	total: 4.68s	remaining: 5.36s
# 466:	learn: 0.2998285	total: 4.69s	remaining: 5.35s
# 467:	learn: 0.2997825	total: 4.7s	remaining: 5.34s
# 468:	learn: 0.2997503	total: 4.71s	remaining: 5.33s
# 469:	learn: 0.2997109	total: 4.72s	remaining: 5.32s
# 470:	learn: 0.2996506	total: 4.73s	remaining: 5.31s
# 471:	learn: 0.2995909	total: 4.74s	remaining: 5.3s
# 472:	learn: 0.2995542	total: 4.75s	remaining: 5.29s
# 473:	learn: 0.2995226	total: 4.76s	remaining: 5.28s
# 474:	learn: 0.2994441	total: 4.77s	remaining: 5.27s
# 475:	learn: 0.2994005	total: 4.78s	remaining: 5.26s
# 476:	learn: 0.2993723	total: 4.79s	remaining: 5.25s
# 477:	learn: 0.2993116	total: 4.8s	remaining: 5.24s
# 478:	learn: 0.2992689	total: 4.81s	remaining: 5.23s
# 479:	learn: 0.2992415	total: 4.82s	remaining: 5.22s
# 480:	learn: 0.2991939	total: 4.83s	remaining: 5.21s
# 481:	learn: 0.2991629	total: 4.84s	remaining: 5.2s
# 482:	learn: 0.2991424	total: 4.85s	remaining: 5.19s
# 483:	learn: 0.2991054	total: 4.86s	remaining: 5.18s
# 484:	learn: 0.2990778	total: 4.87s	remaining: 5.17s
# 485:	learn: 0.2990180	total: 4.88s	remaining: 5.16s
# 486:	learn: 0.2989836	total: 4.89s	remaining: 5.15s
# 487:	learn: 0.2989501	total: 4.9s	remaining: 5.14s
# 488:	learn: 0.2989174	total: 4.91s	remaining: 5.13s
# 489:	learn: 0.2988731	total: 4.92s	remaining: 5.12s
# 490:	learn: 0.2988241	total: 4.93s	remaining: 5.11s
# 491:	learn: 0.2987926	total: 4.94s	remaining: 5.1s
# 492:	learn: 0.2987589	total: 4.95s	remaining: 5.09s
# 493:	learn: 0.2987111	total: 4.96s	remaining: 5.08s
# 494:	learn: 0.2986757	total: 4.97s	remaining: 5.07s
# 495:	learn: 0.2986471	total: 4.98s	remaining: 5.06s
# 496:	learn: 0.2986186	total: 4.99s	remaining: 5.05s
# 497:	learn: 0.2985794	total: 5s	remaining: 5.04s
# 498:	learn: 0.2985158	total: 5.01s	remaining: 5.03s
# 499:	learn: 0.2984757	total: 5.02s	remaining: 5.02s
# 500:	learn: 0.2984304	total: 5.03s	remaining: 5.01s
# 501:	learn: 0.2983847	total: 5.04s	remaining: 5s
# 502:	learn: 0.2983429	total: 5.05s	remaining: 4.99s
# 503:	learn: 0.2983013	total: 5.06s	remaining: 4.98s
# 504:	learn: 0.2982541	total: 5.07s	remaining: 4.97s
# 505:	learn: 0.2982231	total: 5.08s	remaining: 4.96s
# 506:	learn: 0.2981832	total: 5.09s	remaining: 4.95s
# 507:	learn: 0.2980862	total: 5.1s	remaining: 4.94s
# 508:	learn: 0.2980488	total: 5.11s	remaining: 4.93s
# 509:	learn: 0.2980091	total: 5.12s	remaining: 4.92s
# 510:	learn: 0.2979457	total: 5.13s	remaining: 4.91s
# 511:	learn: 0.2979096	total: 5.14s	remaining: 4.9s
# 512:	learn: 0.2978499	total: 5.16s	remaining: 4.89s
# 513:	learn: 0.2978111	total: 5.16s	remaining: 4.88s
# 514:	learn: 0.2977625	total: 5.17s	remaining: 4.87s
# 515:	learn: 0.2976886	total: 5.18s	remaining: 4.86s
# 516:	learn: 0.2976358	total: 5.19s	remaining: 4.85s
# 517:	learn: 0.2975847	total: 5.2s	remaining: 4.84s
# 518:	learn: 0.2975319	total: 5.21s	remaining: 4.83s
# 519:	learn: 0.2974728	total: 5.22s	remaining: 4.82s
# 520:	learn: 0.2974186	total: 5.23s	remaining: 4.81s
# 521:	learn: 0.2973450	total: 5.24s	remaining: 4.8s
# 522:	learn: 0.2973009	total: 5.25s	remaining: 4.79s
# 523:	learn: 0.2972539	total: 5.26s	remaining: 4.78s
# 524:	learn: 0.2972229	total: 5.27s	remaining: 4.77s
# 525:	learn: 0.2971572	total: 5.28s	remaining: 4.76s
# 526:	learn: 0.2971151	total: 5.29s	remaining: 4.75s
# 527:	learn: 0.2970780	total: 5.3s	remaining: 4.74s
# 528:	learn: 0.2970347	total: 5.31s	remaining: 4.73s
# 529:	learn: 0.2969953	total: 5.32s	remaining: 4.72s
# 530:	learn: 0.2969434	total: 5.33s	remaining: 4.71s
# 531:	learn: 0.2968968	total: 5.34s	remaining: 4.7s
# 532:	learn: 0.2968466	total: 5.35s	remaining: 4.69s
# 533:	learn: 0.2968161	total: 5.36s	remaining: 4.68s
# 534:	learn: 0.2967733	total: 5.37s	remaining: 4.67s
# 535:	learn: 0.2967214	total: 5.38s	remaining: 4.66s
# 536:	learn: 0.2966828	total: 5.39s	remaining: 4.65s
# 537:	learn: 0.2966371	total: 5.4s	remaining: 4.64s
# 538:	learn: 0.2966119	total: 5.41s	remaining: 4.63s
# 539:	learn: 0.2965769	total: 5.42s	remaining: 4.62s
# 540:	learn: 0.2965301	total: 5.43s	remaining: 4.61s
# 541:	learn: 0.2965044	total: 5.44s	remaining: 4.6s
# 542:	learn: 0.2964458	total: 5.45s	remaining: 4.59s
# 543:	learn: 0.2964007	total: 5.46s	remaining: 4.58s
# 544:	learn: 0.2963495	total: 5.47s	remaining: 4.57s
# 545:	learn: 0.2963187	total: 5.49s	remaining: 4.56s
# 546:	learn: 0.2962931	total: 5.5s	remaining: 4.55s
# 547:	learn: 0.2962502	total: 5.51s	remaining: 4.54s
# 548:	learn: 0.2961950	total: 5.52s	remaining: 4.53s
# 549:	learn: 0.2961541	total: 5.53s	remaining: 4.53s
# 550:	learn: 0.2961180	total: 5.54s	remaining: 4.51s
# 551:	learn: 0.2960732	total: 5.55s	remaining: 4.5s
# 552:	learn: 0.2960278	total: 5.56s	remaining: 4.5s
# 553:	learn: 0.2959719	total: 5.57s	remaining: 4.49s
# 554:	learn: 0.2959494	total: 5.58s	remaining: 4.48s
# 555:	learn: 0.2959028	total: 5.6s	remaining: 4.47s
# 556:	learn: 0.2958338	total: 5.61s	remaining: 4.46s
# 557:	learn: 0.2958114	total: 5.62s	remaining: 4.45s
# 558:	learn: 0.2957658	total: 5.63s	remaining: 4.44s
# 559:	learn: 0.2957158	total: 5.64s	remaining: 4.43s
# 560:	learn: 0.2956718	total: 5.65s	remaining: 4.42s
# 561:	learn: 0.2956209	total: 5.66s	remaining: 4.41s
# 562:	learn: 0.2955802	total: 5.67s	remaining: 4.4s
# 563:	learn: 0.2955402	total: 5.68s	remaining: 4.39s
# 564:	learn: 0.2954822	total: 5.69s	remaining: 4.38s
# 565:	learn: 0.2954579	total: 5.7s	remaining: 4.37s
# 566:	learn: 0.2954237	total: 5.71s	remaining: 4.36s
# 567:	learn: 0.2953803	total: 5.72s	remaining: 4.35s
# 568:	learn: 0.2953202	total: 5.74s	remaining: 4.35s
# 569:	learn: 0.2952861	total: 5.75s	remaining: 4.34s
# 570:	learn: 0.2952228	total: 5.76s	remaining: 4.33s
# 571:	learn: 0.2951675	total: 5.77s	remaining: 4.32s
# 572:	learn: 0.2951168	total: 5.78s	remaining: 4.31s
# 573:	learn: 0.2950648	total: 5.79s	remaining: 4.3s
# 574:	learn: 0.2950435	total: 5.8s	remaining: 4.29s
# 575:	learn: 0.2950056	total: 5.81s	remaining: 4.28s
# 576:	learn: 0.2949835	total: 5.82s	remaining: 4.27s
# 577:	learn: 0.2949346	total: 5.83s	remaining: 4.26s
# 578:	learn: 0.2948947	total: 5.84s	remaining: 4.25s
# 579:	learn: 0.2948697	total: 5.85s	remaining: 4.24s
# 580:	learn: 0.2948340	total: 5.86s	remaining: 4.23s
# 581:	learn: 0.2948017	total: 5.87s	remaining: 4.22s
# 582:	learn: 0.2947722	total: 5.88s	remaining: 4.21s
# 583:	learn: 0.2947236	total: 5.89s	remaining: 4.2s
# 584:	learn: 0.2946727	total: 5.9s	remaining: 4.19s
# 585:	learn: 0.2946391	total: 5.91s	remaining: 4.18s
# 586:	learn: 0.2946135	total: 5.92s	remaining: 4.17s
# 587:	learn: 0.2945784	total: 5.93s	remaining: 4.16s
# 588:	learn: 0.2945405	total: 5.94s	remaining: 4.15s
# 589:	learn: 0.2945025	total: 5.95s	remaining: 4.14s
# 590:	learn: 0.2944513	total: 5.96s	remaining: 4.13s
# 591:	learn: 0.2944031	total: 5.97s	remaining: 4.12s
# 592:	learn: 0.2943317	total: 5.98s	remaining: 4.11s
# 593:	learn: 0.2942851	total: 6s	remaining: 4.1s
# 594:	learn: 0.2942545	total: 6s	remaining: 4.09s
# 595:	learn: 0.2942331	total: 6.01s	remaining: 4.08s
# 596:	learn: 0.2941910	total: 6.03s	remaining: 4.07s
# 597:	learn: 0.2941613	total: 6.04s	remaining: 4.06s
# 598:	learn: 0.2941033	total: 6.04s	remaining: 4.05s
# 599:	learn: 0.2940697	total: 6.05s	remaining: 4.04s
# 600:	learn: 0.2940499	total: 6.06s	remaining: 4.03s
# 601:	learn: 0.2939801	total: 6.07s	remaining: 4.01s
# 602:	learn: 0.2939294	total: 6.08s	remaining: 4s
# 603:	learn: 0.2939013	total: 6.09s	remaining: 4s
# 604:	learn: 0.2938662	total: 6.1s	remaining: 3.98s
# 605:	learn: 0.2938324	total: 6.12s	remaining: 3.98s
# 606:	learn: 0.2937795	total: 6.13s	remaining: 3.97s
# 607:	learn: 0.2937411	total: 6.14s	remaining: 3.96s
# 608:	learn: 0.2937152	total: 6.15s	remaining: 3.95s
# 609:	learn: 0.2936868	total: 6.16s	remaining: 3.94s
# 610:	learn: 0.2936546	total: 6.17s	remaining: 3.93s
# 611:	learn: 0.2936163	total: 6.18s	remaining: 3.92s
# 612:	learn: 0.2935476	total: 6.19s	remaining: 3.91s
# 613:	learn: 0.2935240	total: 6.2s	remaining: 3.9s
# 614:	learn: 0.2934919	total: 6.22s	remaining: 3.89s
# 615:	learn: 0.2934276	total: 6.23s	remaining: 3.88s
# 616:	learn: 0.2933773	total: 6.24s	remaining: 3.87s
# 617:	learn: 0.2933457	total: 6.25s	remaining: 3.86s
# 618:	learn: 0.2933166	total: 6.26s	remaining: 3.85s
# 619:	learn: 0.2932760	total: 6.27s	remaining: 3.84s
# 620:	learn: 0.2932356	total: 6.28s	remaining: 3.83s
# 621:	learn: 0.2932020	total: 6.29s	remaining: 3.82s
# 622:	learn: 0.2931625	total: 6.3s	remaining: 3.81s
# 623:	learn: 0.2931196	total: 6.31s	remaining: 3.8s
# 624:	learn: 0.2930665	total: 6.32s	remaining: 3.79s
# 625:	learn: 0.2930158	total: 6.33s	remaining: 3.78s
# 626:	learn: 0.2929719	total: 6.34s	remaining: 3.77s
# 627:	learn: 0.2929505	total: 6.35s	remaining: 3.76s
# 628:	learn: 0.2929134	total: 6.37s	remaining: 3.75s
# 629:	learn: 0.2928763	total: 6.38s	remaining: 3.74s
# 630:	learn: 0.2928248	total: 6.38s	remaining: 3.73s
# 631:	learn: 0.2927879	total: 6.39s	remaining: 3.72s
# 632:	learn: 0.2927244	total: 6.41s	remaining: 3.71s
# 633:	learn: 0.2926874	total: 6.42s	remaining: 3.7s
# 634:	learn: 0.2926354	total: 6.43s	remaining: 3.69s
# 635:	learn: 0.2925675	total: 6.44s	remaining: 3.68s
# 636:	learn: 0.2925320	total: 6.45s	remaining: 3.67s
# 637:	learn: 0.2924961	total: 6.46s	remaining: 3.66s
# 638:	learn: 0.2924578	total: 6.47s	remaining: 3.65s
# 639:	learn: 0.2924099	total: 6.48s	remaining: 3.65s
# 640:	learn: 0.2923703	total: 6.49s	remaining: 3.63s
# 641:	learn: 0.2923256	total: 6.5s	remaining: 3.63s
# 642:	learn: 0.2922806	total: 6.51s	remaining: 3.62s
# 643:	learn: 0.2922453	total: 6.53s	remaining: 3.61s
# 644:	learn: 0.2921978	total: 6.54s	remaining: 3.6s
# 645:	learn: 0.2921703	total: 6.55s	remaining: 3.59s
# 646:	learn: 0.2921314	total: 6.56s	remaining: 3.58s
# 647:	learn: 0.2920979	total: 6.57s	remaining: 3.57s
# 648:	learn: 0.2920662	total: 6.58s	remaining: 3.56s
# 649:	learn: 0.2920353	total: 6.59s	remaining: 3.55s
# 650:	learn: 0.2920105	total: 6.6s	remaining: 3.54s
# 651:	learn: 0.2919460	total: 6.61s	remaining: 3.53s
# 652:	learn: 0.2919235	total: 6.62s	remaining: 3.52s
# 653:	learn: 0.2918590	total: 6.63s	remaining: 3.51s
# 654:	learn: 0.2917967	total: 6.64s	remaining: 3.5s
# 655:	learn: 0.2917633	total: 6.65s	remaining: 3.49s
# 656:	learn: 0.2917352	total: 6.67s	remaining: 3.48s
# 657:	learn: 0.2916745	total: 6.68s	remaining: 3.47s
# 658:	learn: 0.2916175	total: 6.69s	remaining: 3.46s
# 659:	learn: 0.2915597	total: 6.7s	remaining: 3.45s
# 660:	learn: 0.2914944	total: 6.71s	remaining: 3.44s
# 661:	learn: 0.2914578	total: 6.72s	remaining: 3.43s
# 662:	learn: 0.2913851	total: 6.73s	remaining: 3.42s
# 663:	learn: 0.2913391	total: 6.74s	remaining: 3.41s
# 664:	learn: 0.2912988	total: 6.75s	remaining: 3.4s
# 665:	learn: 0.2912618	total: 6.76s	remaining: 3.39s
# 666:	learn: 0.2912328	total: 6.77s	remaining: 3.38s
# 667:	learn: 0.2911959	total: 6.78s	remaining: 3.37s
# 668:	learn: 0.2911556	total: 6.79s	remaining: 3.36s
# 669:	learn: 0.2911146	total: 6.8s	remaining: 3.35s
# 670:	learn: 0.2910859	total: 6.81s	remaining: 3.34s
# 671:	learn: 0.2910492	total: 6.82s	remaining: 3.33s
# 672:	learn: 0.2910164	total: 6.83s	remaining: 3.32s
# 673:	learn: 0.2909606	total: 6.84s	remaining: 3.31s
# 674:	learn: 0.2909210	total: 6.85s	remaining: 3.3s
# 675:	learn: 0.2908918	total: 6.86s	remaining: 3.29s
# 676:	learn: 0.2908309	total: 6.87s	remaining: 3.28s
# 677:	learn: 0.2907928	total: 6.88s	remaining: 3.27s
# 678:	learn: 0.2907536	total: 6.89s	remaining: 3.26s
# 679:	learn: 0.2907012	total: 6.91s	remaining: 3.25s
# 680:	learn: 0.2906294	total: 6.91s	remaining: 3.24s
# 681:	learn: 0.2905987	total: 6.92s	remaining: 3.23s
# 682:	learn: 0.2905751	total: 6.93s	remaining: 3.22s
# 683:	learn: 0.2905471	total: 6.94s	remaining: 3.21s
# 684:	learn: 0.2905213	total: 6.95s	remaining: 3.2s
# 685:	learn: 0.2904893	total: 6.96s	remaining: 3.19s
# 686:	learn: 0.2904304	total: 6.97s	remaining: 3.18s
# 687:	learn: 0.2903947	total: 6.98s	remaining: 3.17s
# 688:	learn: 0.2903586	total: 6.99s	remaining: 3.16s
# 689:	learn: 0.2903015	total: 7s	remaining: 3.15s
# 690:	learn: 0.2902596	total: 7.01s	remaining: 3.14s
# 691:	learn: 0.2902162	total: 7.02s	remaining: 3.13s
# 692:	learn: 0.2901794	total: 7.03s	remaining: 3.12s
# 693:	learn: 0.2901512	total: 7.04s	remaining: 3.1s
# 694:	learn: 0.2901162	total: 7.05s	remaining: 3.1s
# 695:	learn: 0.2900607	total: 7.06s	remaining: 3.08s
# 696:	learn: 0.2900366	total: 7.07s	remaining: 3.08s
# 697:	learn: 0.2899945	total: 7.08s	remaining: 3.06s
# 698:	learn: 0.2899515	total: 7.09s	remaining: 3.06s
# 699:	learn: 0.2899121	total: 7.11s	remaining: 3.04s
# 700:	learn: 0.2898864	total: 7.11s	remaining: 3.03s
# 701:	learn: 0.2898491	total: 7.13s	remaining: 3.02s
# 702:	learn: 0.2897827	total: 7.14s	remaining: 3.02s
# 703:	learn: 0.2897216	total: 7.15s	remaining: 3s
# 704:	learn: 0.2896618	total: 7.16s	remaining: 3s
# 705:	learn: 0.2896085	total: 7.17s	remaining: 2.98s
# 706:	learn: 0.2895860	total: 7.18s	remaining: 2.97s
# 707:	learn: 0.2895194	total: 7.19s	remaining: 2.96s
# 708:	learn: 0.2894832	total: 7.2s	remaining: 2.95s
# 709:	learn: 0.2894469	total: 7.21s	remaining: 2.94s
# 710:	learn: 0.2894054	total: 7.22s	remaining: 2.93s
# 711:	learn: 0.2893719	total: 7.22s	remaining: 2.92s
# 712:	learn: 0.2893174	total: 7.24s	remaining: 2.91s
# 713:	learn: 0.2892813	total: 7.25s	remaining: 2.9s
# 714:	learn: 0.2892355	total: 7.25s	remaining: 2.89s
# 715:	learn: 0.2892006	total: 7.26s	remaining: 2.88s
# 716:	learn: 0.2891652	total: 7.27s	remaining: 2.87s
# 717:	learn: 0.2891311	total: 7.28s	remaining: 2.86s
# 718:	learn: 0.2890632	total: 7.29s	remaining: 2.85s
# 719:	learn: 0.2890195	total: 7.3s	remaining: 2.84s
# 720:	learn: 0.2889703	total: 7.31s	remaining: 2.83s
# 721:	learn: 0.2889434	total: 7.32s	remaining: 2.82s
# 722:	learn: 0.2889117	total: 7.33s	remaining: 2.81s
# 723:	learn: 0.2888490	total: 7.34s	remaining: 2.8s
# 724:	learn: 0.2888174	total: 7.35s	remaining: 2.79s
# 725:	learn: 0.2887826	total: 7.36s	remaining: 2.78s
# 726:	learn: 0.2887193	total: 7.37s	remaining: 2.77s
# 727:	learn: 0.2886587	total: 7.38s	remaining: 2.76s
# 728:	learn: 0.2886239	total: 7.39s	remaining: 2.75s
# 729:	learn: 0.2885831	total: 7.4s	remaining: 2.74s
# 730:	learn: 0.2885444	total: 7.41s	remaining: 2.73s
# 731:	learn: 0.2885053	total: 7.42s	remaining: 2.72s
# 732:	learn: 0.2884740	total: 7.43s	remaining: 2.71s
# 733:	learn: 0.2884524	total: 7.44s	remaining: 2.7s
# 734:	learn: 0.2884352	total: 7.45s	remaining: 2.69s
# 735:	learn: 0.2884067	total: 7.46s	remaining: 2.68s
# 736:	learn: 0.2883766	total: 7.47s	remaining: 2.67s
# 737:	learn: 0.2883199	total: 7.48s	remaining: 2.66s
# 738:	learn: 0.2882612	total: 7.49s	remaining: 2.65s
# 739:	learn: 0.2882218	total: 7.5s	remaining: 2.64s
# 740:	learn: 0.2881994	total: 7.51s	remaining: 2.63s
# 741:	learn: 0.2881728	total: 7.52s	remaining: 2.62s
# 742:	learn: 0.2881506	total: 7.53s	remaining: 2.6s
# 743:	learn: 0.2881194	total: 7.54s	remaining: 2.6s
# 744:	learn: 0.2880904	total: 7.55s	remaining: 2.58s
# 745:	learn: 0.2880610	total: 7.56s	remaining: 2.58s
# 746:	learn: 0.2880394	total: 7.57s	remaining: 2.56s
# 747:	learn: 0.2880083	total: 7.58s	remaining: 2.56s
# 748:	learn: 0.2879476	total: 7.59s	remaining: 2.54s
# 749:	learn: 0.2879182	total: 7.61s	remaining: 2.54s
# 750:	learn: 0.2878773	total: 7.62s	remaining: 2.52s
# 751:	learn: 0.2878496	total: 7.63s	remaining: 2.52s
# 752:	learn: 0.2878176	total: 7.64s	remaining: 2.5s
# 753:	learn: 0.2877727	total: 7.65s	remaining: 2.5s
# 754:	learn: 0.2877528	total: 7.66s	remaining: 2.48s
# 755:	learn: 0.2877096	total: 7.67s	remaining: 2.47s
# 756:	learn: 0.2876725	total: 7.68s	remaining: 2.46s
# 757:	learn: 0.2876309	total: 7.69s	remaining: 2.45s
# 758:	learn: 0.2875817	total: 7.7s	remaining: 2.44s
# 759:	learn: 0.2875532	total: 7.71s	remaining: 2.43s
# 760:	learn: 0.2875086	total: 7.72s	remaining: 2.42s
# 761:	learn: 0.2874541	total: 7.73s	remaining: 2.41s
# 762:	learn: 0.2874314	total: 7.74s	remaining: 2.4s
# 763:	learn: 0.2873997	total: 7.75s	remaining: 2.39s
# 764:	learn: 0.2873631	total: 7.76s	remaining: 2.38s
# 765:	learn: 0.2873117	total: 7.77s	remaining: 2.37s
# 766:	learn: 0.2872874	total: 7.78s	remaining: 2.36s
# 767:	learn: 0.2872401	total: 7.79s	remaining: 2.35s
# 768:	learn: 0.2871937	total: 7.8s	remaining: 2.34s
# 769:	learn: 0.2871655	total: 7.82s	remaining: 2.33s
# 770:	learn: 0.2871212	total: 7.83s	remaining: 2.32s
# 771:	learn: 0.2870772	total: 7.84s	remaining: 2.31s
# 772:	learn: 0.2870431	total: 7.85s	remaining: 2.3s
# 773:	learn: 0.2870151	total: 7.86s	remaining: 2.29s
# 774:	learn: 0.2870003	total: 7.87s	remaining: 2.29s
# 775:	learn: 0.2869620	total: 7.88s	remaining: 2.27s
# 776:	learn: 0.2869260	total: 7.89s	remaining: 2.26s
# 777:	learn: 0.2868992	total: 7.9s	remaining: 2.25s
# 778:	learn: 0.2868565	total: 7.91s	remaining: 2.24s
# 779:	learn: 0.2868157	total: 7.92s	remaining: 2.23s
# 780:	learn: 0.2867857	total: 7.93s	remaining: 2.22s
# 781:	learn: 0.2867450	total: 7.94s	remaining: 2.21s
# 782:	learn: 0.2867117	total: 7.95s	remaining: 2.2s
# 783:	learn: 0.2866780	total: 7.96s	remaining: 2.19s
# 784:	learn: 0.2866371	total: 7.97s	remaining: 2.18s
# 785:	learn: 0.2866025	total: 7.98s	remaining: 2.17s
# 786:	learn: 0.2865675	total: 7.99s	remaining: 2.16s
# 787:	learn: 0.2865347	total: 8s	remaining: 2.15s
# 788:	learn: 0.2864919	total: 8.01s	remaining: 2.14s
# 789:	learn: 0.2864321	total: 8.02s	remaining: 2.13s
# 790:	learn: 0.2864032	total: 8.03s	remaining: 2.12s
# 791:	learn: 0.2863881	total: 8.04s	remaining: 2.11s
# 792:	learn: 0.2863565	total: 8.05s	remaining: 2.1s
# 793:	learn: 0.2863256	total: 8.06s	remaining: 2.09s
# 794:	learn: 0.2863055	total: 8.07s	remaining: 2.08s
# 795:	learn: 0.2862507	total: 8.08s	remaining: 2.07s
# 796:	learn: 0.2862273	total: 8.09s	remaining: 2.06s
# 797:	learn: 0.2861866	total: 8.1s	remaining: 2.05s
# 798:	learn: 0.2861510	total: 8.11s	remaining: 2.04s
# 799:	learn: 0.2861304	total: 8.12s	remaining: 2.03s
# 800:	learn: 0.2860967	total: 8.13s	remaining: 2.02s
# 801:	learn: 0.2860629	total: 8.14s	remaining: 2.01s
# 802:	learn: 0.2860223	total: 8.15s	remaining: 2s
# 803:	learn: 0.2859820	total: 8.15s	remaining: 1.99s
# 804:	learn: 0.2859626	total: 8.16s	remaining: 1.98s
# 805:	learn: 0.2859126	total: 8.17s	remaining: 1.97s
# 806:	learn: 0.2858899	total: 8.18s	remaining: 1.96s
# 807:	learn: 0.2858452	total: 8.19s	remaining: 1.95s
# 808:	learn: 0.2857950	total: 8.2s	remaining: 1.94s
# 809:	learn: 0.2857467	total: 8.21s	remaining: 1.93s
# 810:	learn: 0.2857141	total: 8.22s	remaining: 1.92s
# 811:	learn: 0.2856817	total: 8.23s	remaining: 1.91s
# 812:	learn: 0.2856253	total: 8.24s	remaining: 1.9s
# 813:	learn: 0.2855593	total: 8.26s	remaining: 1.89s
# 814:	learn: 0.2855069	total: 8.27s	remaining: 1.88s
# 815:	learn: 0.2854809	total: 8.28s	remaining: 1.87s
# 816:	learn: 0.2854353	total: 8.29s	remaining: 1.86s
# 817:	learn: 0.2853954	total: 8.3s	remaining: 1.85s
# 818:	learn: 0.2853449	total: 8.31s	remaining: 1.84s
# 819:	learn: 0.2853111	total: 8.32s	remaining: 1.82s
# 820:	learn: 0.2852569	total: 8.33s	remaining: 1.81s
# 821:	learn: 0.2852120	total: 8.34s	remaining: 1.8s
# 822:	learn: 0.2851877	total: 8.35s	remaining: 1.79s
# 823:	learn: 0.2851474	total: 8.36s	remaining: 1.78s
# 824:	learn: 0.2850875	total: 8.37s	remaining: 1.77s
# 825:	learn: 0.2850562	total: 8.38s	remaining: 1.76s
# 826:	learn: 0.2850255	total: 8.39s	remaining: 1.75s
# 827:	learn: 0.2850065	total: 8.4s	remaining: 1.74s
# 828:	learn: 0.2849532	total: 8.41s	remaining: 1.73s
# 829:	learn: 0.2848976	total: 8.42s	remaining: 1.72s
# 830:	learn: 0.2848793	total: 8.43s	remaining: 1.71s
# 831:	learn: 0.2848296	total: 8.44s	remaining: 1.7s
# 832:	learn: 0.2847902	total: 8.45s	remaining: 1.69s
# 833:	learn: 0.2847518	total: 8.46s	remaining: 1.68s
# 834:	learn: 0.2847251	total: 8.47s	remaining: 1.67s
# 835:	learn: 0.2846978	total: 8.47s	remaining: 1.66s
# 836:	learn: 0.2846731	total: 8.48s	remaining: 1.65s
# 837:	learn: 0.2846403	total: 8.49s	remaining: 1.64s
# 838:	learn: 0.2845968	total: 8.5s	remaining: 1.63s
# 839:	learn: 0.2845638	total: 8.51s	remaining: 1.62s
# 840:	learn: 0.2845402	total: 8.52s	remaining: 1.61s
# 841:	learn: 0.2844838	total: 8.53s	remaining: 1.6s
# 842:	learn: 0.2844558	total: 8.54s	remaining: 1.59s
# 843:	learn: 0.2844107	total: 8.55s	remaining: 1.58s
# 844:	learn: 0.2843747	total: 8.56s	remaining: 1.57s
# 845:	learn: 0.2843053	total: 8.57s	remaining: 1.56s
# 846:	learn: 0.2842615	total: 8.58s	remaining: 1.55s
# 847:	learn: 0.2842214	total: 8.59s	remaining: 1.54s
# 848:	learn: 0.2841863	total: 8.6s	remaining: 1.53s
# 849:	learn: 0.2841274	total: 8.61s	remaining: 1.52s
# 850:	learn: 0.2840886	total: 8.62s	remaining: 1.51s
# 851:	learn: 0.2840569	total: 8.63s	remaining: 1.5s
# 852:	learn: 0.2839976	total: 8.64s	remaining: 1.49s
# 853:	learn: 0.2839645	total: 8.65s	remaining: 1.48s
# 854:	learn: 0.2839340	total: 8.66s	remaining: 1.47s
# 855:	learn: 0.2838871	total: 8.67s	remaining: 1.46s
# 856:	learn: 0.2838584	total: 8.68s	remaining: 1.45s
# 857:	learn: 0.2838010	total: 8.69s	remaining: 1.44s
# 858:	learn: 0.2837576	total: 8.7s	remaining: 1.43s
# 859:	learn: 0.2837054	total: 8.71s	remaining: 1.42s
# 860:	learn: 0.2836670	total: 8.71s	remaining: 1.41s
# 861:	learn: 0.2836443	total: 8.72s	remaining: 1.4s
# 862:	learn: 0.2836016	total: 8.73s	remaining: 1.39s
# 863:	learn: 0.2835573	total: 8.74s	remaining: 1.38s
# 864:	learn: 0.2835117	total: 8.75s	remaining: 1.36s
# 865:	learn: 0.2834835	total: 8.76s	remaining: 1.35s
# 866:	learn: 0.2834357	total: 8.77s	remaining: 1.34s
# 867:	learn: 0.2834113	total: 8.78s	remaining: 1.33s
# 868:	learn: 0.2833555	total: 8.79s	remaining: 1.32s
# 869:	learn: 0.2833145	total: 8.8s	remaining: 1.31s
# 870:	learn: 0.2832831	total: 8.81s	remaining: 1.3s
# 871:	learn: 0.2832506	total: 8.82s	remaining: 1.29s
# 872:	learn: 0.2832099	total: 8.82s	remaining: 1.28s
# 873:	learn: 0.2831856	total: 8.84s	remaining: 1.27s
# 874:	learn: 0.2831206	total: 8.84s	remaining: 1.26s
# 875:	learn: 0.2830895	total: 8.86s	remaining: 1.25s
# 876:	learn: 0.2830310	total: 8.86s	remaining: 1.24s
# 877:	learn: 0.2829915	total: 8.87s	remaining: 1.23s
# 878:	learn: 0.2829423	total: 8.88s	remaining: 1.22s
# 879:	learn: 0.2829068	total: 8.89s	remaining: 1.21s
# 880:	learn: 0.2828917	total: 8.9s	remaining: 1.2s
# 881:	learn: 0.2828627	total: 8.91s	remaining: 1.19s
# 882:	learn: 0.2828189	total: 8.92s	remaining: 1.18s
# 883:	learn: 0.2827782	total: 8.93s	remaining: 1.17s
# 884:	learn: 0.2827545	total: 8.94s	remaining: 1.16s
# 885:	learn: 0.2827037	total: 8.95s	remaining: 1.15s
# 886:	learn: 0.2826697	total: 8.95s	remaining: 1.14s
# 887:	learn: 0.2826186	total: 8.96s	remaining: 1.13s
# 888:	learn: 0.2825714	total: 8.97s	remaining: 1.12s
# 889:	learn: 0.2825464	total: 8.98s	remaining: 1.11s
# 890:	learn: 0.2825112	total: 8.99s	remaining: 1.1s
# 891:	learn: 0.2824883	total: 9s	remaining: 1.09s
# 892:	learn: 0.2824581	total: 9.01s	remaining: 1.08s
# 893:	learn: 0.2824155	total: 9.02s	remaining: 1.07s
# 894:	learn: 0.2823633	total: 9.03s	remaining: 1.06s
# 895:	learn: 0.2823497	total: 9.04s	remaining: 1.05s
# 896:	learn: 0.2823224	total: 9.05s	remaining: 1.04s
# 897:	learn: 0.2822790	total: 9.06s	remaining: 1.03s
# 898:	learn: 0.2822451	total: 9.07s	remaining: 1.02s
# 899:	learn: 0.2822217	total: 9.08s	remaining: 1.01s
# 900:	learn: 0.2821958	total: 9.09s	remaining: 999ms
# 901:	learn: 0.2821578	total: 9.1s	remaining: 989ms
# 902:	learn: 0.2821300	total: 9.11s	remaining: 978ms
# 903:	learn: 0.2820966	total: 9.12s	remaining: 968ms
# 904:	learn: 0.2820538	total: 9.13s	remaining: 958ms
# 905:	learn: 0.2820184	total: 9.14s	remaining: 948ms
# 906:	learn: 0.2819921	total: 9.15s	remaining: 938ms
# 907:	learn: 0.2819699	total: 9.16s	remaining: 928ms
# 908:	learn: 0.2819292	total: 9.17s	remaining: 918ms
# 909:	learn: 0.2818881	total: 9.18s	remaining: 908ms
# 910:	learn: 0.2818495	total: 9.19s	remaining: 897ms
# 911:	learn: 0.2817871	total: 9.2s	remaining: 887ms
# 912:	learn: 0.2817640	total: 9.2s	remaining: 877ms
# 913:	learn: 0.2817431	total: 9.21s	remaining: 867ms
# 914:	learn: 0.2817201	total: 9.22s	remaining: 857ms
# 915:	learn: 0.2816657	total: 9.23s	remaining: 847ms
# 916:	learn: 0.2816065	total: 9.24s	remaining: 837ms
# 917:	learn: 0.2815751	total: 9.25s	remaining: 827ms
# 918:	learn: 0.2815508	total: 9.26s	remaining: 816ms
# 919:	learn: 0.2815130	total: 9.27s	remaining: 806ms
# 920:	learn: 0.2814834	total: 9.28s	remaining: 796ms
# 921:	learn: 0.2814631	total: 9.29s	remaining: 786ms
# 922:	learn: 0.2814228	total: 9.3s	remaining: 776ms
# 923:	learn: 0.2814000	total: 9.31s	remaining: 766ms
# 924:	learn: 0.2813528	total: 9.32s	remaining: 756ms
# 925:	learn: 0.2813282	total: 9.33s	remaining: 745ms
# 926:	learn: 0.2813030	total: 9.34s	remaining: 735ms
# 927:	learn: 0.2812703	total: 9.35s	remaining: 725ms
# ...
# 692:	learn: 0.3758415	total: 6.67s	remaining: 2.96s
# 693:	learn: 0.3758082	total: 6.68s	remaining: 2.94s
# 694:	learn: 0.3757546	total: 6.69s	remaining: 2.93s
# 695:	learn: 0.3756746	total: 6.69s	remaining: 2.92s
# 696:	learn: 0.3756198	total: 6.7s	remaining: 2.91s
# 697:	learn: 0.3755742	total: 6.71s	remaining: 2.9s
# 698:	learn: 0.3755391	total: 6.72s	remaining: 2.89s
# 699:	learn: 0.3755062	total: 6.73s	remaining: 2.88s
# 700:	learn: 0.3754629	total: 6.74s	remaining: 2.87s
# 701:	learn: 0.3754062	total: 6.75s	remaining: 2.86s
# 702:	learn: 0.3753240	total: 6.76s	remaining: 2.85s
# 703:	learn: 0.3752893	total: 6.77s	remaining: 2.85s
# 704:	learn: 0.3752443	total: 6.78s	remaining: 2.83s
# 705:	learn: 0.3752050	total: 6.79s	remaining: 2.83s
# 706:	learn: 0.3751752	total: 6.8s	remaining: 2.82s
# 707:	learn: 0.3751467	total: 6.81s	remaining: 2.81s
# 708:	learn: 0.3751167	total: 6.82s	remaining: 2.8s
# 709:	learn: 0.3750897	total: 6.82s	remaining: 2.79s
# 710:	learn: 0.3750288	total: 6.83s	remaining: 2.78s
# 711:	learn: 0.3749831	total: 6.84s	remaining: 2.77s
# 712:	learn: 0.3749503	total: 6.85s	remaining: 2.76s
# 713:	learn: 0.3748934	total: 6.85s	remaining: 2.75s
# 714:	learn: 0.3748542	total: 6.86s	remaining: 2.73s
# 715:	learn: 0.3747881	total: 6.87s	remaining: 2.72s
# 716:	learn: 0.3747355	total: 6.88s	remaining: 2.71s
# 717:	learn: 0.3746798	total: 6.88s	remaining: 2.7s
# 718:	learn: 0.3746205	total: 6.89s	remaining: 2.69s
# 719:	learn: 0.3745582	total: 6.91s	remaining: 2.69s
# 720:	learn: 0.3745227	total: 6.92s	remaining: 2.68s
# 721:	learn: 0.3744833	total: 6.93s	remaining: 2.67s
# 722:	learn: 0.3744516	total: 6.94s	remaining: 2.66s
# 723:	learn: 0.3744117	total: 6.95s	remaining: 2.65s
# 724:	learn: 0.3743634	total: 6.96s	remaining: 2.64s
# 725:	learn: 0.3743310	total: 6.97s	remaining: 2.63s
# 726:	learn: 0.3742895	total: 6.98s	remaining: 2.62s
# 727:	learn: 0.3742534	total: 6.99s	remaining: 2.61s
# 728:	learn: 0.3742009	total: 7s	remaining: 2.6s
# 729:	learn: 0.3741522	total: 7.02s	remaining: 2.6s
# 730:	learn: 0.3741278	total: 7.03s	remaining: 2.59s
# 731:	learn: 0.3740657	total: 7.04s	remaining: 2.58s
# 732:	learn: 0.3740243	total: 7.06s	remaining: 2.57s
# 733:	learn: 0.3739838	total: 7.07s	remaining: 2.56s
# 734:	learn: 0.3739523	total: 7.08s	remaining: 2.55s
# 735:	learn: 0.3738768	total: 7.1s	remaining: 2.54s
# 736:	learn: 0.3738116	total: 7.11s	remaining: 2.54s
# 737:	learn: 0.3737541	total: 7.12s	remaining: 2.53s
# 738:	learn: 0.3737262	total: 7.13s	remaining: 2.52s
# 739:	learn: 0.3736588	total: 7.14s	remaining: 2.51s
# 740:	learn: 0.3735841	total: 7.16s	remaining: 2.5s
# 741:	learn: 0.3735317	total: 7.17s	remaining: 2.49s
# 742:	learn: 0.3735150	total: 7.19s	remaining: 2.49s
# 743:	learn: 0.3734743	total: 7.2s	remaining: 2.48s
# 744:	learn: 0.3734565	total: 7.22s	remaining: 2.47s
# 745:	learn: 0.3733880	total: 7.23s	remaining: 2.46s
# 746:	learn: 0.3733211	total: 7.24s	remaining: 2.45s
# 747:	learn: 0.3732646	total: 7.25s	remaining: 2.44s
# 748:	learn: 0.3732238	total: 7.27s	remaining: 2.44s
# 749:	learn: 0.3731861	total: 7.28s	remaining: 2.42s
# 750:	learn: 0.3731395	total: 7.29s	remaining: 2.42s
# 751:	learn: 0.3730981	total: 7.3s	remaining: 2.41s
# 752:	learn: 0.3730771	total: 7.31s	remaining: 2.4s
# 753:	learn: 0.3730355	total: 7.32s	remaining: 2.39s
# 754:	learn: 0.3729686	total: 7.33s	remaining: 2.38s
# 755:	learn: 0.3729081	total: 7.34s	remaining: 2.37s
# 756:	learn: 0.3728931	total: 7.35s	remaining: 2.36s
# 757:	learn: 0.3728568	total: 7.36s	remaining: 2.35s
# 758:	learn: 0.3728104	total: 7.37s	remaining: 2.34s
# 759:	learn: 0.3727666	total: 7.38s	remaining: 2.33s
# 760:	learn: 0.3727119	total: 7.38s	remaining: 2.32s
# 761:	learn: 0.3726709	total: 7.39s	remaining: 2.31s
# 762:	learn: 0.3726041	total: 7.4s	remaining: 2.3s
# 763:	learn: 0.3725686	total: 7.4s	remaining: 2.29s
# 764:	learn: 0.3725252	total: 7.41s	remaining: 2.28s
# 765:	learn: 0.3725045	total: 7.42s	remaining: 2.27s
# 766:	learn: 0.3724619	total: 7.42s	remaining: 2.25s
# 767:	learn: 0.3724118	total: 7.43s	remaining: 2.25s
# 768:	learn: 0.3723726	total: 7.44s	remaining: 2.23s
# 769:	learn: 0.3723337	total: 7.45s	remaining: 2.22s
# 770:	learn: 0.3723002	total: 7.46s	remaining: 2.21s
# 771:	learn: 0.3722776	total: 7.47s	remaining: 2.21s
# 772:	learn: 0.3722253	total: 7.48s	remaining: 2.2s
# 773:	learn: 0.3722033	total: 7.49s	remaining: 2.19s
# 774:	learn: 0.3721668	total: 7.51s	remaining: 2.18s
# 775:	learn: 0.3721255	total: 7.52s	remaining: 2.17s
# 776:	learn: 0.3720923	total: 7.53s	remaining: 2.16s
# 777:	learn: 0.3720521	total: 7.55s	remaining: 2.15s
# 778:	learn: 0.3720149	total: 7.56s	remaining: 2.15s
# 779:	learn: 0.3719697	total: 7.58s	remaining: 2.14s
# 780:	learn: 0.3719046	total: 7.58s	remaining: 2.13s
# 781:	learn: 0.3718518	total: 7.6s	remaining: 2.12s
# 782:	learn: 0.3718045	total: 7.61s	remaining: 2.11s
# 783:	learn: 0.3717500	total: 7.62s	remaining: 2.1s
# 784:	learn: 0.3717201	total: 7.63s	remaining: 2.09s
# 785:	learn: 0.3716791	total: 7.64s	remaining: 2.08s
# 786:	learn: 0.3716401	total: 7.66s	remaining: 2.07s
# 787:	learn: 0.3716100	total: 7.67s	remaining: 2.06s
# 788:	learn: 0.3715550	total: 7.67s	remaining: 2.05s
# 789:	learn: 0.3715238	total: 7.68s	remaining: 2.04s
# 790:	learn: 0.3714799	total: 7.69s	remaining: 2.03s
# 791:	learn: 0.3714235	total: 7.7s	remaining: 2.02s
# 792:	learn: 0.3713695	total: 7.7s	remaining: 2.01s
# 793:	learn: 0.3713207	total: 7.71s	remaining: 2s
# 794:	learn: 0.3712822	total: 7.72s	remaining: 1.99s
# 795:	learn: 0.3712623	total: 7.73s	remaining: 1.98s
# 796:	learn: 0.3712465	total: 7.73s	remaining: 1.97s
# 797:	learn: 0.3711844	total: 7.74s	remaining: 1.96s
# 798:	learn: 0.3711393	total: 7.75s	remaining: 1.95s
# 799:	learn: 0.3711023	total: 7.75s	remaining: 1.94s
# 800:	learn: 0.3710726	total: 7.76s	remaining: 1.93s
# 801:	learn: 0.3710024	total: 7.77s	remaining: 1.92s
# 802:	learn: 0.3709648	total: 7.78s	remaining: 1.91s
# 803:	learn: 0.3708985	total: 7.79s	remaining: 1.9s
# 804:	learn: 0.3708607	total: 7.8s	remaining: 1.89s
# 805:	learn: 0.3707843	total: 7.81s	remaining: 1.88s
# 806:	learn: 0.3707309	total: 7.81s	remaining: 1.87s
# 807:	learn: 0.3706706	total: 7.82s	remaining: 1.86s
# 808:	learn: 0.3706051	total: 7.83s	remaining: 1.85s
# 809:	learn: 0.3705536	total: 7.84s	remaining: 1.84s
# 810:	learn: 0.3705097	total: 7.84s	remaining: 1.83s
# 811:	learn: 0.3704790	total: 7.85s	remaining: 1.82s
# 812:	learn: 0.3704369	total: 7.86s	remaining: 1.81s
# 813:	learn: 0.3703768	total: 7.87s	remaining: 1.8s
# 814:	learn: 0.3703462	total: 7.87s	remaining: 1.79s
# 815:	learn: 0.3703097	total: 7.88s	remaining: 1.78s
# 816:	learn: 0.3702471	total: 7.89s	remaining: 1.77s
# 817:	learn: 0.3702285	total: 7.89s	remaining: 1.76s
# 818:	learn: 0.3701712	total: 7.9s	remaining: 1.75s
# 819:	learn: 0.3701366	total: 7.91s	remaining: 1.74s
# 820:	learn: 0.3701065	total: 7.91s	remaining: 1.73s
# 821:	learn: 0.3700480	total: 7.92s	remaining: 1.72s
# 822:	learn: 0.3700123	total: 7.93s	remaining: 1.71s
# 823:	learn: 0.3699181	total: 7.93s	remaining: 1.69s
# 824:	learn: 0.3698793	total: 7.94s	remaining: 1.68s
# 825:	learn: 0.3698281	total: 7.95s	remaining: 1.67s
# 826:	learn: 0.3697905	total: 7.96s	remaining: 1.66s
# 827:	learn: 0.3697531	total: 7.96s	remaining: 1.65s
# 828:	learn: 0.3697123	total: 7.97s	remaining: 1.64s
# 829:	learn: 0.3696545	total: 7.98s	remaining: 1.63s
# 830:	learn: 0.3696256	total: 7.98s	remaining: 1.62s
# 831:	learn: 0.3695472	total: 7.99s	remaining: 1.61s
# 832:	learn: 0.3695013	total: 8s	remaining: 1.6s
# 833:	learn: 0.3694741	total: 8.01s	remaining: 1.59s
# 834:	learn: 0.3694313	total: 8.01s	remaining: 1.58s
# 835:	learn: 0.3693775	total: 8.02s	remaining: 1.57s
# 836:	learn: 0.3693207	total: 8.03s	remaining: 1.56s
# 837:	learn: 0.3692858	total: 8.03s	remaining: 1.55s
# 838:	learn: 0.3692571	total: 8.04s	remaining: 1.54s
# 839:	learn: 0.3692023	total: 8.05s	remaining: 1.53s
# 840:	learn: 0.3691670	total: 8.05s	remaining: 1.52s
# 841:	learn: 0.3691370	total: 8.06s	remaining: 1.51s
# 842:	learn: 0.3691166	total: 8.07s	remaining: 1.5s
# 843:	learn: 0.3690678	total: 8.08s	remaining: 1.49s
# 844:	learn: 0.3690208	total: 8.08s	remaining: 1.48s
# 845:	learn: 0.3689745	total: 8.09s	remaining: 1.47s
# 846:	learn: 0.3689481	total: 8.1s	remaining: 1.46s
# 847:	learn: 0.3688755	total: 8.11s	remaining: 1.45s
# 848:	learn: 0.3688169	total: 8.12s	remaining: 1.44s
# 849:	learn: 0.3687585	total: 8.13s	remaining: 1.43s
# 850:	learn: 0.3687004	total: 8.13s	remaining: 1.42s
# 851:	learn: 0.3686518	total: 8.14s	remaining: 1.41s
# 852:	learn: 0.3685855	total: 8.15s	remaining: 1.4s
# 853:	learn: 0.3685668	total: 8.16s	remaining: 1.39s
# 854:	learn: 0.3685337	total: 8.17s	remaining: 1.38s
# 855:	learn: 0.3684821	total: 8.17s	remaining: 1.38s
# 856:	learn: 0.3684392	total: 8.18s	remaining: 1.36s
# 857:	learn: 0.3684038	total: 8.19s	remaining: 1.35s
# 858:	learn: 0.3683582	total: 8.19s	remaining: 1.34s
# 859:	learn: 0.3683300	total: 8.2s	remaining: 1.33s
# 860:	learn: 0.3683037	total: 8.21s	remaining: 1.32s
# 861:	learn: 0.3682541	total: 8.22s	remaining: 1.31s
# 862:	learn: 0.3682262	total: 8.23s	remaining: 1.3s
# 863:	learn: 0.3681818	total: 8.23s	remaining: 1.29s
# 864:	learn: 0.3681246	total: 8.24s	remaining: 1.28s
# 865:	learn: 0.3680787	total: 8.25s	remaining: 1.28s
# 866:	learn: 0.3680528	total: 8.25s	remaining: 1.27s
# 867:	learn: 0.3679948	total: 8.26s	remaining: 1.26s
# 868:	learn: 0.3679719	total: 8.27s	remaining: 1.25s
# 869:	learn: 0.3679278	total: 8.27s	remaining: 1.24s
# 870:	learn: 0.3678805	total: 8.28s	remaining: 1.23s
# 871:	learn: 0.3678231	total: 8.29s	remaining: 1.22s
# 872:	learn: 0.3677724	total: 8.29s	remaining: 1.21s
# 873:	learn: 0.3677194	total: 8.3s	remaining: 1.2s
# 874:	learn: 0.3676725	total: 8.31s	remaining: 1.19s
# 875:	learn: 0.3676388	total: 8.31s	remaining: 1.18s
# 876:	learn: 0.3675911	total: 8.32s	remaining: 1.17s
# 877:	learn: 0.3675580	total: 8.33s	remaining: 1.16s
# 878:	learn: 0.3675110	total: 8.34s	remaining: 1.15s
# 879:	learn: 0.3674745	total: 8.34s	remaining: 1.14s
# 880:	learn: 0.3674368	total: 8.35s	remaining: 1.13s
# 881:	learn: 0.3673903	total: 8.36s	remaining: 1.12s
# 882:	learn: 0.3673303	total: 8.36s	remaining: 1.11s
# 883:	learn: 0.3672557	total: 8.37s	remaining: 1.1s
# 884:	learn: 0.3672120	total: 8.38s	remaining: 1.09s
# 885:	learn: 0.3671620	total: 8.38s	remaining: 1.08s
# 886:	learn: 0.3671390	total: 8.39s	remaining: 1.07s
# 887:	learn: 0.3670707	total: 8.4s	remaining: 1.06s
# 888:	learn: 0.3670216	total: 8.4s	remaining: 1.05s
# 889:	learn: 0.3669884	total: 8.41s	remaining: 1.04s
# 890:	learn: 0.3669584	total: 8.42s	remaining: 1.03s
# 891:	learn: 0.3669090	total: 8.43s	remaining: 1.02s
# 892:	learn: 0.3668555	total: 8.43s	remaining: 1.01s
# 893:	learn: 0.3668364	total: 8.44s	remaining: 1s
# 894:	learn: 0.3667934	total: 8.45s	remaining: 991ms
# 895:	learn: 0.3667428	total: 8.45s	remaining: 981ms
# 896:	learn: 0.3667038	total: 8.46s	remaining: 971ms
# 897:	learn: 0.3666807	total: 8.47s	remaining: 962ms
# 898:	learn: 0.3666384	total: 8.47s	remaining: 952ms
# 899:	learn: 0.3665903	total: 8.48s	remaining: 942ms
# 900:	learn: 0.3665463	total: 8.49s	remaining: 933ms
# 901:	learn: 0.3664895	total: 8.49s	remaining: 923ms
# 902:	learn: 0.3664493	total: 8.5s	remaining: 913ms
# 903:	learn: 0.3663825	total: 8.51s	remaining: 903ms
# 904:	learn: 0.3663429	total: 8.51s	remaining: 894ms
# 905:	learn: 0.3663086	total: 8.52s	remaining: 884ms
# 906:	learn: 0.3662603	total: 8.53s	remaining: 874ms
# 907:	learn: 0.3662464	total: 8.53s	remaining: 865ms
# 908:	learn: 0.3661939	total: 8.54s	remaining: 855ms
# 909:	learn: 0.3661458	total: 8.55s	remaining: 845ms
# 910:	learn: 0.3660988	total: 8.55s	remaining: 836ms
# 911:	learn: 0.3660514	total: 8.56s	remaining: 826ms
# 912:	learn: 0.3660083	total: 8.57s	remaining: 816ms
# 913:	learn: 0.3659672	total: 8.57s	remaining: 807ms
# 914:	learn: 0.3659236	total: 8.58s	remaining: 797ms
# 915:	learn: 0.3658941	total: 8.59s	remaining: 788ms
# 916:	learn: 0.3658511	total: 8.6s	remaining: 778ms
# 917:	learn: 0.3657994	total: 8.61s	remaining: 769ms
# 918:	learn: 0.3657189	total: 8.62s	remaining: 759ms
# 919:	learn: 0.3656835	total: 8.63s	remaining: 750ms
# 920:	learn: 0.3656530	total: 8.63s	remaining: 741ms
# 921:	learn: 0.3656215	total: 8.64s	remaining: 731ms
# 922:	learn: 0.3655918	total: 8.65s	remaining: 722ms
# 923:	learn: 0.3655449	total: 8.66s	remaining: 712ms
# 924:	learn: 0.3654974	total: 8.67s	remaining: 703ms
# 925:	learn: 0.3654760	total: 8.67s	remaining: 693ms
# 926:	learn: 0.3654226	total: 8.68s	remaining: 684ms
# 927:	learn: 0.3653712	total: 8.69s	remaining: 674ms
# 928:	learn: 0.3653160	total: 8.7s	remaining: 665ms
# 929:	learn: 0.3652781	total: 8.7s	remaining: 655ms
# 930:	learn: 0.3652165	total: 8.71s	remaining: 646ms
# 931:	learn: 0.3651573	total: 8.72s	remaining: 636ms
# 932:	learn: 0.3651104	total: 8.72s	remaining: 627ms
# 933:	learn: 0.3650808	total: 8.73s	remaining: 617ms
# 934:	learn: 0.3650116	total: 8.74s	remaining: 608ms
# 935:	learn: 0.3649491	total: 8.75s	remaining: 598ms
# 936:	learn: 0.3649060	total: 8.75s	remaining: 589ms
# 937:	learn: 0.3648646	total: 8.76s	remaining: 579ms
# 938:	learn: 0.3648263	total: 8.77s	remaining: 570ms
# 939:	learn: 0.3647926	total: 8.77s	remaining: 560ms
# 940:	learn: 0.3647294	total: 8.78s	remaining: 551ms
# 941:	learn: 0.3647089	total: 8.79s	remaining: 541ms
# 942:	learn: 0.3646505	total: 8.79s	remaining: 532ms
# 943:	learn: 0.3646232	total: 8.8s	remaining: 522ms
# 944:	learn: 0.3645904	total: 8.81s	remaining: 513ms
# 945:	learn: 0.3645356	total: 8.81s	remaining: 503ms
# 946:	learn: 0.3644969	total: 8.82s	remaining: 494ms
# 947:	learn: 0.3644524	total: 8.83s	remaining: 484ms
# 948:	learn: 0.3643891	total: 8.84s	remaining: 475ms
# 949:	learn: 0.3643494	total: 8.84s	remaining: 465ms
# 950:	learn: 0.3643255	total: 8.85s	remaining: 456ms
# 951:	learn: 0.3642842	total: 8.86s	remaining: 447ms
# 952:	learn: 0.3642517	total: 8.86s	remaining: 437ms
# 953:	learn: 0.3641917	total: 8.87s	remaining: 428ms
# 954:	learn: 0.3641530	total: 8.88s	remaining: 418ms
# 955:	learn: 0.3641072	total: 8.88s	remaining: 409ms
# 956:	learn: 0.3640501	total: 8.89s	remaining: 399ms
# 957:	learn: 0.3640208	total: 8.9s	remaining: 390ms
# 958:	learn: 0.3639799	total: 8.9s	remaining: 381ms
# 959:	learn: 0.3639553	total: 8.91s	remaining: 371ms
# 960:	learn: 0.3638949	total: 8.91s	remaining: 362ms
# 961:	learn: 0.3638594	total: 8.92s	remaining: 352ms
# 962:	learn: 0.3638117	total: 8.93s	remaining: 343ms
# 963:	learn: 0.3637809	total: 8.94s	remaining: 334ms
# 964:	learn: 0.3637389	total: 8.94s	remaining: 324ms
# 965:	learn: 0.3637166	total: 8.95s	remaining: 315ms
# 966:	learn: 0.3636688	total: 8.96s	remaining: 306ms
# 967:	learn: 0.3636437	total: 8.96s	remaining: 296ms
# 968:	learn: 0.3636096	total: 8.97s	remaining: 287ms
# 969:	learn: 0.3635444	total: 8.98s	remaining: 278ms
# 970:	learn: 0.3635023	total: 8.98s	remaining: 268ms
# 971:	learn: 0.3634411	total: 8.99s	remaining: 259ms
# 972:	learn: 0.3634289	total: 9s	remaining: 250ms
# 973:	learn: 0.3633776	total: 9.01s	remaining: 240ms
# 974:	learn: 0.3633301	total: 9.01s	remaining: 231ms
# 975:	learn: 0.3632769	total: 9.02s	remaining: 222ms
# 976:	learn: 0.3632250	total: 9.03s	remaining: 212ms
# 977:	learn: 0.3631927	total: 9.03s	remaining: 203ms
# 978:	learn: 0.3631618	total: 9.04s	remaining: 194ms
# 979:	learn: 0.3631122	total: 9.04s	remaining: 185ms
# 980:	learn: 0.3630705	total: 9.05s	remaining: 175ms
# 981:	learn: 0.3630322	total: 9.06s	remaining: 166ms
# 982:	learn: 0.3629816	total: 9.07s	remaining: 157ms
# 983:	learn: 0.3629465	total: 9.07s	remaining: 148ms
# 984:	learn: 0.3628967	total: 9.08s	remaining: 138ms
# 985:	learn: 0.3628523	total: 9.09s	remaining: 129ms
# 986:	learn: 0.3628238	total: 9.09s	remaining: 120ms
# 987:	learn: 0.3627767	total: 9.1s	remaining: 111ms
# 988:	learn: 0.3627365	total: 9.11s	remaining: 101ms
# 989:	learn: 0.3627190	total: 9.11s	remaining: 92.1ms
# 990:	learn: 0.3626781	total: 9.12s	remaining: 82.8ms
# 991:	learn: 0.3626469	total: 9.13s	remaining: 73.6ms
# 992:	learn: 0.3626127	total: 9.14s	remaining: 64.4ms
# 993:	learn: 0.3625729	total: 9.14s	remaining: 55.2ms
# 994:	learn: 0.3625294	total: 9.15s	remaining: 46ms
# 995:	learn: 0.3624781	total: 9.16s	remaining: 36.8ms
# 996:	learn: 0.3624417	total: 9.16s	remaining: 27.6ms
# 997:	learn: 0.3624010	total: 9.17s	remaining: 18.4ms
# 998:	learn: 0.3623662	total: 9.18s	remaining: 9.19ms
# 999:	learn: 0.3623446	total: 9.19s	remaining: 0us
# 48.272

# %%
print(round(qini_score_test, 3))
# Out:
# 48.272
