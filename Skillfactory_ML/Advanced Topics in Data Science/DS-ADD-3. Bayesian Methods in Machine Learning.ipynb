# %% [markdown]
# # DS-ADD-3. Байесовские методы в машинном обучении

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 1. Введение

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Метод максимального правдоподобия

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Байесовский подход

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 2. Байесовская регрессия

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Линейная регрессия

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Байесовская линейная регрессия

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Байесовская ridge-регрессия

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### ДОПОЛНИТЕЛЬНЫЕ МАТЕРИАЛЫ
#
# Bishop, C. Pattern Recognition And Machine Learning (Главы 3.1 и 3.3) http://users.isr.ist.utl.pt/~wurmd/Livros/school/Bishop%20-%20Pattern%20Recognition%20And%20Machine%20Learning%20-%20Springer%20%202006.pdf
#
# Пример применения Bayesian Ridge Regression на игрушечных данных  https://scikit-learn.org/stable/auto_examples/linear_model/plot_ard.html
#
# Статья на towardsdatascience.com (на английском) https://towardsdatascience.com/bayesian-linear-regression-in-python-using-machine-learning-to-predict-student-grades-part-2-b72059a8ac7e

# %% [markdown]
# # 3. Байесовская классификация

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Сопряжённые распределения

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ДОПОЛНИТЕЛЬНЫЕ МАТЕРИАЛЫ
#
#
# Статья на machinelearning.ru о наивном байесовском классификаторе http://www.machinelearning.ru/wiki/index.php?title=Наивный_байесовский_классификатор
#
# Игрушечные примеры построения наивного байесовского классификатора https://machinelearningmastery.com/naive-bayes-tutorial-for-machine-learning/
#
# Спам-фильтр с помощью наивного байесовского классификатора   https://www.kdnuggets.com/2020/07/spam-filter-python-naive-bayes-scratch.html
#
# Введение в модель мешка слов (на английском) https://machinelearningmastery.com/gentle-introduction-bag-words-model/
#
# Статья об использовании модели мешка слов для определения тональности текста (на русском) https://habr.com/ru/companies/mlclass/articles/270591/
#
# Multinomial Naive Bayes в sklearn (документация) https://scikit-learn.org/stable/modules/naive_bayes.html#multinomial-naive-bayes

# %% [markdown]
# # 4. Байесовские модели. Практика
