# %% [markdown]
# # DS-ADD-1. Рекомендательные системы

# %% [markdown]
# # 1. Введение. Задача рекомендаций

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
