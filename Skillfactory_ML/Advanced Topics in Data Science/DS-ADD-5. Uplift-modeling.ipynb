# %% [markdown]
# # DS-ADD-5. Uplift-моделирование

# %% [markdown]
# ## 1. Введение

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 2. Оценка качества uplift-модели

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 3. Оценка качества uplift-модели. Практика

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 4. S-learner, T-learner. Принципы работы

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 5. S-learner, T-learner. Принципы работы. Практика

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 6. X-learner, R-learner. Принципы работы

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 7. X-learner, R-learner. Принципы работы. Практика

# %% [markdown]
# ![image.png](attachment:image.png)
