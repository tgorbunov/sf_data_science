# %% [markdown]
# # DE-1. The CAP Theorem. SQL Databases

# %% [markdown]
# ## 0. Вспомнить пройденное

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 1. Введение

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
