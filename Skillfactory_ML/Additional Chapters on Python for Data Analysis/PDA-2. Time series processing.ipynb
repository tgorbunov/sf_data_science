# %% [markdown]
# # PDA-2. Обработка временных рядов

# %% [markdown]
# ## 1. Введение

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 2. Проект модуля

# %% [markdown]
# В этом модуле вас ждёт нестандартное практическое задание! В каждом юните вам необходимо последовательно выполнять задания над проектом в Jupyter Notebook. В конце модуля проект нужно выложить на GitHub для менторской проверки.
#
# Наш проект будет основываться на данных по прогнозированию объёмов продаж тысяч товаров, реализованных в различных магазинах Favorita, расположенных в Эквадоре. Данные включают в себя даты, информацию о магазине и товаре, факте продаж товаров, а также объёме продаж. Дополнительные файлы содержат информацию, которая может быть полезна при построении наших моделей.
#
#  Посмотрим на исходные данные:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# В работе с проектом мы будем использовать не все предоставленные данные. Однако после завершения модуля вы можете дополнить проект таблицами и попробовать улучшить качество прогнозов.
#
# Загрузите файлы с данными и приготовьте Jupyter Notebook. Мы начинаем!

# %% [markdown]
# # 3. Понятие временного ряда. Примеры

# %% [markdown]
# ЧТО ЭТО И ЗАЧЕМ?
#
# Представьте, что вы климатолог и хотите анализировать скорость и направление ветра в разных точках земного шара.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Если вы берёте измерения климатических показателей из разных точек планеты в одно и то же время, то можете считать их независимыми, если точки расположены достаточно далеко друг от друга, и применять для анализа обычную линейную или нелинейную регрессию. В этом случае счётчиком для наблюдений будет номер конкретной метеостанции в вашей выборке.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Но что если вы хотите анализировать климатические характеристики в одной и той же точке планеты, например, измеренные на одной метеорологической станции? Здесь счётчиком будет время, и классическая линейная регрессия внезапно может перестать давать достоверные прогнозы.

# %% [markdown]
# Дело в том, что с появлением зависимости наблюдений от времени вся математическая структура данных поменялась — наблюдения одной и той же переменной в разные моменты времени стали зависимыми между собой. Мы получили так называемый временной ряд.
#
# **Временной ряд** — это измерения одной и той же случайной величины в разные моменты времени.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 4. Характеристики и параметры временных рядов

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Стационарность и нестационарность

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# В качестве дополнительной литературы рекомендуем вам:
#
# - изучить статью «Stationarity in time series analysis» и её дословный перевод; https://towardsdatascience.com/stationarity-in-time-series-a-comprehensive-guide-8beabe20d68/ https://www.machinelearningmastery.ru/stationarity-in-time-series-analysis-90c94f27322/
# - прочесть о гипотезе случайных блужданий для моделей рынка; https://habr.com/ru/companies/iticapital/articles/280954/
# - освоить примеры стационарных случайных процессов; https://hmong.ru/
# - прочесть о проверке стационарности ряда с Python. https://www.machinelearningmastery.ru/time-series-data-stationary-python/
#
# Если вам интересно математическое определение стационарности ряда, то советуем прочесть «Анализ временных рядов» Канторовича Г.  Г. https://lms-cdn.skillfactory.ru/assets/courseware/v1/d5573dadb04656fbbdec9f26f1948c69/asset-v1:SkillFactory+DSPRML+ALWAYS+type@asset+block/lektsii-analiz-vremennyh-ryadov.pdf

# %% [markdown]
# # 5. Характеристики и параметры временных рядов. Практика
