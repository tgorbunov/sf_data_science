# %% [markdown]
# # MVP-2. Оценка качества моделей

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 2. Офлайн-валидация моделей

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## train-validation-test

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Cross-validation

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 3. Офлайн-валидация моделей со смещёнными факторами

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Разное распределение признаков

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Почему модель будет работать плохо?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# https://ru.wikipedia.org/wiki/Экстраполяция

# %% [markdown]
# ## Разное распределение целевой переменной

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Взвешивание объектов

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Увеличение выборки (oversampling)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Удаление выборки (undersampling)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Stratified k-fold cross-validation

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #  4. Офлайн-валидация моделей во времени

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Валидация во времени

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Особенности валидации для оценки временной модели

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 5. Офлайн-валидация. Практика

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 6. Онлайн-метрики качества системы

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Приблизительная оценка precision и recall для онлайн-системы

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## precision

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## recall

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Оценивание модели через бизнес-метрики

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 7. Онлайн-метрики качества системы. Практика

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Пример 3. Банковский скоринг

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Пример 4. Определение оптимального количества операций по рассылке sms

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 8. Подведём итоги

# %% [markdown]
# ![image.png](attachment:image.png)
