# %% [markdown]
# # REAL-ML-2. Машинное обучение в банках

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 2. Примеры ML-задач в банках

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 3. Задача кредитного скоринга. Практика

# %% [markdown]
# Итак, давайте попробуем оценить вероятность того, что человек не вернёт кредит в ближайшие 90 дней.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Почему мы не пошли сразу в более сложные модели? Обсудим это далее! При этом решённая задача выглядит как простая задача классификации — она ей и является.

# %% [markdown]
# # 4. Оценка модельного риска

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 5. Проблемы внутренней кухни

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 6. Подведём итоги

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
