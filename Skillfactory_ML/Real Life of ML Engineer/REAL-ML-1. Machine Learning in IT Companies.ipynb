# %% [markdown]
# # REAL-ML-1. Machine Learning in IT Companies

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 2. Примеры задач в IT-компаниях

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# https://ir-docs.s3.yandex.net/events/2021/IR%20Presentation_4Q2021.pdf

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 3. Перевод бизнес-метрик в метрики машинного обучения

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 4. Задачи машинного обучения в IT-компаниях. Практика

# %% [markdown]
# Давайте теперь немного отвлечёмся от пространной теории и посмотрим на решение задачи предсказания спроса на товары на market-плейсе. Для этого возьмём датасет с Kaggle.
#
# https://www.kaggle.com/c/avito-demand-prediction

# %% [markdown]
# data:
#
# https://drive.google.com/drive/folders/1qTJvfEKLCWHmmN9OyXhNE7AfNuqROnPm

# %% [markdown]
# google notebook:
#
# https://colab.research.google.com/drive/1-Sjm_RIeDbu4RuRKkJ8E0Fiv9cX1Avlf

# %% [markdown]
# эталонное решение: https://colab.research.google.com/drive/1OglAvAmehsrHbD_viTD5fwPe1SCbkLe6

# %% [markdown]
# # 5. Декомпозиция задач

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 6. Проблемы внутренней кухни. Итоги

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
