# %% [markdown]
# # REAL-ML-3. Машинное обучение в ритейле

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 2. Примеры ML-задач в ритейле

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 3. Задача предсказания спроса на товары. Практика

# %% [markdown]
# Давайте слегка попрактикуемся решать задачу предсказания спроса на товары, чтобы отвлечься от теории и вспомнить, как пишется код. Не переживайте, мы не будем уходить в глубокие исследования! В качестве датасета возьмём датасет одного из соревнований Kaggle. Если вы не зарегистрированы на этой площадке, вы можете скачать данные по ссылке ниже.
#
# https://www.kaggle.com/c/favorita-grocery-sales-forecasting/data

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 4. Проблемы внутренней кухни

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 5. Особенности A/B-тестирования в ритейле

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 6. Подведём итоги

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
