# %% [markdown]
# <center> <img src = https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/hh%20label.jpg alt="drawing" style="width:400px;">

# %% [markdown]
# # <center> Проект: Анализ резюме из HeadHunter

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# # Исследование структуры данных

# %% [markdown]
# 1. Прочитайте данные с помощью библиотеки Pandas. Совет: перед чтением обратите внимание на разделитель внутри файла.

# %%
#ваш код здесь
hh_data = pd.read_csv('data/dst-3.0_16_1_hh_database.csv', sep=';')

display(hh_data.shape)
# Out:
# (44744, 12)

# %% [markdown]
# 2. Выведите несколько первых (последних) строк таблицы, чтобы убедиться в том, что ваши данные не повреждены. Ознакомьтесь с признаками и их структурой.

# %%
#ваш код здесь

display(hh_data)
# Out:
#                                        Пол, возраст           ЗП  \
# 0        Мужчина ,  39 лет , родился 27 ноября 1979   29000 руб.
# 1         Мужчина ,  60 лет , родился 20 марта 1959   40000 руб.
# 2      Женщина ,  36 лет , родилась 12 августа 1982   20000 руб.
# 3          Мужчина ,  38 лет , родился 25 июня 1980  100000 руб.
# 4         Женщина ,  26 лет , родилась 3 марта 1993  140000 руб.
# ...                                             ...          ...
# 44739    Мужчина ,  30 лет , родился 17 января 1989   50000 руб.
# 44740      Мужчина ,  27 лет , родился 5 марта 1992   39000 руб.
# 44741  Женщина ,  48 лет , родилась 26 декабря 1970   40000 руб.
# 44742   Мужчина ,  24 года , родился 6 октября 1994   20000 руб.
# 44743    Мужчина ,  38 лет , родился 25 апреля 1980  120000 руб.
#
#                                Ищет работу на должность:  \
# 0                                Системный администратор
# 1                                   Технический писатель
# ...

# %% [markdown]
# 3. Выведите основную информацию о числе непустых значений в столбцах и их типах в таблице.

# %% [markdown]
# 4. Обратите внимание на информацию о числе непустых значений.

# %%
#ваш код здесь
hh_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44744 entries, 0 to 44743
# Data columns (total 12 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Пол, возраст                     44744 non-null  object
#  1   ЗП                               44744 non-null  object
#  2   Ищет работу на должность:        44744 non-null  object
#  3   Город, переезд, командировки     44744 non-null  object
#  4   Занятость                        44744 non-null  object
#  5   График                           44744 non-null  object
#  6   Опыт работы                      44576 non-null  object
#  7   Последнее/нынешнее место работы  44743 non-null  object
#  8   Последняя/нынешняя должность     44742 non-null  object
#  9   Образование и ВУЗ                44744 non-null  object
#  10  Обновление резюме                44744 non-null  object
#  11  Авто                             44744 non-null  object
# ...

# %% [markdown]
# 5. Выведите основную статистическую информацию о столбцах.

# %%
#ваш код здесь
print(f'Ответ: \n {hh_data["Опыт работы"].nunique()} уникальных значений содержится в столбце "Опыт работы"')

display(hh_data['Последняя/нынешняя должность'].value_counts(normalize=True))
# Out:
# Ответ:
#  44413 уникальных значений содержится в столбце "Опыт работы"
# Последняя/нынешняя должность
# Системный администратор                         0.046086
# Инженер                                         0.019713
# Инженер-программист                             0.014997
# Программист                                     0.010348
# Руководитель проектов                           0.008247
#                                                   ...
# Инженер-микроэлектроники                        0.000022
# Начальник отдела продаж новостроек              0.000022
# Web-мастер (фриланс)                            0.000022
# Ведущий инженер по планированию и учету ПАГК    0.000022
# SMM-менеджер/ SEO                               0.000022
# Name: proportion, Length: 16927, dtype: float64

# %% [markdown]
# # Преобразование данных

# %% [markdown]
# 1. Начнем с простого - с признака **"Образование и ВУЗ"**. Его текущий формат это: **<Уровень образования год выпуска ВУЗ специальность...>**. Например:
# * Высшее образование 2016 Московский авиационный институт (национальный исследовательский университет)...
# * Неоконченное высшее образование 2000  Балтийская государственная академия рыбопромыслового флота…
# Нас будет интересовать только уровень образования.
#
# Создайте с помощью функции-преобразования новый признак **"Образование"**, который должен иметь 4 категории: "высшее", "неоконченное высшее", "среднее специальное" и "среднее".
#
# Выполните преобразование, ответьте на контрольные вопросы и удалите признак "Образование и ВУЗ".
#
# Совет: обратите внимание на структуру текста в столбце **"Образование и ВУЗ"**. Гарантируется, что текущий уровень образования соискателя всегда находится в первых 2ух слов и начинается с заглавной буквы. Воспользуйтесь этим.
#
# *Совет: проверяйте полученные категории, например, с помощью метода unique()*

# %%
#ваш код здесь

def education_degree(row): #функция на преобразование столбца "Образование и ВУЗ"
    row_split = row.split(' ') #разделить строку по пробелам
    row_split = row_split[0:3] #взять только первые три слова
    if 'Высшее' in row_split: # в условии задания указано что гарантировано написание с заглавной буквы
        return 'высшее'
    elif 'Неоконченное' in row_split and 'высшее' in row_split:
        return 'неоконченное высшее'
    elif 'Среднее' in row_split and 'специальное' in row_split:
        return 'среднее специальное'
    elif 'Среднее' in row_split:
        return 'среднее'
    else:
        return 'другое' # пустых значений по образованию в таблице нет, если выдаст ДРУГОЕ значит гдето я накосячил с кодом


hh_data['Образование'] = hh_data['Образование и ВУЗ'].apply(education_degree)
# hh_data['Образование'] = hh_data['Образование'].astype('category') # преобразуем признак в категорию
hh_data = hh_data.drop('Образование и ВУЗ', axis=1) #по условию задания необходимо удалить оригинальный признак

display(hh_data['Образование'].value_counts(normalize=False))
print(f"Ответ: \n {hh_data['Образование'].value_counts().get('среднее', 0)} соискателей имеет средний уровень образования (школьное образование)")
# Out:
# Образование
# высшее                 33863
# среднее специальное     5765
# неоконченное высшее     4557
# среднее                  559
# Name: count, dtype: int64
# Ответ:
#  559 соискателей имеет средний уровень образования (школьное образование)

# %% [markdown]
# 2. Теперь нас интересует столбец **"Пол, возраст"**. Сейчас он представлен в формате **<Пол , возраст , дата рождения >**. Например:
# * Мужчина , 39 лет , родился 27 ноября 1979
# * Женщина , 21 год , родилась 13 января 2000
# Как вы понимаете, нам необходимо выделить каждый параметр в отдельный столбец.
#
# Создайте два новых признака **"Пол"** и **"Возраст"**. При этом важно учесть:
# * Признак пола должен иметь 2 уникальных строковых значения: 'М' - мужчина, 'Ж' - женщина.
# * Признак возраста должен быть представлен целыми числами.
#
# Выполните преобразование, ответьте на контрольные вопросы и удалите признак **"Пол, возраст"** из таблицы.
#
# *Совет: обратите внимание на структуру текста в столбце, в части на то, как разделены параметры пола, возраста и даты рождения между собой - символом ' , '.
# Гарантируется, что структура одинакова для всех строк в таблице. Вы можете воспользоваться этим.*

# %%
#ваш код здесь

def gender_extraction(row): #функция на преобразование столбца "Пол, возраст"
    row_split = row.split(', ') #разделить строку по запятым
    if 'муж' in row_split[0].lower():
        gender = 'М'
    elif 'жен' in row_split[0].lower():
        gender = 'Ж'
    return gender # вернуть первый элемент (Пол)

def age_extraction(row): #функция на преобразование столбца "Пол, возраст"
    row_split = row.split(', ') #разделить строку по запятым
    age = int(row_split[1].split(' ')[1])
    return age

hh_data['Пол'] = hh_data['Пол, возраст'].apply(gender_extraction)
# hh_data['Пол'] = hh_data['Пол'].astype('category') # преобразуем признак в категорию
hh_data['Возраст'] = hh_data['Пол, возраст'].apply(age_extraction)

hh_data = hh_data.drop('Пол, возраст', axis=1) #по условию задания необходимо удалить оригинальный признак

#display(hh_data['Возраст'].value_counts(normalize=False))
print(f"Ответ: \n Средний возраст соискателей {round(hh_data['Возраст'].mean(), 1)} лет")
display(hh_data['Пол'].value_counts(normalize=True))
# Out:
# Ответ:
#  Средний возраст соискателей 32.2 лет
# Пол
# М    0.809293
# Ж    0.190707
# Name: proportion, dtype: float64

# %% [markdown]
# 3. Следующим этапом преобразуем признак **"Опыт работы"**. Его текущий формат - это: **<Опыт работы: n лет m месяцев, периоды работы в различных компаниях…>**.
#
# Из столбца нам необходимо выделить общий опыт работы соискателя в месяцах, новый признак назовем "Опыт работы (месяц)"
#
# Для начала обсудим условия решения задачи:
# * Во-первых, в данном признаке есть пропуски. Условимся, что если мы встречаем пропуск, оставляем его как есть (функция-преобразование возвращает NaN)
# * Во-вторых, в данном признаке есть скрытые пропуски. Для некоторых соискателей в столбце стоит значения "Не указано". Их тоже обозначим как NaN (функция-преобразование возвращает NaN)
# * В-третьих, нас не интересует информация, которая описывается после указания опыта работы (периоды работы в различных компаниях)
# * В-четвертых, у нас есть проблема: опыт работы может быть представлен только в годах или только месяцах. Например, можно встретить следующие варианты:
#     * Опыт работы 3 года 2 месяца…
#     * Опыт работы 4 года…
#     * Опыт работы 11 месяцев…
#     * Учитывайте эту особенность в вашем коде
#
# Учитывайте эту особенность в вашем коде
#
# В результате преобразования у вас должен получиться столбец, содержащий информацию о том, сколько месяцев проработал соискатель.
# Выполните преобразование, ответьте на контрольные вопросы и удалите столбец **"Опыт работы"** из таблицы.

# %%
#ваш код здесь

# Словарь для преобразования числительных-слов в числа
russian_dict = {
    'ноль': 0, 'один': 1, 'одна': 1, 'два': 2, 'две': 2, 'три': 3, 'четыре': 4, 'пять': 5,
    'шесть': 6, 'семь': 7, 'восемь': 8, 'девять': 9, 'десять': 10, 'одиннадцать': 11, 'двенадцать': 12,
    'тринадцать': 13, 'четырнадцать': 14, 'пятнадцать': 15, 'шестнадцать': 16, 'семнадцать': 17,
    'восемнадцать': 18, 'девятнадцать': 19, 'двадцать': 20
}

def to_int(s):
    try:
        return int(s)
    except ValueError:
        return russian_dict.get(s.lower(), np.nan)

def experience(row): # функция опыт работы
    if pd.isnull(row) or row == 'Не указано':
        return np.nan
    row_split = row.split(' ')[:7]
    year = ('год', 'года', 'лет')
    month = ('месяц', 'месяца', 'месяцев')
    exp = 0
    i = 0
    while i < len(row_split):
        if row_split[i] in year:
            val = to_int(row_split[i-1])
            if not np.isnan(val):
                exp += val * 12
        elif row_split[i] in month:
            val = to_int(row_split[i-1])
            if not np.isnan(val):
                exp += val
        i += 1
    return exp if exp > 0 else np.nan

hh_data['Опыт работы (месяц)'] = hh_data['Опыт работы'].apply(experience)
hh_data = hh_data.drop('Опыт работы', axis=1) #по условию задания необходимо удалить оригинальный признак

display(hh_data['Опыт работы (месяц)'].describe())
print(f"Ответ: \n {hh_data['Опыт работы (месяц)'].median()} месяцев - медианный опыт работы (в месяцах) ")
# Out:
# count    44574.000000
# mean       114.418944
# std         79.047861
# min          1.000000
# 25%         57.000000
# 50%        100.000000
# 75%        154.000000
# max       1188.000000
# Name: Опыт работы (месяц), dtype: float64
# Ответ:
#  100.0 месяцев - медианный опыт работы (в месяцах)

# %% [markdown]
# 4. Хорошо идем! Следующий на очереди признак "Город, переезд, командировки". Информация в нем представлена в следующем виде: **<Город , (метро) , готовность к переезду (города для переезда) , готовность к командировкам>**. В скобках указаны необязательные параметры строки. Например, можно встретить следующие варианты:
#
# * Москва , не готов к переезду , готов к командировкам
# * Москва , м. Беломорская , не готов к переезду, не готов к командировкам
# * Воронеж , готов к переезду (Сочи, Москва, Санкт-Петербург) , готов к командировкам
#
# Создадим отдельные признаки **"Город"**, **"Готовность к переезду"**, **"Готовность к командировкам"**. При этом важно учесть:
#
# * Признак **"Город"** должен содержать только 4 категории: "Москва", "Санкт-Петербург" и "город-миллионник" (их список ниже), остальные обозначьте как "другие".
#
#     Список городов-миллионников:
#
#    <code>million_cities = ['Новосибирск', 'Екатеринбург','Нижний Новгород','Казань', 'Челябинск','Омск', 'Самара', 'Ростов-на-Дону', 'Уфа', 'Красноярск', 'Пермь', 'Воронеж','Волгоград']
#     </code>
#     Инфорация о метро, рядом с которым проживает соискатель нас не интересует.
# * Признак **"Готовность к переезду"** должен иметь два возможных варианта: True или False. Обратите внимание, что возможны несколько вариантов описания готовности к переезду в признаке "Город, переезд, командировки". Например:
#     * … , готов к переезду , …
#     * … , не готова к переезду , …
#     * … , готова к переезду (Москва, Санкт-Петербург, Ростов-на-Дону)
#     * … , хочу переехать (США) , …
#
#     Нас интересует только сам факт возможности или желания переезда.
# * Признак **"Готовность к командировкам"** должен иметь два возможных варианта: True или False. Обратите внимание, что возможны несколько вариантов описания готовности к командировкам в признаке "Город, переезд, командировки". Например:
#     * … , готов к командировкам , …
#     * … , готова к редким командировкам , …
#     * … , не готов к командировкам , …
#
#     Нас интересует только сам факт готовности к командировке.
#
#     Еще один важный факт: при выгрузки данных у некоторых соискателей "потерялась" информация о готовности к командировкам. Давайте по умолчанию будем считать, что такие соискатели не готовы к командировкам.
#
# Выполните преобразования и удалите столбец **"Город, переезд, командировки"** из таблицы.
#
# *Совет: обратите внимание на то, что структура текста может меняться в зависимости от указания ближайшего метро. Учите это, если будете использовать порядок слов в своей программе.*

# %%
#ваш код здесь

million_cities = ['Новосибирск', 'Екатеринбург', 'Нижний Новгород', 'Казань', 'Челябинск', 'Омск', 'Самара', 'Ростов-на-Дону', 'Уфа', 'Красноярск', 'Пермь', 'Воронеж', 'Волгоград' ]

def city_extraction(row): #функция на извлечение признака "Город"
    row_split = row.split(' , ')  # разделить строку по запятым
    if row_split[0] == 'Москва' or row_split[0] == 'Санкт-Петербург':
        return row_split[0]
    if row_split[0] in million_cities:
        return 'город-миллионник'
    else:
        return 'другие'

hh_data['Город'] = hh_data['Город, переезд, командировки'].apply(city_extraction)
display(hh_data['Город'].value_counts(normalize=True))


def readiness_moveout(row): #функция на извлечение признака "Готовность к переезду"
    row = row.lower()
    if ('не готов к переезду' in row) or ('не готова к переезду' in row):
        return False
    elif 'хочу' in row:
        return True
    else:
        return True

hh_data['Готовность к переезду'] = hh_data['Город, переезд, командировки'].apply(readiness_moveout)
display(hh_data['Готовность к переезду'].value_counts(normalize=True))


def ready_for_trips(row): #функция на извлечение признака "Готовность к командировкам"
    if ('командировка' in row):
        if 'не готов к командировкам' in row or 'не готова к командировкам' in row:
            return False
        else:
            return True
    else:
        return True

hh_data['Готовность к командировкам'] = hh_data['Город, переезд, командировки'].apply(ready_for_trips)
display(hh_data['Готовность к командировкам'].value_counts(normalize=True))

hh_data = hh_data.drop('Город, переезд, командировки', axis=1) #по условию задания необходимо удалить оригинальный признак

print(f"Ответ: \n {round(hh_data[hh_data['Готовность к переезду'] & hh_data['Готовность к командировкам']].shape[0] / hh_data.shape[0] * 100)} соискателей готовы одновременно и к переездам, и к командировкам")
print(f" {round(hh_data['Город'].value_counts(normalize=True)['Санкт-Петербург'] * 100)} процентов соискателей живут в Санкт-Петербурге")
# Out:
# Город
# Москва              0.371469
# другие              0.354327
# город-миллионник    0.163866
# Санкт-Петербург     0.110339
# Name: proportion, dtype: float64
# Готовность к переезду
# False    0.641851
# True     0.358149
# Name: proportion, dtype: float64
# Готовность к командировкам
# True     0.708832
# False    0.291168
# Name: proportion, dtype: float64
# Ответ:
#  32 соискателей готовы одновременно и к переездам, и к командировкам
#  11 процентов соискателей живут в Санкт-Петербурге

# %% [markdown]
# 5. Рассмотрим поближе признаки **"Занятость"** и **"График"**. Сейчас признаки представляют собой набор категорий желаемой занятости (полная занятость, частичная занятость, проектная работа, волонтерство, стажировка) и желаемого графика работы (полный день, сменный график, гибкий график, удаленная работа, вахтовый метод).
# На сайте hh.ru соискатель может указывать различные комбинации данных категорий, например:
# * полная занятость, частичная занятость
# * частичная занятость, проектная работа, волонтерство
# * полный день, удаленная работа
# * вахтовый метод, гибкий график, удаленная работа, полная занятость
#
# Такой вариант признаков имеет множество различных комбинаций, а значит множество уникальных значений, что мешает анализу. Нужно это исправить!
#
# Давайте создадим признаки-мигалки для каждой категории: если категория присутствует в списке желаемых соискателем, то в столбце на месте строки рассматриваемого соискателя ставится True, иначе - False.
#
# Такой метод преобразования категориальных признаков называется One Hot Encoding и его схема представлена на рисунке ниже:
# <img src=https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/ohe.jpg>
# Выполните данное преобразование для признаков "Занятость" и "График", ответьте на контрольные вопросы, после чего удалите их из таблицы

# %%
#ваш код здесь

#новые признаки по типу Занятости
hh_data['полная занятость'] = hh_data['Занятость'].apply(lambda x: True if 'полная занятость' in x else False)
hh_data['частичная занятость'] = hh_data['Занятость'].apply(lambda x: True if 'частичная занятость' in x else False)
hh_data['проектная работа'] = hh_data['Занятость'].apply(lambda x: True if 'проектная работа' in x else False)
hh_data['стажировка'] = hh_data['Занятость'].apply(lambda x: True if 'стажировка' in x else False)
hh_data['волонтерство'] = hh_data['Занятость'].apply(lambda x: True if 'волонтерство' in x else False)

#новые признаки по Графику работы
hh_data['полный день'] = hh_data['График'].apply(lambda x: True if 'полный день' in x else False)
hh_data['сменный график'] = hh_data['График'].apply(lambda x: True if 'сменный график' in x else False)
hh_data['гибкий график'] = hh_data['График'].apply(lambda x: True if 'гибкий график' in x else False)
hh_data['удалённая работа'] = hh_data['График'].apply(lambda x: True if 'удалённая работа' in x else False)
hh_data['вахтовый метод'] = hh_data['График'].apply(lambda x: True if 'вахтовый метод' in x else False)

hh_data = hh_data.drop('Занятость', axis=1) #по условию задания необходимо удалить оригинальный признак
hh_data = hh_data.drop('График', axis=1) #по условию задания необходимо удалить оригинальный признак

#Ответ
print(f"Ответ: \n {hh_data[(hh_data['проектная работа'] == True) & (hh_data['волонтерство'] == True)].shape[0]} людей ищут проектную работу и волонтерство")
print(f"{hh_data[(hh_data['вахтовый метод'] == True) & (hh_data['гибкий график'] == True)].shape[0]} людей хотят работать вахтовым методом и с гибким графиком")
# Out:
# Ответ:
#  436 людей ищут проектную работу и волонтерство
# 2311 людей хотят работать вахтовым методом и с гибким графиком

# %% [markdown]
# 6. (2 балла) Наконец, мы добрались до самого главного и самого важного - признака заработной платы **"ЗП"**.
# В чем наша беда? В том, что помимо желаемой заработной платы соискатель указывает валюту, в которой он бы хотел ее получать, например:
# * 30000 руб.
# * 50000 грн.
# * 550 USD
#
# Нам бы хотелось видеть заработную плату в единой валюте, например, в рублях. Возникает вопрос, а где взять курс валют по отношению к рублю?
#
# На самом деле язык Python имеет в арсенале огромное количество возможностей получения данной информации, от обращения к API Центробанка, до использования специальных библиотек, например pycbrf. Однако, это не тема нашего проекта.
#
# Поэтому мы пойдем в лоб: обратимся к специальным интернет-ресурсам для получения данных о курсе в виде текстовых файлов. Например, MDF.RU, данный ресурс позволяет удобно экспортировать данные о курсах различных валют и акций за указанные периоды в виде csv файлов. Мы уже сделали выгрузку курсов валют, которые встречаются в наших данных за период с 29.12.2017 по 05.12.2019. Скачать ее вы можете **на платформе**
#
# Создайте новый DataFrame из полученного файла. В полученной таблице нас будут интересовать столбцы:
# * "currency" - наименование валюты в ISO кодировке,
# * "date" - дата,
# * "proportion" - пропорция,
# * "close" - цена закрытия (последний зафиксированный курс валюты на указанный день).
#
#
# Перед вами таблица соответствия наименований иностранных валют в наших данных и их общепринятых сокращений, которые представлены в нашем файле с курсами валют. Пропорция - это число, за сколько единиц валюты указан курс в таблице с курсами. Например, для казахстанского тенге курс на 20.08.2019 составляет 17.197 руб. за 100 тенге, тогда итоговый курс равен - 17.197 / 100 = 0.17197 руб за 1 тенге.
# Воспользуйтесь этой информацией в ваших преобразованиях.
#
# <img src=https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/table.jpg>
#
#
# Осталось только понять, откуда брать дату, по которой определяется курс? А вот же она - в признаке **"Обновление резюме"**, в нем содержится дата и время, когда соискатель выложил текущий вариант своего резюме. Нас интересует только дата, по ней бы и будем сопоставлять курсы валют.
#
# Теперь у нас есть вся необходимая информация для того, чтобы создать признак "ЗП (руб)" - заработная плата в рублях.
#
# После ответа на контрольные вопросы удалите исходный столбец заработной платы "ЗП" и все промежуточные столбцы, если вы их создавали.

# %% [markdown]
# Итак, давайте обсудим возможный алгоритм преобразования:
# 1. Перевести признак "Обновление резюме" из таблицы с резюме в формат datetime и достать из него дату. В тот же формат привести признак "date" из таблицы с валютами.
# 2. Выделить из столбца "ЗП" сумму желаемой заработной платы и наименование валюты, в которой она исчисляется. Наименование валюты перевести в стандарт ISO согласно с таблицей выше.
# 3. Присоединить к таблице с резюме таблицу с курсами по столбцам с датой и названием валюты (подумайте, какой тип объединения надо выбрать, чтобы в таблице с резюме сохранились данные о заработной плате, изначально представленной в рублях). Значение close для рубля заполнить единицей 1 (курс рубля самого к себе)
# 4. Умножить сумму желаемой заработной платы на присоединенный курс валюты (close) и разделить на пропорцию (обратите внимание на пропуски после объединения в этих столбцах), результат занести в новый столбец "ЗП (руб)".

# %%
#ваш код здесь

# Загрузка данных о курсах валют
currency_data = pd.read_csv('data/ExchangeRates.csv', sep=',')
currency_data = currency_data.drop(['per', 'time', 'vol'], axis=1)

# Преобразуем столбец 'date' в формат datetime
currency_data['date'] = pd.to_datetime(currency_data['date'], dayfirst=True).dt.date
# display(currency_data.head())

# Преобразуем столбец 'date' в формат даты без времени
hh_data['Обновление резюме'] = pd.to_datetime(hh_data['Обновление резюме'], dayfirst=True).dt.date

#Выделить из столбца «ЗП» сумму желаемой заработной платы и наименование валюты, в которой она исчисляется. Наименование валюты перевести в стандарт ISO согласно таблице выше
def salary_extraction(row):
    if pd.isnull(row) or row == 'Не указана':
        return np.nan, np.nan
    row_split = row.split(' ')
    if len(row_split) < 2:
        return np.nan, np.nan
    salary = int(row_split[0].replace(' ', ''))  # Удаляем пробелы и преобразуем в число
    currency = row_split[1].replace('.', '')  # Удаляем точку из названия валюты
    return salary, currency

hh_data['ЗП сумма'], hh_data['ЗП валюта'] = zip(*hh_data['ЗП'].apply(salary_extraction))

# словарь для преобразования валют в ISO-стандарт
currency_dict = {
        'USD': 'USD', 'KZT': 'KZT',
        'грн': 'UAH', 'белруб': 'BYN',
        'EUR': 'EUR', 'KGS': 'KGS',
        'сум': 'UZS', 'AZN': 'AZN'
    }

# Функция для преобразования валюты в ISO-стандарт
def currency_conversion(curr):
    if curr == 'руб':
        return 'RUB'
    else:
        return currency_dict[curr]

# Применяем функцию для преобразования валюты
hh_data['ЗП валюта'] = hh_data['ЗП валюта'].apply(currency_conversion)

# Объединяем данные по двум столбцам: 'ЗП валюта' и 'Обновление резюме'
merged_data = hh_data.merge(
    currency_data, 
    left_on=['ЗП валюта', 'Обновление резюме'],
    right_on=['currency', 'date',], 
    how='left'
)

# Заполняем пропуски в столбцах 'close' и 'proportion' значением 1, если они есть
merged_data['close'] = merged_data['close'].fillna(1)
merged_data['proportion'] = merged_data['proportion'].fillna(1)

# Создаем признак для желаемой заработной платы в рублях
merged_data['ЗП (руб)'] = merged_data['close'] * merged_data['ЗП сумма'] / merged_data['proportion']

# убираем временные признаки
merged_data = merged_data.drop(['ЗП', 'ЗП сумма', 'ЗП валюта', 'currency', 'date', 'close', 'proportion'], axis=1)

# display(merged_data.head())
print(f" Ответ: \n Желаемая медианная заработная плата соискателей составляет: {round(merged_data['ЗП (руб)'].median()/1000)} тыс. рублей")
# Out:
# C:\Users\tgorbunov\AppData\Local\Temp\ipykernel_36148\1104367120.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   currency_data['date'] = pd.to_datetime(currency_data['date'], dayfirst=True).dt.date
#  Ответ:
#  Желаемая медианная заработная плата соискателей составляет: 59 тыс. рублей

# %% [markdown]
# # Исследование зависимостей в данных

# %% [markdown]
# 1. Постройте распределение признака **"Возраст"**. Опишите распределение, отвечая на следующие вопросы: чему равна мода распределения, каковы предельные значения признака, в каком примерном интервале находится возраст большинства соискателей? Есть ли аномалии для признака возраста, какие значения вы бы причислили к их числу?
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
# ваш код здесь

age_distribution = merged_data['Возраст']
display(merged_data['Возраст'].describe())

fig = plt.figure(figsize=(6, 4))
axes = fig.add_axes([0, 0, 1, 1])
sns.histplot(
    x=age_distribution,
    color='blue', bins=40,
    ax=axes
)
axes.grid()
axes.set_xlabel('Возраст')
axes.set_ylabel('Количество соискателей')
axes.set_title('Гистограмма распределения возраста соискателей')
axes.xaxis.set_tick_params(rotation=30)


fig = plt.figure(figsize=(8, 5))
box_plot_age = sns.boxplot(
    data=merged_data,
    x='Пол',
    y='Возраст',
    orient='v',
    width=0.5,
    hue='Пол'
)
box_plot_age.set_xticklabels(['Мужской', 'Женский'])
box_plot_age.set_xlabel('Пол')
box_plot_age.set_ylabel('Возраст соискателей')
box_plot_age.set_title('Распределение возраста соискателей по полу')
box_plot_age.grid()

print(f"Ответ: \n Мода по возрасту соискателей: {merged_data['Возраст'].mode()} лет")
# Out:
# count    44744.000000
# mean        32.196741
# std          7.929800
# min         14.000000
# 25%         27.000000
# 50%         31.000000
# 75%         36.000000
# max        100.000000
# Name: Возраст, dtype: float64
# Ответ:
#  Мода по возрасту соискателей: 0    30
# Name: Возраст, dtype: int64 лет
# C:\Users\tgorbunov\AppData\Local\Temp\ipykernel_36148\3657713269.py:29: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   box_plot_age.set_xticklabels(['Мужской', 'Женский'])

# %% [markdown]
# ваши выводы по графику здесь:
# - мода распределения равна 30 годам
# - большинство соискателей (М + Ж) в возрасте от 27 до 36 лет
# - к аномалиям отнес бы кандидата возрастом 100 лет

# %% [markdown]
# 2. Постройте распределение признака **"Опыт работы (месяц)"**. Опишите данное распределение, отвечая на следующие вопросы: чему равна мода распределения, каковы предельные значения признака, в каком примерном интервале находится опыт работы большинства соискателей? Есть ли аномалии для признака опыта работы, какие значения вы бы причислили к их числу?
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
# ваш код здесь

experience_distribution = merged_data['Опыт работы (месяц)']
display(merged_data['Опыт работы (месяц)'].describe())

fig = plt.figure(figsize=(6, 4))
axes = fig.add_axes([0, 0, 1, 1])
sns.histplot(
    x=experience_distribution,
    color='blue', bins=40,
    ax=axes
)
axes.grid()
axes.set_xlabel('Опыт работы (месяц)')
axes.set_ylabel('Количество соискателей')
axes.set_title('Гистограмма распределения опыта работы соискателей')
axes.xaxis.set_tick_params(rotation=30)

fig = plt.figure(figsize=(8, 5))
box_plot_experience = sns.boxplot(
    data=merged_data,
    #x='Пол',
    y='Опыт работы (месяц)',
    orient='v',
    width=0.5,
    #hue='Пол'
)
box_plot_experience.set_xticklabels(['Соискатели'])
box_plot_experience.set_ylabel('Опыт работы (месяц)')
box_plot_experience.set_title('Распределение опыта работы соискателей')
box_plot_experience.grid()

print(f"Ответ: \n Максимальный опыт работы соискателей: {merged_data['Опыт работы (месяц)'].max()} месяцев")
print(f"Мода по опыту работы соискателей: {merged_data['Опыт работы (месяц)'].mode()} месяцев")
# Out:
# count    44574.000000
# mean       114.418944
# std         79.047861
# min          1.000000
# 25%         57.000000
# 50%        100.000000
# 75%        154.000000
# max       1188.000000
# Name: Опыт работы (месяц), dtype: float64
# Ответ:
#  Максимальный опыт работы соискателей: 1188.0 месяцев
# Мода по опыту работы соискателей: 0    81.0
# Name: Опыт работы (месяц), dtype: float64 месяцев
# C:\Users\tgorbunov\AppData\Local\Temp\ipykernel_36148\3167232541.py:28: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   box_plot_experience.set_xticklabels(['Соискатели'])

# %% [markdown]
# ваши выводы здесь:
# - Мода распределения равна 81 месяц
# - Предельные значения признака (Макс= 1188 месяцев; Мин= 1 месяц)
# -  Опыт работы большинства соискателей находится в интервале 57-154 месяцев
# - Аномалии для признака опыт работы 1188 месяцев (99 лет) не возможно на практике.

# %% [markdown]
# 3. Постройте распределение признака **"ЗП (руб)"**. Опишите данное распределение, отвечая на следующие вопросы: каковы предельные значения признака, в каком примерном интервале находится заработная плата большинства соискателей? Есть ли аномалии для признака возраста? Обратите внимание на гигантские размеры желаемой заработной платы.
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
# ваш код здесь

salary_extraction_distribution = merged_data['ЗП (руб)']
display(merged_data['ЗП (руб)'].describe())

fig = plt.figure(figsize=(6, 4))
axes = fig.add_axes([0, 0, 1, 1])
sns.histplot(
    x=salary_extraction_distribution,
    color='blue', bins=40,
    ax=axes
)
axes.grid()
axes.set_xlabel('ЗП (руб)')
axes.set_ylabel('Количество соискателей')
axes.set_title('Гистограмма распределения ЗП соискателей')
axes.xaxis.set_tick_params(rotation=30)

fig = plt.figure(figsize=(8, 5))
box_plot_salary = sns.boxplot(
    data=merged_data,
    #x='Пол',
    y='ЗП (руб)',
    orient='v',
    width=0.5,
    #hue='Пол'
)
box_plot_salary.set_xticklabels(['Соискатели'])
box_plot_salary.set_ylabel('ЗП (руб)')
box_plot_salary.set_title('Распределение ЗП соискателей')
box_plot_salary.grid()

print(f"Ответ: \n Максимальная ЗП соискателей: {merged_data['ЗП (руб)'].max()} рублей")
print(f"Минимальная ЗП соискателей: {merged_data['ЗП (руб)'].min()} рублей")
print(f"Мода по ЗП соискателей: {merged_data['ЗП (руб)'].mode()} рублей")
print(f"ЗП выше 1млн руб: {merged_data['ЗП (руб)'][merged_data['ЗП (руб)'] > 1000000].count()} соискателей")
# Out:
# count    4.474400e+04
# mean     7.653354e+04
# std      1.359315e+05
# min      1.000000e+00
# 25%      3.708220e+04
# 50%      5.901900e+04
# 75%      9.500000e+04
# max      2.430488e+07
# Name: ЗП (руб), dtype: float64
# Ответ:
#  Максимальная ЗП соискателей: 24304876.0 рублей
# Минимальная ЗП соискателей: 1.0 рублей
# Мода по ЗП соискателей: 0    50000.0
# Name: ЗП (руб), dtype: float64 рублей
# ЗП выше 1млн руб: 5 соискателей
# C:\Users\tgorbunov\AppData\Local\Temp\ipykernel_36148\1609851657.py:28: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   box_plot_salary.set_xticklabels(['Соискатели'])

# %% [markdown]
# ваши выводы здесь:
# - Мода распределения ЗП 50000 руб
# - Предельные значения признака Min=1 руб; Max=24'304'880 руб
# - Заработная плата большинства соискателей находится в интервале 37082 - 59019 руб
# - Аномалии для признака заработной платы являются минимальные и максимальные значения которые не соответствуют действительности.
# - 5 соискателей требуют заработную плату выше 1 миллиона рублей

# %% [markdown]
# 4. Постройте диаграмму, которая показывает зависимость **медианной** желаемой заработной платы (**"ЗП (руб)"**) от уровня образования (**"Образование"**). Используйте для диаграммы данные о резюме, где желаемая заработная плата меньше 1 млн рублей.
# *Сделайте выводы по представленной диаграмме: для каких уровней образования наблюдаются наибольшие и наименьшие уровни желаемой заработной платы? Как вы считаете, важен ли признак уровня образования при прогнозировании заработной платы?*

# %%
# ваш код здесь
# Фильтруем данные: только ЗП < 1 млн руб
salary_education_data = merged_data[merged_data['ЗП (руб)'] < 1_000_000]

fig = plt.figure(figsize=(5, 4))
box_plot_salary_education = sns.boxplot(
    data=salary_education_data,
    y='Образование',
    x='ЗП (руб)',
    orient='h',
    width=0.5,
    hue='Образование'
)
box_plot_salary_education.set_ylabel('Образование')
box_plot_salary_education.set_xlabel('ЗП (руб)')
box_plot_salary_education.set_title('Распределение ЗП по уровню образования')
box_plot_salary_education.grid()

# %% [markdown]
# ваши выводы здесь:
# - "Высшее" образование имеет наибольший уровень желаемой заработной платы
# - "Среднее" образование иммеет наименьший уровень желаемой заработной платы
# - Признак уровня образования важен при прогнозировании заработной платы

# %% [markdown]
# 5. Постройте диаграмму, которая показывает распределение желаемой заработной платы (**"ЗП (руб)"**) в зависимости от города (**"Город"**). Используйте для диаграммы данные о резюме, где желая заработная плата меньше 1 млн рублей.
# *Сделайте выводы по полученной диаграмме: как соотносятся медианные уровни желаемой заработной платы и их размах в городах? Как вы считаете, важен ли признак города при прогнозировании заработной платы?*

# %%
# ваш код здесь
# Фильтруем данные: только ЗП < 1 млн руб
salary_education_data = merged_data[merged_data['ЗП (руб)'] < 1_000_000]

fig = plt.figure(figsize=(5, 4))
box_plot_salary_education = sns.boxplot(
    data=salary_education_data,
    y='Город',
    x='ЗП (руб)',
    orient='h',
    width=0.5,
    hue='Город'
)
box_plot_salary_education.set_ylabel('Город')
box_plot_salary_education.set_xlabel('ЗП (руб)')
box_plot_salary_education.set_title('Распределение ЗП по городу и уровню образования')
box_plot_salary_education.grid()

print(f"Медианная ЗП в Москве: {salary_education_data[salary_education_data['Город'] == 'Москва']['ЗП (руб)'].median()}")
print(f"Медианная ЗП в Санкт-Петербурге: {salary_education_data[salary_education_data['Город'] == 'Санкт-Петербург']['ЗП (руб)'].median()}")
print(f"Медианная ЗП в городе-миллионнике: {salary_education_data[salary_education_data['Город'] == 'город-миллионник']['ЗП (руб)'].median()}")
print(f"Медианная ЗП в другие: {salary_education_data[salary_education_data['Город'] == 'другие']['ЗП (руб)'].median()}")
# Out:
# Медианная ЗП в Москве: 85000.0
# Медианная ЗП в Санкт-Петербурге: 60000.0
# Медианная ЗП в городе-миллионнике: 40000.0
# Медианная ЗП в другие: 40000.0

# %% [markdown]
# ваши выводы здесь:
# 1. Медианные уровни желаемой заработной платы и их размах в городах:
#     - Медианная ЗП в Москве: 85000.0
#     - Медианная ЗП в Санкт-Петербурге: 60000.0
#     - Медианная ЗП в городе-миллионнике: 40000.0
#     - Медианная ЗП в другие: 40000.0
# 2. Да, признак города важен при прогнозировании заработной платы

# %% [markdown]
# 6. Постройте **многоуровневую столбчатую диаграмму**, которая показывает зависимость медианной заработной платы (**"ЗП (руб)"**) от признаков **"Готовность к переезду"** и **"Готовность к командировкам"**. Проанализируйте график, сравнив уровень заработной платы в категориях.

# %%
# ваш код здесь

# Группируем по двум признакам и считаем медиану и количество
median_per_status = (
    merged_data
    .groupby(['Готовность к переезду', 'Готовность к командировкам'])['ЗП (руб)']
    .agg(['median', 'count'])
    .reset_index()
)

# Строим многоуровневую столбчатую диаграмму медианной ЗП
fig, ax = plt.subplots(figsize=(7, 5))
sns.barplot(
    data=median_per_status,
    x='Готовность к переезду',
    y='median',
    hue='Готовность к командировкам',
    ax=ax
)

ax.set_title('Медианная ЗП в зависимости от готовности к переезду и командировкам')
ax.set_xlabel('Готовность к переезду')
ax.set_ylabel('Медианная ЗП (руб)')
ax.grid(axis='y')
plt.legend(title='Готовность к командировкам')
plt.show()

filtered = merged_data[
    (merged_data['Готовность к переезду'] == True) & 
    (merged_data['Готовность к командировкам'] == True)
]
answer = filtered['ЗП (руб)'].median()
print(f"Ответ: \n Медианная ЗП соискателей, готовых к переезду и командировкам: {answer} рублей")
# Out:
# Ответ:
#  Медианная ЗП соискателей, готовых к переезду и командировкам: 67000.0 рублей

# %% [markdown]
# ваши выводы здесь:
# - Медианная ЗП соискателей, готовых к переезду и командировкам: 67000.0 рублей
# - Медианная ЗП для готовых к переездам и командировкам наивысшая, по сравнению с другими комбинациями

# %% [markdown]
# 7. Постройте сводную таблицу, иллюстрирующую зависимость **медианной** желаемой заработной платы от возраста (**"Возраст"**) и образования (**"Образование"**). На полученной сводной таблице постройте **тепловую карту**. Проанализируйте тепловую карту, сравнив показатели внутри групп.

# %%
# ваш код здесь
#churn_data['Exited_int'] = churn_data['Exited'].astype(int)
pivot_table = merged_data.pivot_table(
    index='Образование',
    columns='Возраст',
    values='ЗП (руб)',
    aggfunc='median'
)

display(pivot_table)

plt.figure(figsize=(12, 4))
sns.heatmap(
    pivot_table,
    #annot=True,
    fmt=".2f",
    cmap="Reds"
)
plt.title('Медианная ЗП по категориям образования и возрасту')
plt.ylabel('Образование соискателей')
plt.xlabel('Возраст соискателей')
plt.show()
# Out:
# Возраст                  14       15         16       17       18       19   \
# Образование
# высшее               60000.0      NaN  122582.49  90075.5  30000.0  30000.0
# неоконченное высшее      NaN      NaN        NaN  80000.0  25000.0  30000.0
# среднее                  NaN  10000.0        NaN  44000.0  35000.0  45000.0
# среднее специальное      NaN   2000.0   30000.00  25000.0  25151.0  30000.0
#
# Возраст                  20       21       22       23   ...       67   \
# Образование                                              ...
# высшее               30000.0  35000.0  40000.0  45000.0  ...   70000.0
# неоконченное высшее  31000.0  35000.0  40000.0  40000.0  ...       NaN
# среднее              29000.0  40000.0  40000.0  35000.0  ...       NaN
# среднее специальное  30000.0  30000.0  30000.0  35000.0  ...  120000.0
#
# Возраст                  68        69       70       71       72       73   \
# Образование
# ...

# %% [markdown]
# ваши выводы здесь:
# - Наивысшие медианные ЗП для группы соискателей с "высшим" образованием
# - для той же группы с "высшим образованием" наивысшие значения наблюдается в возрасте 38-48 лет

# %% [markdown]
# 8. Постройте **диаграмму рассеяния**, показывающую зависимость опыта работы (**"Опыт работы (месяц)"**) от возраста (**"Возраст"**). Опыт работы переведите из месяцев в года, чтобы признаки были в едином масштабе. Постройте на графике дополнительно прямую, проходящую через точки (0, 0) и (100, 100). Данная прямая соответствует значениям, когда опыт работы равен возрасту человека. Точки, лежащие на этой прямой и выше нее - аномалии в наших данных (опыт работы больше либо равен возрасту соискателя)

# %%
# ваш код здесь
fig = plt.figure(figsize=(10, 5))
scatter_data = merged_data.copy()
scatter_data['Опыт работы (год)'] = scatter_data['Опыт работы (месяц)']/12
sns.lineplot(x=[0, 100], y=[0, 100])
ax = sns.scatterplot(
    data=scatter_data, 
    x='Возраст',
    y='Опыт работы (год)',
)
ax.set_title('Зависимость опыта работы от возраста');

# %% [markdown]
# ваши выводы здесь:
# - 6 точек лежат на линии или выше нее, можно удалить из данных как аномалии

# %% [markdown]
# **Дополнительные баллы**
#
# Для получения 2 дополнительных баллов по разведывательному анализу постройте еще два любых содержательных графика или диаграммы, которые помогут проиллюстрировать влияние признаков/взаимосвязь между признаками/распределения признаков. Приведите выводы по ним. Желательно, чтобы в анализе участвовали признаки, которые мы создавали ранее в разделе "Преобразование данных".

# %%
# ваш код здесь

# %% [markdown]
# ваши выводы здесь

# %% [markdown]
# # Очистка данных

# %% [markdown]
# 1. Начнем с дубликатов в наших данных. Найдите **полные дубликаты** в таблице с резюме и удалите их.

# %%
# ваш код здесь
duplicates = merged_data[merged_data.duplicated(subset=merged_data.columns)]
merged_data = merged_data.drop_duplicates()
print(duplicates.shape[0])
# Out:
# 161

# %% [markdown]
# 2. Займемся пропусками. Выведите информацию **о числе пропусков** в столбцах.

# %%
# ваш код здесь
null_data = merged_data.isnull().sum()
display(null_data[null_data > 0])
# Out:
# Последнее/нынешнее место работы      1
# Последняя/нынешняя должность         2
# Опыт работы (месяц)                168
# dtype: int64

# %% [markdown]
# 3. Итак, у нас есть пропуски в 3ех столбцах: **"Опыт работы (месяц)"**, **"Последнее/нынешнее место работы"**, **"Последняя/нынешняя должность"**. Поступим следующим образом: удалите строки, где есть пропуск в столбцах с местом работы и должностью. Пропуски в столбце с опытом работы заполните **медианным** значением.

# %%
# ваш код здесь
merged_data = merged_data.dropna(subset=['Последнее/нынешнее место работы', 'Последняя/нынешняя должность'])
merged_data['Опыт работы (месяц)'] = merged_data['Опыт работы (месяц)'].fillna(merged_data['Опыт работы (месяц)'].median())
print(round(merged_data['Опыт работы (месяц)'].mean()))
# Out:
# 114

# %% [markdown]
# 4. Мы добрались до ликвидации выбросов. Сначала очистим данные вручную. Удалите резюме, в которых указана заработная плата либо выше 1 млн. рублей, либо ниже 1 тыс. рублей.

# %%
# ваш код здесь
outliers = merged_data[(merged_data['ЗП (руб)'] > 1000000) | (merged_data['ЗП (руб)'] < 1000)]
merged_data = merged_data.drop(outliers.index)
print(outliers.shape[0])
# Out:
# 89

# %% [markdown]
# 5. В процессе разведывательного анализа мы обнаружили резюме, в которых **опыт работы в годах превышал возраст соискателя**. Найдите такие резюме и удалите их из данных

# %%
# ваш код здесь
outliers = merged_data[merged_data['Опыт работы (месяц)']/12 >= merged_data['Возраст']]
merged_data = merged_data.drop(outliers.index)
print(outliers.shape[0])
# Out:
# 7

# %% [markdown]
# 6. В результате анализа мы обнаружили потенциальные выбросы в признаке **"Возраст"**. Это оказались резюме людей чересчур преклонного возраста для поиска работы. Попробуйте построить распределение признака в **логарифмическом масштабе**. Добавьте к графику линии, отображающие **среднее и границы интервала метода трех сигм**. Напомним, сделать это можно с помощью метода axvline. Например, для построение линии среднего будет иметь вид:
#
# `histplot.axvline(log_age.mean(), color='k', lw=2)`
#
# В какую сторону асимметрично логарифмическое распределение? Напишите об этом в комментарии к графику.
# Найдите выбросы с помощью метода z-отклонения и удалите их из данных, используйте логарифмический масштаб. Давайте сделаем послабление на **1 сигму** (возьмите 4 сигмы) в **правую сторону**.
#
# Выведите таблицу с полученными выбросами и оцените, с каким возрастом соискатели попадают под категорию выбросов?

# %%
# ваш код здесь
fig, ax = plt.subplots(1, 1, figsize=(8, 4))
log_age = np.log(merged_data['Возраст'] + 1)
histplot = sns.histplot(log_age, bins=30, ax=ax)
histplot.axvline(log_age.mean(), color='k', lw=2)
histplot.axvline(log_age.mean()+ 4 *log_age.std(), color='k', ls='--', lw=2)
histplot.axvline(log_age.mean()- 3 *log_age.std(), color='k', ls='--', lw=2)
histplot.set_title('Log Age Distribution');

def outliers_z_score_mod(data, feature, left=3, right=3, log_scale=False):
    if log_scale:
        x = np.log(data[feature]+1)
    else:
        x = data[feature]
    mu = x.mean()
    sigma = x.std()
    lower_bound = mu - left * sigma
    upper_bound = mu + right * sigma
    outliers = data[(x < lower_bound) | (x > upper_bound)]
    cleaned = data[(x >= lower_bound) & (x <= upper_bound)]
    return outliers, cleaned
outliers, cleaned_data = outliers_z_score_mod(merged_data, 'Возраст', left=3,  right=4, log_scale=True)
print(outliers.shape[0])

display(outliers.head())
# Out:
# 3
#             Ищет работу на должность: Последнее/нынешнее место работы  \
# 31137  Менеджер по работе с клиентами           ООО "ФёрстКэшКомпани"
# 32950                 Тестировщик игр                        OOO ЖМЫХ
# 33654            Frontend-разработчик                       Freelance
#
#          Последняя/нынешняя должность Обновление резюме        Авто  \
# 31137  Менеджер по работе с клиентами        2019-04-06  Не указано
# 32950                  Тестировщик ПО        2019-04-09  Не указано
# 33654            Frontend-разработчик        2019-04-19  Не указано
#
#                Образование Пол  Возраст  Опыт работы (месяц)            Город  \
# 31137              среднее   М       15                  2.0  Санкт-Петербург
# 32950  среднее специальное   М       15                  3.0           другие
# 33654  среднее специальное   М      100                 30.0  Санкт-Петербург
#
#        ...  частичная занятость  проектная работа  стажировка  волонтерство  \
# ...

# %% [markdown]
# ваш комментарий здесь:
# - В Категорию выбросов попали 3 соискателя с возрастом 15, 15, 100 лет что не может соответствовать действительности.

# %% [markdown]
# ### <center> Пометка для ментора <center> ###
#
# Я решил преобразовать данные с целью уменьшения размера файла. В итоге вышло 14Mb , так что заливать его на гугл драйв не вижу смысла, файл подгружен на GitHub

# %%
merged_data['Пол'] = merged_data['Пол'].astype('category') # преобразуем признак в категорию
merged_data['Образование'] = merged_data['Образование'].astype('category') # преобразуем признак в категорию
merged_data['Город'] = merged_data['Город'].astype('category') # преобразуем признак в категорию

merged_data.info()
merged_data.to_csv('data/dst-3.0_16_1_hh_database_updated.csv', sep=';')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 44485 entries, 0 to 44743
# Data columns (total 23 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Ищет работу на должность:        44485 non-null  object
#  1   Последнее/нынешнее место работы  44485 non-null  object
#  2   Последняя/нынешняя должность     44485 non-null  object
#  3   Обновление резюме                44485 non-null  object
#  4   Авто                             44485 non-null  object
#  5   Образование                      44485 non-null  category
#  6   Пол                              44485 non-null  category
#  7   Возраст                          44485 non-null  int64
#  8   Опыт работы (месяц)              44485 non-null  float64
#  9   Город                            44485 non-null  category
#  10  Готовность к переезду            44485 non-null  bool
#  11  Готовность к командировкам       44485 non-null  bool
# ...
